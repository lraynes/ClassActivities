# %% [markdown]
# # Students Turn Activity 1 API Recap
#
# In this warm-up activity, we will utilize the openweathermapy API wrapper to query the OpenWeatherMap API.
#
# * **Instructions:**
#
#   * Using the starter file and openweathermapy API wrapper, write a script to check the five-day forecast for Phoenix, Arizona.
#
#   * Your final code should the print the results using the below format:
#
#     ```output
#     2017-01-17 09:00:00 | 43.92 F
#     2017-01-17 12:00:00 | 40.62 F
#     2017-01-17 15:00:00 | 39.07 F
#     ```
#
# * **Hints:**
#
#   * See the [OpenWeatherMap API Documentation](https://openweathermap.org/api)
#
# * **Bonus:**
#
#   1. Use a method from openweathermapy that will parse through every record returned, extracting the desired data, without the use of a loop.
#
#   2. Create code that will plot the forecasted temperature over time.

# %%
# Dependencies
import openweathermapy.core as owm

# Import api_key
from config import api_key

# %%
# Create settings parameters
settings = {"units": "imperial", "appid": api_key}

# %%
# make the API call using a method from openweathermapy that 
# returns hourly forecasts for Phoenix, AZ and prints the result
city_name = "Phoenix"
country_code = "US"

current_weather_phoenix = owm.get_forecast_hourly("Phoenix, US", **settings)
print(f"{current_weather_phoenix}")
# Out:
# [{'dt': 1527822000, 'main': {'temp': 87.46, 'temp_min': 85.16, 'temp_max': 87.46, 'pressure': 967.79, 'sea_level': 1019.43, 'grnd_level': 967.79, 'humidity': 17, 'temp_kf': 1.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 7.96, 'deg': 245.501}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-01 03:00:00'}, {'dt': 1527832800, 'main': {'temp': 73.36, 'temp_min': 71.63, 'temp_max': 73.36, 'pressure': 969.11, 'sea_level': 1021.39, 'grnd_level': 969.11, 'humidity': 33, 'temp_kf': 0.96}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.38, 'deg': 257.502}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-01 06:00:00'}, {'dt': 1527843600, 'main': {'temp': 66.51, 'temp_min': 65.36, 'temp_max': 66.51, 'pressure': 969.35, 'sea_level': 1021.82, 'grnd_level': 969.35, 'humidity': 41, 'temp_kf': 0.64}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 5.06, 'deg': 203.502}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-01 09:00:00'}, {'dt': 1527854400, 'main': {'temp': 59.88, 'temp_min': 59.31, 'temp_max': 59.88, 'pressure': 970.51, 'sea_level': 1023.19, 'grnd_level': 970.51, 'humidity': 50, 'temp_kf': 0.32}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.18, 'deg': 121.514}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-01 12:00:00'}, {'dt': 1527865200, 'main': {'temp': 77.31, 'temp_min': 77.31, 'temp_max': 77.31, 'pressure': 972.31, 'sea_level': 1024.47, 'grnd_level': 972.31, 'humidity': 23, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.32, 'deg': 89.0054}, 'sys': {'pod': 'd'}, 'dt_txt': '2018-06-01 15:00:00'}, {'dt': 1527876000, 'main': {'temp': 89.7, 'temp_min': 89.7, 'temp_max': 89.7, 'pressure': 972.19, 'sea_level': 1023.95, 'grnd_level': 972.19, 'humidity': 19, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.94, 'deg': 164.003}, 'sys': {'pod': 'd'}, 'dt_txt': '2018-06-01 18:00:00'}, {'dt': 1527886800, 'main': {'temp': 95.14, 'temp_min': 95.14, 'temp_max': 95.14, 'pressure': 970.64, 'sea_level': 1022.12, 'grnd_level': 970.64, 'humidity': 17, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.94, 'deg': 217}, 'sys': {'pod': 'd'}, 'dt_txt': '2018-06-01 21:00:00'}, {'dt': 1527897600, 'main': {'temp': 95.81, 'temp_min': 95.81, 'temp_max': 95.81, 'pressure': 969.38, 'sea_level': 1020.7, 'grnd_level': 969.38, 'humidity': 13, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.94, 'deg': 231.502}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-02 00:00:00'}, {'dt': 1527908400, 'main': {'temp': 80.1, 'temp_min': 80.1, 'temp_max': 80.1, 'pressure': 969.61, 'sea_level': 1021.44, 'grnd_level': 969.61, 'humidity': 19, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 2.62, 'deg': 242.507}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-02 03:00:00'}, {'dt': 1527919200, 'main': {'temp': 68.84, 'temp_min': 68.84, 'temp_max': 68.84, 'pressure': 970.25, 'sea_level': 1022.59, 'grnd_level': 970.25, 'humidity': 24, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.94, 'deg': 290.507}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-06-02 06:00:00'}, {'dt': 1527930000, 'main': {'temp': 65.68, 'temp_min': 65.68, 'temp_max': 65.68, 'pressure': 969.58, 'sea_level': 1022.18, 'grnd_level': 969.58, 'humidity': 27, 'temp_kf': 0}, 'weather': [{'id': 800 ...

# %%
# use a method from openweatherpy and list comprehension  
# to extract the date in text and the temperature and store in a list
extract = ["dt_txt", "main.temp"]
data = [current_weather_phoenix(*extract)]
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3b9e8f51edac> in <module>()
#       2 # to extract the date in text and the temperature and store in a list
#       3 extract = ["dt_txt", "main.temp"]
# ----> 4 data = [current_weather_phoenix(*extract)]
#       5 data
#
# TypeError: __call__() takes 2 positional arguments but 3 were given

# %%
# print formatted results

# %%
# BONUS 1
# Use a method from openweathermapy that will extract the desired data
# without requiring a loop, and then print formatted results

# %%
# BONUS 2 : Plot the forecasted temperature over time.

# %% [markdown]
# # Instructor Turn Activity 2 Google Geo code

# %%
# Dependencies
import requests
import json

# Google developer API key
from config import * #imports every variable
print(gkey)
print(api_key)
# Target city
target_city = "Boise, Idaho"

# Build the endpoint URL
target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
    "address=%s&key=%s" % (target_city, gkey)

# Print the assembled URL, avoid pushing this print out to github for key security
print(target_url)
# Out:
# AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg
# 25bc90a1196e6f153eece0bc0b0fc9eb
# https://maps.googleapis.com/maps/api/geocode/json?address=Boise, Idaho&key=AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Boise', 'short_name': 'Boise', 'types': ['locality', 'political']}, {'long_name': 'Ada County', 'short_name': 'Ada County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Idaho', 'short_name': 'ID', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Boise, ID, USA', 'geometry': {'bounds': {'northeast': {'lat': 43.6898951, 'lng': -116.1019091}, 'southwest': {'lat': 43.511717, 'lng': -116.3658869}}, 'location': {'lat': 43.6150186, 'lng': -116.2023137}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 43.6898951, 'lng': -116.1019091}, 'southwest': {'lat': 43.511717, 'lng': -116.3658869}}}, 'place_id': 'ChIJnbRH6XLxrlQRm51nNpuYW5o', 'types': ['locality', 'political']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=2, sort_keys=True))
# Out:
# {
#   "results": [
#     {
#       "address_components": [
#         {
#           "long_name": "Boise",
#           "short_name": "Boise",
#           "types": [
#             "locality",
#             "political"
#           ]
#         },
#         {
#           "long_name": "Ada County",
#           "short_name": "Ada County",
#           "types": [
#             "administrative_area_level_2",
#             "political"
#           ]
#         },
#         {
#           "long_name": "Idaho",
#           "short_name": "ID",
#           "types": [
#             "administrative_area_level_1",
#             "political"
#           ]
#         },
#         {
#           "long_name": "United States",
#           "short_name": "US",
#           "types": [
#             "country",
#             "political"
#           ]
#         }
#       ],
#       "formatted_address": "Boise, ID, USA",
#       "geometry": {
#         "bounds": {
#           "northeast": {
#             "lat": 43.6898951,
#             "lng": -116.1019091
#           },
#           "southwest": {
#             "lat": 43.511717,
#             "lng": -116.3658869
#           }
#         },
#         "location": {
#           "lat": 43.6150186,
#           "lng": -116.2023137
#         },
#         "location_type": "APPROXIMATE",
#         "viewport": {
#           "northeast": {
#             "lat": 43.6898951,
#             "lng": -116.1019091
#           },
#           "southwest": {
#             "lat": 43.511717,
#             "lng": -116.3658869
#           }
#         }
#       },
#       "place_id": "ChIJnbRH6XLxrlQRm51nNpuYW5o",
#       "types": [
#         "locality",
#         "political"
#       ]
#     }
#   ],
#   "status": "OK"
# }

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print("%s: %s, %s" % (target_city, lat, lng))
# Out:
# Boise, Idaho: 43.6150186, -116.2023137

# %% [markdown]
# # Instructors Turn Activity 3 Google Places

# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.6187102%2C+-116.2146068&keyword=Chinese&radius=8000&type=restaurant&key=AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCLAEAAIpzEbqKv6pW_2_oUojTj3tqQjjEw_0a3n1-bjZQQ0CzBOGKbrW57wIk948fYyplzY6nwr-nXQf6nmltNS5Wt81yEjC1mNU3DvAdFtVMJxSzFP9Tq2H1wfPg4rlvnkbg8e2XJIEVCJjUdL025quNjUH8Iub8msKj4GNGuphysXld3qV3pBe5T4y4Fjg5wG0TTUhP9xhiAzoN_JxPXeDt6Jo6CNA_xW6GvRzV-hJUAoiufnHBpzZ_N4Qkt3vOzOvVaw9sJxPPRzLx3BzcjzqDidp39H0d4QQ4lDaNCKlP15hD4J_hnAfDnwOLROb-IislZ8Id5GVK6jmy-3DPboDJzYfk3EoIMv6N6Kaz78VrcK4H1bcwwKColoQlymUnQCDAyK44hw4-l0jMlpWmsUIq2XESEMjyknd_TJ5EBl7hnLGQ2PkaFDWU7v6amjSkjAPsy7FYSsZD7p0X",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6201152,
#                     "lng": -116.312547
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62114217989272,
#                         "lng": -116.3112022701073
#                     },
#                     "southwest": {
#                         "lat": 43.61844252010728,
#                         "lng": -116.3139019298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "4929e977dc1f7858efe1b37024d1fa6db3684772",
#             "name": "China Grand Buffet",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101287468922822261096/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJh3IJDf8zfb9wa9u4m4XQgW9mtFCjb9eK_LOO5jD_nvkR1J23evAjIRi2giBgkN6iBZlHSZX9FoA9XPDaH7pmE1wnh8QC4qsDfjvg4CverjhmoKgYFKqxWPbIntKpBnwEhCiaj4yW0MsTig9kekfMxkpGhQJAGIG9QfqlijBzZvYWCf61wLuLg",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "CmRbAAAAThjzQ1_rH2y9DsCaESdUsE7OOG8F6w4uYbRe4gZkfbks-bPRWO7cJtc9ulTdEwUk_QXqU2PQm977im3FflPLxYeYn-JUjawyoNbWjnikphQYqTh-rhyGoVzt9fTrJszyEhCHw0vmfbqAupOYodUTBGA_GhT1yW4VvaDRr8h8qPjuuS_GdGq76g",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "10498 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6251218,
#                     "lng": -116.2123933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62631952989272,
#                         "lng": -116.2111869701072
#                     },
#                     "southwest": {
#                         "lat": 43.62361987010728,
#                         "lng": -116.2138866298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b1910608eed20a9557d6d9fb29675484932ad9ce",
#             "name": "North End Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103039634556116345378/photos\">Duane Hughes</a>"
#                     ],
#                     "photo_reference": "CmRaAAA
",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2775 S Broadway Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.618054,
#                     "lng": -116.282076
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.6200802,
#                         "lng": -116.2808748701073
#                     },
#                     "southwest": {
#                         "lat": 43.6173786,
#                         "lng": -116.2835745298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "f81ca5c2cbaac12e40248363e8e791490f61b119",
#             "name": "City Buffet",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103425469668596867526/photos\">dee shuck</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxqrYwdEmDTboaW6BDRvCCUSCZwpvl4_btzh-wvtk05tTn1k5OxtCFNphO0yHfrcGERZaCsbx6jP2-LDPa3wseum_bgxnJnrH5maSjrvgSmIBXi5XRObpk6HKsKKkPaR5EhDjUCqvdCl1cfQBwvhI0rViGhSu4fhP0sDLn8UeVdNeW1oSKFmh7Q",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJDU3kvQtWrlQRqEpYSPtJ_5I",
#             "price_level": 2,
#             "rating": 4,
#             "reference": "CmRbAAAAhHzWTALBEE2hj9I8MAjMdynn5SGQcc3eDIZxztbsNQf6iMJ6y7Px6Ap7a-te9KTaBBaHelmFahBumBtjzFU3SAhR5AzgNO_IRIrnS1yzyLFxpUJSVSP-GAH2zk0cKNq9EhBy8I9OeUeTyQznee4qC7n3GhTLvSkC1iooq0zHolf8hqcA6WYElA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "8049 W Fairview Ave, Boise"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.58963800000001,
#                     "lng": -116.216586
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59109642989272,
#                         "lng": -116.2152351701072
#                     },
#                     "southwest": {
#                         "lat": 43.58839677010727,
#                         "lng": -116.2179348298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "fb20fca1a524f40bfea6af8ba52d1bd870bb8e7a",
#             "name": "Panda Garden",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103973203825542789666/photos\">Ben Studer</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAW55nWIfBh1YNBHAcngoBI9Ft0jc0Q0uwMKyFFJ9j2um36wHPbbNE5GGyXNxTfAVE4LU64i4D6M6Kinbjxsz0ID1mMAtvL166AVNkZlS4_cvdER9m9lu368EHgTdqCNxwEhAxfgSCI2Qb0NiJ3gViUiteGhQNkHgyQIve0xXmCrN8XhuwI-uq3A",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "rating": 3.9,
#             "reference": "CmRbAAAAJNe190_BwXWnIaGFRIBZye5tpWPLlu7pVmdLt2yctNq4n2iU5Weyodsu9CfW49S8GyycFTGiaWGjSCQd3Z_tpIfsvXyOt8MRQ5yDXBwp2qru_e23a868pLv_K-X90G83EhCUsahcVJLMySEdEPw96kHVGhRlNsB4SKvBMgxVmLkBilELS0zNsw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2801 W Overland Rd, Boise"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# China Grand Buffet
# 10498 W Fairview Ave, Boise

# %% [markdown]
# # Students Turn Activity 4
# # Google Drills
#
# In this activity we will perform API calls to the Google Places and Google Maps API.
#
# ## Instructions
#
# * Complete each of the six drills articulated in the code provided. Feel encouraged to look back at the previous examples but know that you will have to consult the Google API documentation.
#
# ### Hints
#
# * See the [Google Geocoding Documentation](https://developers.google.com/maps/documentation/geocoding/intro)
#
# * See the [Google Places Documentation](https://developers.google.com/maps/documentation/javascript/places#place_search_requests)

# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target urls and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
from config import gkey

# %%
# 1. What are the geocordinates (latitude and longitude) of Seattle, Washington?

# Target city
target_city = "Seattle, Washington"

# Build the endpoint URL
target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
    "address=%s&key=%s" % (target_city, gkey)

# Print the assembled URL, avoid pushing this print out to github for key security
print(target_url)


# Run request
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)

# Convert to JSON

#["results"][0]["geometry"]["location"]["lng"]
print(geo_data["results"][0]["geometry"]["location"]["lat"], geo_data["results"][0]["geometry"]["location"]["lng"])

# Extract Lat/Lng


# Print results
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=Seattle, Washington&key=AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg
# {'results': [{'address_components': [{'long_name': 'Seattle', 'short_name': 'Seattle', 'types': ['locality', 'political']}, {'long_name': 'King County', 'short_name': 'King County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Washington', 'short_name': 'WA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Seattle, WA, USA', 'geometry': {'bounds': {'northeast': {'lat': 47.734145, 'lng': -122.2244331}, 'southwest': {'lat': 47.4919119, 'lng': -122.4596959}}, 'location': {'lat': 47.6062095, 'lng': -122.3320708}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 47.734145, 'lng': -122.2244331}, 'southwest': {'lat': 47.4919119, 'lng': -122.4596959}}}, 'place_id': 'ChIJVTPokywQkFQRmtVEaUZlJRA', 'types': ['locality', 'political']}], 'status': 'OK'}
# 47.6062095 -122.3320708

# %%
# 2. What are the geocordinates (latitude and longitude) of The White House?
# update params dict

search = "The White House"

# Build the endpoint URL
target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
    "address=%s&key=%s" % (search, gkey)

# Print the assembled URL, avoid pushing this print out to github for key security
print(target_url)


# Run request
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)

# Convert to JSON

#["results"][0]["geometry"]["location"]["lng"]
print(geo_data["results"][0]["geometry"]["location"]["lat"], geo_data["results"][0]["geometry"]["location"]["lng"])
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=The White House&key=AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg
# {'results': [{'address_components': [{'long_name': '1600', 'short_name': '1600', 'types': ['street_number']}, {'long_name': 'Pennsylvania Avenue Northwest', 'short_name': 'Pennsylvania Ave NW', 'types': ['route']}, {'long_name': 'Northwest Washington', 'short_name': 'Northwest Washington', 'types': ['neighborhood', 'political']}, {'long_name': 'Washington', 'short_name': 'Washington', 'types': ['locality', 'political']}, {'long_name': 'District of Columbia', 'short_name': 'DC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}], 'formatted_address': '1600 Pennsylvania Ave NW, Washington, DC 20500, USA', 'geometry': {'location': {'lat': 38.8976763, 'lng': -77.0365298}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 38.8990252802915, 'lng': -77.0351808197085}, 'southwest': {'lat': 38.8963273197085, 'lng': -77.0378787802915}}}, 'place_id': 'ChIJ37HL3ry3t4kRv3YLbdhpWXE', 'types': ['establishment', 'point_of_interest']}], 'status': 'OK'}
# 38.8976763 -77.0365298

# %%
# 3. Find the names and addresses of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

# geocoordinates
target_coordinates = "47.6062095 -122.3320708"
target_search = "bike store"
target_radius = 2000
#OR target_type = "bicycle_store"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()


# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
print(response["results"][0]["name"])
print(response["results"][0]["vicinity"])
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6157411,
#                     "lng": -122.3409428
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61714797989273,
#                         "lng": -122.3395186701073
#                     },
#                     "southwest": {
#                         "lat": 47.61444832010729,
#                         "lng": -122.3422183298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "755849071497c5d178731e49b6396f604f7446dd",
#             "name": "Velo Bike Shop",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105746056324544705882/photos\">Velo Bike Shop</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAMD1y72-YDDTicI5yt5et-0nfCn1m6We6xLgHdwToDZuxLPB8D-iebQcYyN9rG6ANxi9a4-P7KI73WFY3H4_f_t1EBjfJ8WfgaYSkh_6GWPXblXB1nv1PhKOz3qSLftT6EhA68GLjc2y4ylcho9-BHeNWGhRsuJwGjfbTnUVCcR4D7QfrhU6m8g",
#                     "width": 1504
#                 }
#             ],
#             "place_id": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "rating": 4.2,
#             "reference": "CmRbAAAA50kT1kSivxKUngzvKd3VtILs2kWpp4Ceh6NEehXiVuD1KUo55qyFy6eIs4spcLujfeS8PNdHIk7dV_8ipia3mChXGLEhm0LoLqnMu3n1YwdjuIjyLkIgm4_CvoixMTruEhAsD6TVykkGbZkgwaO3-351GhRZr0a-H6iCwEtLroMnSrkcKNeX4Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "parking",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "2151 6th Ave, Seattle"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6157815,
#                     "lng": -122.3349557
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61717042989272,
#                         "lng": -122.3335548701073
#                     },
#                     "southwest": {
#                         "lat": 47.61447077010727,
#                         "lng": -122.3362545298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "df8b5a2e8d7cc13983672ccfcf6f1f8593f2fae8",
#             "name": "MBR Bike Shop + Mobile Bicycle Rescue",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115817002899975955852/photos\">Mobile Bicycle Rescue</a>"
#                     ],
#                     "photo_reference": "CmRaAAA
#             "reference": "CmRbAAAAv4J4WLSu3oqp_D_T_juCvqZNh5sOIYVDYkTC-UlleQs6UUE3ja0dNLKt10OXbQToKEuLn1vVe8wBYAdX-T3lsBq76eIFVy8vY2xklDfTQdGinTBCu1RbRUIxRVUr2BqREhC7g4ouzpIn1W9kywdRR48wGhTc0_hDCJXRIV4yZkQQ_3dObvxo1g",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "cafe",
#                 "bar",
#                 "gym",
#                 "store",
#                 "health",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1017 E Union St, Seattle"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.604188,
#                     "lng": -122.3377419
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60548892989272,
#                         "lng": -122.3363472701073
#                     },
#                     "southwest": {
#                         "lat": 47.60278927010728,
#                         "lng": -122.3390469298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "c38dc81c18e10256e4625fc6ac01aaae99732ed9",
#             "name": "The Bicycle Repair Shop",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101330920025940637272/photos\">The Bicycle Repair Shop</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAb_Rmg_qqCqa9s6XnYWLtliWltbvDmkUZiu4RaG24Yc9jQ7kvfgcyF8aw-4yM2uoGhBOTta4DpCYG5AaArFIC-GLMmImAKuApNx82KCiUg5oObgGXibFFkTTxPERsJo4oEhBQFHNO1WJbXlm-3-72onLgGhTxZaIewePM6ddF7WoYHfsp1civJg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJY8F11a9qkFQRHNkYuwNpSKk",
#             "rating": 4.9,
#             "reference": "CmRbAAAAfIqROvzXOpo8uIjulASNaOCTkmJQfNmP-mwQ1Zg-VeuGesuOHXNnHkkdqfWmJFQNs3p-Dq55kUbppQTZeYReednljiHLUU2sLlg3OQlx16yJmSMBUYjbaMgyguYeOpjrEhCA3xRboNv06pdqHoXjBZyTGhS69z9OOyT2Zan_TR-fFYNap4n9kw",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "68 Madison St, Seattle"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.613659,
#                     "lng": -122.317747
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61500867989272,
#                         "lng": -122.3165848701073
#                     },
#                     "southwest": {
#                         "lat": 47.61230902010728,
#                         "lng": -122.3192845298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "2679dd49ae2ccd0d76856a6fff55285af508f333",
#             "name": "Good Weather Bicycle & Cafe",
#             "opening_hours": {
#                 "open_now": true,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1200,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112377920326204109653/photos\">kyle rogers</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHfjHJEqnPmH3eTDZsc_EgzVaZXEc7mZWJWC6l26Hjh62I0uVnYm2nm8Z3rQ5r1JY-qfdADlceH9hemYQR1A4Q8Qc5pmSlWR4BpXcBi_3HURYOSF4nSX0t2YDIuKmeD6UEhAXGNyXOsSuVFSao6ffL5pnGhTXRR0AEQW9ri4huzrc9Amc16wUqg",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "rating": 4.7,
#             "reference": "CmRbAAAAFp9sZ0EhEIHZMqnsxU_5oq5Zsi2Jmm10spvn_JCQQfMgb2lhcZwUtVoMQTxuUGF7mbgwNiPLXRyB2_D6PGmK6Yx-xwXPwhl_yzALUBXm1xYNs4UixwFpAOkb9AfjE8W-EhDj2i8DBTQYtSdKrWc6d0uYGhSwQrerRNoAd3FkEHmk0yvWvbOkLw",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "cafe",
#                 "store",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity":

#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "605 Eastlake Ave E, Seattle"
#         }
#     ],
#     "status": "OK"
# }
# Velo Bike Shop
# 2151 6th Ave, Seattle

# %%
# 4. Find a balloon store near the White House.
# geocoordinates
target_coordinates = "38.8976763 -77.0365298"
target_search = "balloon store"
target_radius = 500

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()


# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# Print the name and address of the first balloon shop to appear
print(response["results"][0]["name"])
print(response["results"][0]["vicinity"])
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.9030476,
#                     "lng": -77.03389450000002
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90433337989273,
#                         "lng": -77.03237422010727
#                     },
#                     "southwest": {
#                         "lat": 38.90163372010728,
#                         "lng": -77.03507387989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "6f5b0f05be3feffa78fb6d182f94c884f0fea31a",
#             "name": "Gary's Lighting Party Inc",
#             "place_id": "ChIJo94lKb63t4kRNI_QEnjaEBU",
#             "reference": "CmRbAAAAZEMmpWhYJk8xQBwtK62Vd_U5kByYyWcrfBEtPw8G5cu28q2qThBz4yvOhXfoanVwmRBDLP4k2ACLq3xRn9PuGxXAEc8h1vYiVKiuYyXaGw49Nb_Fd6KacLcYdIamhttAEhD0EYAOBv4R2et4f4qVdyfGGhTHKw7J1gqvFy9ROfGJ0hCkNvCZNg",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1010 Vermont Ave NW, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.9021614,
#                     "lng": -77.03229429999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90363597989272,
#                         "lng": -77.03094392010728
#                     },
#                     "southwest": {
#                         "lat": 38.90093632010728,
#                         "lng": -77.03364357989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "ef73c0e710564863e2b7509c1354c879a5cc27e3",
#             "name": "Party Rental Ltd.",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "place_id": "ChIJSyXWjb63t4kRbbLtxFpw7JA",
#             "rating": 5,
#             "reference": "CmRbAAAAJKKEcnCps1eEA6fnFcrC-oSvCAwR_4dM7GKLLyI_FjOn0gl_JpzGo6hFYAI5kIIIWSdGqwqlMJt5iGWHZw9lPRIBRoSpc4jcXv1I5OSwQAhbqd-rJKA4rA4aG8RQA-snEhDCMfc37I3EVa6V96XgHn9OGhT4eiJBSKfrJmu2d2yw6qX5ZcDq6g",
#             "scope": "GOOGLE",
#             "types": [
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1400 K St NW Suite 575, Washington"
#         }
#     ],
#     "status": "OK"
# }
# Gary's Lighting Party Inc
# 1010 Vermont Ave NW, Washington

# %%
# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.

# Google geocode to find lat, lng
search = "4050 Queenswreath Way, Irvine, CA 92612"

# Build the endpoint URL
target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
    "address=%s&key=%s" % (search, gkey)

# Print the assembled URL, avoid pushing this print out to github for key security
print(target_url)

# Run request, converted to json
geo_data = requests.get(target_url).json()
print(geo_data)

lat = geo_data["results"][0]["geometry"]["location"]["lat"]
long = geo_data["results"][0]["geometry"]["location"]["lng"]
print(f"Coordinates are: {lat}, {long}")    
    
    
# Use lat, lng to use places API to find nearest dentist

# geocoordinates
target_coordinates = "33.6675949 -117.8238389"
target_search = "dentist"
target_radius = 500

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# Print the name and address of the first dentist to appear
print(response["results"][0]["name"])
print(response["results"][0]["vicinity"])
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=4050 Queenswreath Way, Irvine, CA 92612&key=AIzaSyASn3Jow56YTOgf6yeF0p1chD-cLgVqqCg
# {'results': [{'address_components': [{'long_name': 'Queens Wreath Way', 'short_name': 'Queens Wreath Way', 'types': ['route']}, {'long_name': 'University Park', 'short_name': 'University Park', 'types': ['neighborhood', 'political']}, {'long_name': 'Irvine', 'short_name': 'Irvine', 'types': ['locality', 'political']}, {'long_name': 'Orange County', 'short_name': 'Orange County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'California', 'short_name': 'CA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '92612', 'short_name': '92612', 'types': ['postal_code']}], 'formatted_address': 'Queens Wreath Way, Irvine, CA 92612, USA', 'geometry': {'bounds': {'northeast': {'lat': 33.6681362, 'lng': -117.8191998}, 'southwest': {'lat': 33.6668597, 'lng': -117.820796}}, 'location': {'lat': 33.6674254, 'lng': -117.820118}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 33.6688469302915, 'lng': -117.8186489197085}, 'southwest': {'lat': 33.66614896970851, 'lng': -117.8213468802915}}}, 'partial_match': True, 'place_id': 'ChIJT3g7yNrd3IARw1cCVyjvfnk', 'types': ['route']}], 'status': 'OK'}
# Coordinates are: 33.6674254, -117.820118
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6638704,
#                     "lng": -117.8269668
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.66526222989273,
#                         "lng": -117.8258017701073
#                     },
#                     "southwest": {
#                         "lat": 33.66256257010728,
#                         "lng": -117.8285014298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "97c45ec43ba5b3c0eaf856a086538e5fdf806019",
#             "name": "Irvine Children's Dentistry",
#             "photos": [
#                 {
#                     "height": 350,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106202386964468790052/photos\">Irvine Children&#39;s Dentistry .</a>"
#                     ],
#                     "photo_reference": "CmRaAAAACAOmUTKP6YyzflE7jpwN9yWoAyyA6I8spP-xrT35JLrADQ9hQuMR4oFiosPWZpHjaqFPybYxfLopRGja9e8GUkw6lv0P5W9E1CvYu6l_mudTy1U9W17DO4b7FdQziLtXEhBEXwnKbFGclxhGDj-RcLgnGhRNNw9N4eDvZajS1eRXx3-7JLiQlQ",
#                     "width": 351
#                 }
#             ],
#             "place_id": "ChIJtRGvDdnd3IARKghoCSE8OzA",
#             "rating": 4.9,
#             "reference": "CmRbAAAA0XMairKJUjF7f6jrtu2rH_qbqcBBzU9NcArXXN3ROfFDqkpNHF5FIstIw4xLHoDWwqAyA5grt_vqQXHPXc_4IifSFYVpx0XSmXoB4w_yLY4g_PAAgvdbIqTcunPlkcXYEhCQWqodSmK3R_oHg71DVwkPGhQ6GRHMBxgYwSzu0PZbE6ydqGwDjg",
#             "scope": "GOOGLE",
#             "types": [
#                 "dentist",
#                 "doctor",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "18124 Culver Dr, Irvine"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6638878,
#                     "lng": -117.8270673
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.66526837989272,
#                         "lng": -117.8258528701073
#                     },
#                     "southwest": {
#                         "lat": 33.66256872010727,
#                         "lng": -117.8285525298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "6ef43dbb746e5f3fc8bff34c460d799414bb5995",
#             "name": "Wayne A Gouvion Inc",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "place_id": "ChIJtRGvDdnd3IARqH1_Zz05d-w",
#             "rating": 5,
#             "reference": "CmRbAAAAcO_LoujhW_5KcWZk8qtmE3ba4LIu4LB01uuTMruxYfTefQUxoNCCRT4PP_G1DdIycyxa4kzv9f_zN6zR4x13CxKaKZTKlkKxMMhvYbFJ_qW9103jDTgQA8naGf7N2awZEhCBrJf0mB-Q8jIrXFCmZNXvGhSzvdreZon0y11aWICbOE4EW6EYMQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "dentist",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "18124 Culver Dr, Irvine"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6640208,
#                     "lng": -117.8271064
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.66539262989272,
#                         "lng": -117.8258534701073
#                     },
#                     "southwest": {
#                         "lat": 33.66269297010727,
#                         "lng": -117.8285531298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "5c653c0f007fb343cab66b7cb2c9e2d4e6de815a",
#             "name": "Frank C Stone, DDS",
#             "opening_hours": {
#                 "open_now": false,
#                 "weekday_text": []
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118044970077850172824/photos\">Frank C Stone, DDS</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwsu0gKQMUMWM8vuNcNOKkInCenHaKpaJrCK8SIDrurfb03T1Rxm0CTFbx61geHBvt9iJ6BC2TEnMMu2OLiij6m6xAjMi-cNkpGBsiDmoJBy6YYd1Xi-ucj5s5s8ToiNBEhBoXSs935l-SJt0zTziSRGgGhSuj-unrmVnmKGIYlGWJB2rrD6Ozg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJtRGvDdnd3IAR-8ViNkqz7rs",
#             "rating": 5,
#             "reference": "CmRbAAAApkhjq9DCg4ftCpEN_JsSq4X6bBeI0Onpk6xKUyFIj0E01bGKeBOaUEuWPGCL8B96Tah3rVSbmN77_nZkIBBtwn1J5GUqWzMTORDkCST4XNPIyfj5H6zgk4UmbNmp9GTzEhCFwkG9hCX_Z7cLugdTgGYbGhQF_oKWSI0PbHNf0d5p8XQ5ImBhXg",
#             "scope": "GOOGLE",
#             "types": [
#                 "dentist",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "18124 Culver Dr, Irvine"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 33.6736153,
#                     "lng": -117.8290593
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.67488882989272,
#                         "lng": -117.8275987201073
#                     },
#                     "southwest": {
#                         "lat": 33.67218917010728,
#                         "lng": -117.8302983798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "e110e27d64ad671c4f58cced103845316e5de691",
#             "name": "Dr. Priyanka Bhalla, DDS",
#             "place_id": "ChIJH8QQpdXd3IARKRWQhRGsaEo",
#             "reference": "CmRbAAAAxhMmN0KTkOCvkgpvhSjLM5ik3WmcyygrImeZBB-KEea0lvoJUo-hRQ91FVLiogiWMRcxE0JCOpGMnS-Vude8sRtXmUoN1cG2bC9bVW79Ps5TVy9lYghHbLiRmjE1hfe6EhDoc0XcjkuQ6TVRonBbXA83GhTh4KkdFsQoFTY-KyYX0C-49rTL_g",
#             "scope": "GOOGLE",
#             "types": [
#                 "dentist",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "17691 Manchester Ave, Irvine"
#         }
#     ],
#     "status": "OK"
# }
# Irvine Children's Dentistry
# 18124 Culver Dr, Irvine

# %%
# 6. Bonus: Find the names and addresses of the top five places Google suggests
# for the phrase: "Happy Place ". Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)

# %% [markdown]
# # Instructor Turn Activity 5 Nearest Restaurant

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
types_df = pd.read_csv("./Resources/ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# set up additional columns to hold information
types_df['name'] = ""
types_df['address'] = ""
types_df['price_level'] = ""
types_df['rating'] = ""

types_df.head()
# Out:
#   ethnicity name address price_level rating
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}
# use iterrows to iterate through pandas dataframe
for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = row['ethnicity']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params).json()
    results = response.get('results')
    
    # extract first result and use pd.set_value to insert into dataframe
    results = response.get('results')
    if (results):
        restr = response['results'][0]
        print(f"Closest {restr_type} restaurant is {restr.get('name', 'Unknown')}.")
        types_df.loc[index, 'name'] = restr.get('name', '')
        types_df.loc[index, 'address'] = restr.get('vicinity', '')
        types_df.loc[index, 'price_level'] = restr.get('price_level', '')
        types_df.loc[index, 'rating'] = restr.get('rating', '')
    else:
        print("No results for " + restr_type)
    print("------------")
# Out:
# Retrieving Results for Index 0: chinese.
# Closest chinese restaurant is Chinese Fast Wok.
# ------------
# Retrieving Results for Index 1: cuban.
# Closest cuban restaurant is Alma de Cuba - Cuban Restaurant.
# ------------
# Retrieving Results for Index 2: czech.
# Closest czech restaurant is SUBWAY®Restaurants.
# ------------
# Retrieving Results for Index 3: french.
# Closest french restaurant is Amuse.
# ------------
# Retrieving Results for Index 4: german.
# Closest german restaurant is BRÜ Craft & Wurst.
# ------------
# Retrieving Results for Index 5: greek.
# Closest greek restaurant is Noon Mediterranean.
# ------------
# Retrieving Results for Index 6: haitian.
# Closest haitian restaurant is Coconut Breeze Cuisine.
# ------------
# Retrieving Results for Index 7: hungarian.
# Closest hungarian restaurant is Wursthaus Schmitz.
# ------------
# Retrieving Results for Index 8: indian.
# Closest indian restaurant is Cafe Spice Express.
# ------------
# Retrieving Results for Index 9: indonesian.
# Closest indonesian restaurant is Sky Cafe.
# ------------
# Retrieving Results for Index 10: irish.
# Closest irish restaurant is Tir na nOg Irish Bar & Grill.
# ------------
# Retrieving Results for Index 11: israeli.
# Closest israeli restaurant is Goldie.
# ------------
# Retrieving Results for Index 12: italian.
# Closest italian restaurant is Davio's Northern Italian Steakhouse.
# ------------
# Retrieving Results for Index 13: japanese.
# Closest japanese restaurant is Double Knot.
# ------------
# Retrieving Results for Index 14: jewish.
# Closest jewish restaurant is Abe Fisher.
# ------------
# Retrieving Results for Index 15: korean.
# Closest korean restaurant is Giwa - Fresh Korean Kitchen.
# ------------
# Retrieving Results for Index 16: lebanese.
# Closest lebanese restaurant is Boutros Greek & Middle Eastern.
# ------------
# Retrieving Results for Index 17: mexican.
# Closest mexican restaurant is Chipotle Mexican Grill.
# ------------
# Retrieving Results for Index 18: new american.
# Closest new american restaurant is Square 1682.
# ------------
# Retrieving Results for Index 19: pakistani.
# Closest pakistani restaurant is Nanee's Kitchen.
# ------------
# Retrieving Results for Index 20: polish.
# Closest polish restaurant is Franks A-lot.
# ------------
# Retrieving Results for Index 21: russian.
# Closest russian restaurant is Rachael's Nosheri.
# ------------
# Retrieving Results for Index 22: scandinavian.
# Closest scandinavian restaurant is Abe Fisher.
# ------------
# Retrieving Results for Index 23: scottish.
# No results for scottish
# ------------
# Retrieving Results for Index 24: soul food.
# Closest soul food restaurant is Keven Parker's Soul Food Cafe.
# ------------
# Retrieving Results for Index 25: spanish.
# Closest spanish restaurant is Jamonera.
# ------------
# Retrieving Results for Index 26: thai.
# Closest thai restaurant is Xiandu Thai Fusion Cuisine.
# ------------
# Retrieving Results for Index 27: turkish.
# Closest turkish restaurant is The Original Turkey.
# ------------
# Retrieving Results for Index 28: ukrainian.
# Closest ukrainian restaurant is The Pierogie Kitchen.
# ------------
# Retrieving Results for Index 29: vietnamese.
# Closest vietnamese restaurant is Vietnam Express.
# ------------

# %%
types_df
# Out:
#        ethnicity                                 name  \
# 0        chinese                     Chinese Fast Wok
# 1          cuban      Alma de Cuba - Cuban Restaurant
# 2          czech                   SUBWAY®Restaurants
# 3         french                                Amuse
# 4         german                    BRÜ Craft & Wurst
# 5          greek                   Noon Mediterranean
# 6        haitian               Coconut Breeze Cuisine
# 7      hungarian                    Wursthaus Schmitz
# 8         indian                   Cafe Spice Express
# 9     indonesian                             Sky Cafe
# 10         irish         Tir na nOg Irish Bar & Grill
# 11       israeli                               Goldie
# 12       italian  Davio's Northern Italian Steakhouse
# 13      japanese                          Double Knot
# 14        jewish                           Abe Fisher
# 15        korean          Giwa - Fresh Korean Kitchen
# 16      lebanese       Boutros Greek & Middle Eastern
# 17       mexican               Chipotle Mexican Grill
# 18  new american                          Square 1682
# 19     pakistani                      Nanee's Kitchen
# 20        polish                         Franks A-lot
# 21       russian                    Rachael's Nosheri
# 22  scandinavian                           Abe Fisher
# 23      scottish
# 24     soul food        Keven Parker's Soul Food Cafe
# 25       spanish                             Jamonera
# 26          thai           Xiandu Thai Fusion Cuisine
# 27       turkish                  The Original Turkey
# 28     ukrainian                 The Pierogie Kitchen
# 29    vietnamese                      Vietnam Express
#
#                                    address price_level rating
# 0   1500 John F Kennedy Blvd, Philadelphia           2    2.2
# 1             1623 Walnut St, Philadelphia           3    4.4
# 2             1515 Market St, Philadelphia           1    4.2
# 3               1421 Arch St, Philadelphia           4    4.5
# 4           1318 Chestnut St, Philadelphia
# 5             1601 Market St, Philadelphia                3.8
# 6                    708 Church Ln, Yeadon           2    3.9
# 7               51 N 12th St, Philadelphia                3.3
# 8      1625 Chestnut St # F5, Philadelphia                  4
# 9      1122 Washington Ave B, Philadelphia           1    4.6
# 10              1600 Arch St, Philadelphia           2    4.1
# 11            1526 Sansom St, Philadelphia           1    4.7
# 12             111 S 17th St, Philadelphia           3    4.5
# 13             120 S 13th St, Philadelphia           2    4.7
# 14            1623 Sansom St, Philadelphia           3    4.7
# 15            1722 Sansom St, Philadelphia           2    4.4
# 16            200 S Broad St, Philadelphia           1
# 17          1625 Chestnut St, Philadelphia           1      3
# 18             121 S 17th St, Philadelphia           3      4
# 19        2954, 51 N 12th St, Philadelphia                3.1
# 20              51 N 12th St, Philadelphia                2.4
# 21       4629, 120 S 19th St, Philadelphia           1      4
# 22            1623 Sansom St, Philadelphia           3    4.7
# 23
# 24       N 12th St & Arch St, Philadelphia                3.6
# 25             105 S 13th St, Philadelphia           2    4.3
# 26            1119 Walnut St, Philadelphia           2    4.6
# 27              45 N 12th St, Philadelphia           1    4.1
# 28  1709, 648 Roxborough Ave, Philadelphia           1    4.2
# 29             106 S 20th St, Philadelphia                4.5

# %% [markdown]
# # Students Activity 6
# # Google Complex (Airport)
#
# In this activity we are tasked with creating a Data Frame containing the rating of every airport in the top 100 metropolitan areas according to Google Users.
#
# ## Instructions
#
# * Using [06-Stu_Google_Complex/Airport_Ratings.ipynb](Unsolved/Airport_Ratings.ipynb) as a starting point, utilize the Google Geocoding API, the Google Places API, and Python/Jupyter, create a script that lists the "Airport Rating" of the major "International Airport" in each the top 100 metropolitan areas found in [06-Stu_Google_Complex/Cities.csv](Resources/Cities.csv).
#
# * Your final `ipynb` file should contain each of the following headers:
#
#   1. `City`
#
#   2. `State`
#
#   3. `Lat`
#
#   4. `Lng`
#
#   5. `Airport Name`
#
#   6. `Airport Address`
#
#   7. `Airport Rating`
#
# ### Hints
#
# * You will need to obtain the lat/lng of each airport prior to sending it through the Google Places API to obtain the rating.
#
# * When using the Google Places API, be sure to use the term: "International Airport" to ensure that the airport you receive data for is the major airport in the city and not a regional one.
#
# * Use a try-except to skip airports for which there are no Google user ratings.

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("./Resources/cities.csv")
cities_pd.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Latitude"] = ""
cities_pd["Longitude"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#             City         State Latitude Longitude Airport Name  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Airport Address Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create a params dict that will be updated with new city each iteration

params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # get restaurant type from df
    city = row['City']
    state = row['State']

    # add keyword to params dict
    params['address'] = f"{city}, {state} international airport"
    
    # assemble url and make API request
    response = requests.get(base_url, params=params).json()
    results = response.get('results')
    print(response)
    # extract first result and use pd.set_value to insert into dataframe
    results = response.get('results')
    if (results):
        airport = response['results'][0]
        cities_pd.loc[index, 'Latitude'] = airport.get('lat', '')
        cities_pd.loc[index, 'Longitude'] = airport.get('lng', '')
        cities_pd.loc[index, 'Airport Name'] = airport.get('name', '')
        cities_pd.loc[index, 'Airport Address'] = airport.get('address', '')
        cities_pd.loc[index, 'Airport Rating'] = airport.get('rating', '')
    else:
        print("No results for " + city)
    print("------------")
#Visualize to confirm lat lng appear
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for New York City
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Los Angeles
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Chicago
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Houston
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Philadelphia
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Phoenix
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for San Antonio
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for San Diego
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Dallas
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for San Jose
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Austin
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Jacksonville
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for San Francisco
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Indianapolis
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Columbus
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Fort Worth
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Charlotte
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Seattle
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Denver
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for El Paso
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Detroit
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Washington
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Boston
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Memphis
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Nashville
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Portland
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Oklahoma City
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Las Vegas
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Baltimore
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Louisville
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Milwaukee
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Albuquerque
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Tucson
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Fresno
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Sacramento
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Kansas City
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Long Beach
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Mesa
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Atlanta
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Colorado Springs
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Virginia Beach
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Raleigh
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Omaha
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Miami
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Oakland
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Minneapolis
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Tulsa
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Wichita
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for New Orleans
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Arlington
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Cleveland
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Bakersfield
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Tampa
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Aurora
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Honolulu
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Anaheim
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Santa Ana
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Corpus Christi
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Riverside
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for St. Louis
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Lexington
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Stockton
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Pittsburgh
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Saint Paul
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Anchorage
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Cincinnati
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Henderson
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Greensboro
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Plano
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Newark
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Toledo
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Lincoln
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Orlando
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Chula Vista
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Jersey City
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Chandler
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Fort Wayne
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Buffalo
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Durham
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for St. Petersburg
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Irvine
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Laredo
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Lubbock
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Madison
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Gilbert
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Norfolk
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Reno
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Winston-Salem
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Glendale
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Hialeah
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Garland
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Scottsdale
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Irving
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Chesapeake
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for North Las Vegas
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Fremont
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Baton Rouge
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Richmond
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for Boise
# ------------
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
# No results for San Bernardino
# ------------

# %%
# params dictionary to update each iteration


# Use the lat/lng we recovered to identify airports

# %%
# Save Data to csv


# Visualize to confirm airport data appears

# %% [markdown]
# # Everyone Activity 7 Jupyter Gmaps

# %%
# !pip install gmaps
# !pip install ipywidgets
# !jupyter nbextension enable --py gmaps
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: gmaps in c:\users\laura\anaconda3.1\lib\site-packages
# Requirement already satisfied: six in c:\users\laura\anaconda3.1\lib\site-packages (from gmaps)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\laura\anaconda3.1\lib\site-packages (from gmaps)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\laura\anaconda3.1\lib\site-packages (from gmaps)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\laura\anaconda3.1\lib\site-packages (from gmaps)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\laura\anaconda3.1\lib\site-packages (from gmaps)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: widgetsnbextension~=3.1.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: ipython_genutils in c:\users\laura\anaconda3.1\lib\site-packages (from traitlets>=4.3.0->gmaps)
# Requirement already satisfied: decorator in c:\users\laura\anaconda3.1\lib\site-packages (from traitlets>=4.3.0->gmaps)
# Requirement already satisfied: setuptools>=18.5 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: jedi>=0.10 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: pickleshare in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: pygments in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: colorama in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=5.3.0->gmaps)
# Requirement already satisfied: tornado>=4.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: jupyter-client in c:\users\laura\anaconda3.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\laura\anaconda3.1\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: jupyter_core in c:\users\laura\anaconda3.1\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\laura\anaconda3.1\lib\site-packages (from widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: parso==0.1.* in c:\users\laura\anaconda3.1\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps)
# Requirement already satisfied: wcwidth in c:\users\laura\anaconda3.1\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->gmaps)
# Requirement already satisfied: pyzmq>=13 in c:\users\laura\anaconda3.1\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\laura\anaconda3.1\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: jinja2 in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: nbconvert in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: Send2Trash in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\laura\anaconda3.1\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: mistune>=0.7.4 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: bleach in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: testpath in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\laura\anaconda3.1\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# Requirement already satisfied: webencodings in c:\users\laura\anaconda3.1\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets>=7.0.0->gmaps)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: ipywidgets in c:\users\laura\anaconda3.1\lib\site-packages
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets)
# Requirement already satisfied: widgetsnbextension~=3.1.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipywidgets)
# Requirement already satisfied: jupyter-client in c:\users\laura\anaconda3.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets)
# Requirement already satisfied: tornado>=4.0 in c:\users\laura\anaconda3.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets)
# Requirement already satisfied: ipython_genutils in c:\users\laura\anaconda3.1\lib\site-packages (from traitlets>=4.3.1->ipywidgets)
# Requirement already satisfied: six in c:\users\laura\anaconda3.1\lib\site-packages (from traitlets>=4.3.1->ipywidgets)
# Requirement already satisfied: decorator in c:\users\laura\anaconda3.1\lib\site-packages (from traitlets>=4.3.1->ipywidgets)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\laura\anaconda3.1\lib\site-packages (from nbformat>=4.2.0->ipywidgets)
# Requirement already satisfied: jupyter_core in c:\users\laura\anaconda3.1\lib\site-packages (from nbformat>=4.2.0->ipywidgets)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\laura\anaconda3.1\lib\site-packages (from widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: setuptools>=18.5 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: jedi>=0.10 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: pickleshare in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: pygments in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: colorama in c:\users\laura\anaconda3.1\lib\site-packages (from ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: pyzmq>=13 in c:\users\laura\anaconda3.1\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\laura\anaconda3.1\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets)
# Requirement already satisfied: jinja2 in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: nbconvert in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: Send2Trash in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\laura\anaconda3.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: parso==0.1.* in c:\users\laura\anaconda3.1\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: wcwidth in c:\users\laura\anaconda3.1\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\laura\anaconda3.1\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: mistune>=0.7.4 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: bleach in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: testpath in c:\users\laura\anaconda3.1\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\laura\anaconda3.1\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# Requirement already satisfied: webencodings in c:\users\laura\anaconda3.1\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.1.0->ipywidgets)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import gmaps
import matplotlib.pyplot as plt
# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# Create a list containing coordinates
coordinates = [
    (40.71, -74.00),
    (30.26, -97.74),
    (46.87, -96.78),
    (47.60, -122.33),
    (32.71, -117.16)
]
# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', width='400px'))

# %% [markdown]
# # Student Activity 8

# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create aiport dataframe
airport_df = pd.read_csv('./Resources/Airport_Output.csv')
airport_df.dropna()
airport_df.head()
# Out:
#    Unnamed: 0           City         State        Lat         Lng  \
# 0           0  New York City      New York  40.712775  -74.005973
# 1           1    Los Angeles    California  34.052234 -118.243685
# 2           2        Chicago      Illinois  41.878114  -87.629798
# 3           3        Houston         Texas  29.760427  -95.369803
# 4           4   Philadelphia  Pennsylvania  39.952584  -75.165222
#
#                            Airport Name                   Airport Address  \
# 0  Newark Liberty International Airport             3 Brewster Rd, Newark
# 1     Los Angeles International Airport          1 World Way, Los Angeles
# 2          O'Hare International Airport       10000 W O'Hare Ave, Chicago
# 3  George Bush Intercontinental Airport       2800 N Terminal Rd, Houston
# 4    Philadelphia International Airport  8000 Essington Ave, Philadelphia
#
#    Airport Rating
# 0             3.2
# 1             3.5
# 2             3.6
# 3             3.7
# 4             3.3

# %%
# Store latitude and longitude in locations
location = airport_df[["Lat", "Lng"]]

# Fill NaN values and convert to float

# %%
# Plot Heatmap


# Create heat layer


# Add layer


# Display figure

# %%
# BONUS
# Plost as a Hybrid map

# %%
# BONUS
# Plot as a Terrain map

# Create heat layer

# %% [markdown]
# # Instructor Activity 9

# %%
# !pip install census
# Out:
# Collecting census
#   Downloading https://files.pythonhosted.org/packages/52/af/ad681b4a1b903d96569a4295305ef3bb17d99959a15a4d7cd4f6f65e8f3a/census-0.8.7-py2.py3-none-any.whl
# Requirement already satisfied: requests>=1.1.0 in c:\users\laura\anaconda3.1\lib\site-packages (from census)
# Collecting future (from census)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=1.1.0->census)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=1.1.0->census)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=1.1.0->census)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=1.1.0->census)
# Building wheels for collected packages: future
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\Laura\AppData\Local\pip\Cache\wheels\bf\c9\a3\c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built future
# Installing collected packages: future, census
# Successfully installed census-0.8.7 future-0.16.0
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import ckey
c = Census(ckey, year=2013)

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rate"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd = census_pd[["Zipcode", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate"]]

# Visualize
print(len(census_pd))
census_pd.head()
# Out:
# 33120
#   Zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0   00601     18450.0        36.6           12041.0             7380.0
# 1   00602     41302.0        38.6           15663.0             8463.0
# 2   00603     53683.0        38.9           15485.0             9176.0
# 3   00606      6591.0        37.3           15019.0             6383.0
# 4   00610     28963.0        39.2           16707.0             7892.0
#
#    Poverty Count  Poverty Rate
# 0        10816.0     58.623306
# 1        22409.0     54.256452
# 2        26220.0     48.842278
# 3         3721.0     56.455773
# 4        14569.0     50.302110

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("census_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Students Turn
# # Census Activity
#
# In this activity we will utilize the Census API in order to obtain census data at a state level.
#
# ## Instructions
#
# * Using [Census_States.ipynb](Unsolved/Census_States.ipynb) as a reference, create a completely new script that calculates each of the following fields at the **state** level:
#
#   1. Population
#
#   2. Median Age
#
#   3. Household Income
#
#   4. Per Capita Income
#
#   5. Poverty Count
#
#   6. Poverty Rate
#
#   7. Unemployment Rate
#
# * Save the resulting data as a csv.
#
# * Next, read in the provided csv containing state centroid coordinates and merge this data with your original census data.
#
# * With the coordinates now appended to the dataframe, you have the ability to add markers to the base map.
#
#   * Use the 'Poverty Rate' column to create an `info_box` corresponding to each marker.
#
#   ![10-State_Markers.png](Images/10-State_Markers.png)
#
# * **Hints**
#
#   * See documentation for the [Census API Wrapper](https://github.com/datamade/census).
#
#   * See documentation for [Jupyter Gmaps](http://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html) for more information on how to create an `info_box`.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps

# Census & gmaps API Keys
from config import (ckey, gkey)
c = Census(ckey, year=2013)

# Configure gmaps
gmaps.configure(api_key=gkey)
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)# Run C 
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b for labels
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame


# Column Reordering

# Add in Poverty Rate (Poverty Count / Population)

# Final DataFrame

# Visualize

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("census_data.csv", encoding="utf-8", index=False)
