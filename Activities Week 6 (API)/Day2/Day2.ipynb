# %% [markdown]
# # Students Turn Activity 1 JSON Traversal Review
#
# This activity is an opportunity to practice loading and parsing JSON in Python.
#
# ## Instructions
#
# * Load the provided JSON
#
# * Retrieve the video's title
#
# * Retrieve the video's rating
#
# * Retrieve the link to the video's thumbnail
#
# * Retrieve the number of views this video has

# %%
# Dependencies
import json
import requests
import os

# Load JSON
filepath = os.path.join("Resources", "youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
# Isolate "data items" for easy reading
# CODE HERE 
data_items = video_json["data"]["items"]
print(data_items)
# Retrieve the video's title
# CODE HERE 
print(data_items[0]["title"])
# Out:
# [{'id': 'hYB0mn5zh2c', 'uploaded': '2007-06-05T22:07:03.000Z', 'updated': '2010-01-07T13:26:50.000Z', 'uploader': 'GoogleDeveloperDay', 'category': 'News', 'title': 'Google Developers Day US - Maps API Introduction', 'description': 'Google Maps API Introduction ...', 'tags': ['GDD07', 'GDD07US', 'Maps'], 'thumbnail': {'default': 'http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg', 'hqDefault': 'http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg'}, 'player': {'default': 'http://www.youtube.com/watch?vu003dhYB0mn5zh2c'}, 'content': {'1': 'rtsp://v5.cache3.c.youtube.com/CiILENy.../0/0/0/video.3gp', '5': 'http://www.youtube.com/v/hYB0mn5zh2c?f...', '6': 'rtsp://v1.cache1.c.youtube.com/CiILENy.../0/0/0/video.3gp'}, 'duration': 2840, 'aspectRatio': 'widescreen', 'rating': 4.63, 'ratingCount': 68, 'viewCount': 220101, 'favoriteCount': 201, 'commentCount': 22, 'status': {'value': 'restricted', 'reason': 'limitedSyndication'}, 'accessControl': {'syndicate': 'allowed', 'commentVote': 'allowed', 'rate': 'allowed', 'list': 'allowed', 'comment': 'allowed', 'embed': 'allowed', 'videoRespond': 'moderated'}}]
# Google Developers Day US - Maps API Introduction

# %%
# Retrieve the video's rating
# CODE HERE 
print(data_items[0]["rating"])
# Out:
# 4.63

# %%
# Retrieve the link to the video's default thumbnail
# CODE HERE

print(data_items[0]["thumbnail"]["default"])
# Out:
# http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg

# %%
# Retrieve the number of views this video has
# CODE HERE 

print(data_items[0]["viewCount"])
# Out:
# 220101

# %% [markdown]
# # Students Turn Activity 2 Requests & Responses
#
# This activity provides practice making API calls, converting the response to JSON, and then manipulating the result with Python.
#
# ## Instructions
#
# * Make a request to the following endpoint (http://nyt-mongo-scraper.herokuapp.com/api/headlines), and store the response.
#
# * JSON-ify the response.
#
# * Print the JSON representations of the first and last posts.
#
# * Print number of posts received.

# %%
# Dependencies
import json
import requests

# %%
# Specify the URL
# CODE HERE 

url = "http://nyt-mongo-scraper.herokuapp.com/api/headlines"

# Make request and store response
# CODE HERE
variable = requests.get(url).json()
variable
# Out:
# [{'_id': '5b0a10420b7b8a0014cbb3d0',
#   'date': '5_27_2018',
#   'headline': 'Cuomo’s So-Called Women’s Party',
#   'saved': True,
#   'summary': 'Four years ago Gov. Andrew M. Cuomo invented a political party to attract female voters. In the #MeToo era, our columnist asks, will women fall for a political shell company?',
#   'url': 'https://www.nytimes.com/2018/05/24/nyregion/cuomos-so-called-womens-party.html'},
#  {'_id': '5b0a01880b7b8a0014cbb3a3',
#   'date': '5_27_2018',
#   'headline': 'In the Kingdom of Men',
#   'saved': False,
#   'summary': 'Muhterem Gocmen, above, was stabbed to death by her husband in Turkey, where women endure a culture of violence.',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/sunday/in-the-kingdom-of-men.html'},
#  {'_id': '5b0a01880b7b8a0014cbb3a2',
#   'date': '5_27_2018',
#   'headline': 'Why You Should Be Drinking Weird Wines',
#   'saved': False,
#   'summary': 'They’re better for the environment. And they’re delicious.',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/sunday/drinking-obscure-weird-wines.html'},
#  {'_id': '5b0a01880b7b8a0014cbb3a1',
#   'date': '5_27_2018',
#   'headline': 'The Silence of the Bugs',
#   'saved': False,
#   'summary': 'Is an insect Armageddon afoot?',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/sunday/insects-bugs-naturalists-scientists.html'},
#  {'_id': '5b0a01880b7b8a0014cbb3a0',
#   'date': '5_27_2018',
#   'headline': 'What We Get Wrong About Animals',
#   'saved': False,
#   'summary': 'From the marvelous to the utterly bizarre, the astonishing diversity of life is on display in Lucy’s Cooke’s “The Truth About Animals.”',
#   'url': 'https://www.nytimes.com/2018/05/25/books/review/the-truth-about-animals-lucy-cooke.html'},
#  {'_id': '5b0a01880b7b8a0014cbb39f',
#   'date': '5_27_2018',
#   'headline': 'A Ballet Heroine, Step by Step',
#   'saved': False,
#   'summary': 'Who is Swanilda, the lead of “Coppélia”? Our critic demonstrates how her ebullient, game-changing character is shown in her steps.',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/dance/swanilda-step-by-step-coppelia-new-york-city-ballet.html'},
#  {'_id': '5b0a01880b7b8a0014cbb39e',
#   'date': '5_27_2018',
#   'headline': 'An Affable Author With a Penchant for Murder',
#   'saved': False,
#   'summary': 'The best-selling novelist Louise Penny reflects on her love of Quebec, struggles with alcohol, and how Inspector Gamache changed her life.',
#   'url': 'https://www.nytimes.com/2018/05/25/world/canada/louise-penny-murder-mystery-novels.html'},
#  {'_id': '5b0a01880b7b8a0014cbb38b',
#   'date': '5_27_2018',
#   'headline': 'Kim’s Actions Suggest He May Need a Deal, Analysts Say',
#   'saved': False,
#   'summary': 'When Mr. Trump canceled their meeting, Mr. Kim’s attempt to ease sanctions and rebuild the North Korean economy was thrown into doubt.',
#   'url': 'https://www.nytimes.com/2018/05/26/world/asia/kim-summit-trump.html'},
#  {'_id': '5b09f05d0b7b8a0014cbb340',
#   'date': '5_26_2018',
#   'headline': 'Champions League Final: Real Madrid Beats Liverpool',
#   'saved': False,
#   'summary': 'Real Madrid defeated Liverpool, 3-1, to win its third straight Champions League title. It is Madrid’s 13th over all, extending its record.',
#   'url': 'https://www.nytimes.com/2018/05/26/sports/champions-league-real-madrid-liverpool.html'},
#  {'_id': '5b09c3560b7b8a0014cbb307',
#   'date': '5_26_2018',
#   'headline': 'Survivors of El Salvador Massacre Ask ‘Why?’',
#   'saved': False,
#   'summary': 'More than 35 years after a massacre left almost 1,000 dead in rural El Salvador, a trial of the generals accused of planning the slaughter may finally give answers to haunting, horrific questions.',
#   'url': 'https://www.nytimes.com/2018/05/26/world/americas/el-salvador-el-mazote-massacre.html'},
#  {'_id': '5b09c3560b7b8a0014cbb306',
#   'date': '5_26_2018',
#   'headline': 'As Google Feeds Cats, Owl Lovers Cry Foul',
#   'saved': False,
#   'summary': 'In a Silicon Valley park, burrowing owls are dying and disappearing. Public records and a bit of snooping uncovered a path that led to Google and its feline-loving employees.',
#   'url': 'https://www.nytimes.com/2018/05/26/technology/google-cats-owls.html'},
#  {'_id': '5b09b6310b7b8a0014cbb2c2',
#   'date': '5_26_2018',
#   'headline': 'Who Doesn’t Love a Parade?',
#   'saved': False,
#   'summary': 'I spent my formative years in marching band and know a thing or two about being in formation.',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/sunday/who-doesnt-love-a-parade.html'},
#  {'_id': '5b09ae820b7b8a0014cbb295',
#   'date': '5_26_2018',
#   'headline': 'Alan Bean, 4th Astronaut to Walk on the Moon, Dies at 86',
#   'saved': False,
#   'summary': 'After leaving NASA, Mr. Bean, a former Navy test pilot, became a full-time artist, creating images of space exploration.',
#   'url': 'https://www.nytimes.com/2018/05/26/obituaries/alan-bean-astronaut-dies.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1d1',
#   'date': '5_26_2018',
#   'headline': 'Where Do High-Rises Hide Their Water Tanks?',
#   'saved': False,
#   'summary': 'An aficionado of wooden water tanks wonders how skyscrapers quench the thirst of their residents.',
#   'url': 'https://www.nytimes.com/2018/05/26/realestate/how-new-york-water-tanks-work.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1d0',
#   'date': '5_26_2018',
#   'headline': 'Stuck in Traffic on Memorial Day?',
#   'saved': False,
#   'summary': 'Here’s a two-minute exercise to calm your road rage.',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/traffic-memorial-day.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1cf',
#   'date': '5_26_2018',
#   'headline': 'Antibiotics in Meat Could Be Damaging Our Guts',
#   'saved': False,
#   'summary': 'Is the ban on the use of antibiotics for growth promotion in animals being ignored?',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/sunday/meat-antibiotics-organic-farming.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1ce',
#   'date': '5_26_2018',
#   'headline': 'Can Ireland Be Catholic Without the Church?',
#   'saved': False,
#   'summary': 'The institution may be in decline. But Ireland has not simply transformed into another secular Western European country.',
#   'url': 'https://www.nytimes.com/2018/05/26/opinion/ireland-catholic-abortion-referendum.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1cd',
#   'date': '5_26_2018',
#   'headline': 'Jim Parsons Takes a Break From Sheldon',
#   'saved': False,
#   'summary': 'Mr. Parsons talks about his new movie, “A Kid Like Jake,” his return to Broadway in “The Boys in the Band” and life beyond “The Big Bang Theory.”',
#   'url': 'https://www.nytimes.com/2018/05/25/movies/jim-parsons-a-kid-like-jake.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1cc',
#   'date': '5_26_2018',
#   'headline': 'An Icebox Cake Casts Its Spell on Strawberries',
#   'saved': False,
#   'summary': 'Coming together like magic in the fridge, this fluffy no-bake cake has a subtle spiciness from layers of gingersnaps.',
#   'url': 'https://www.nytimes.com/2018/05/25/dining/strawberry-icebox-cake-recipe.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1cb',
#   'date': '5_26_2018',
#   'headline': 'Making Tequila With Others Like Herself',
#   'saved': False,
#   'summary': 'Melly Barajas Cárdenas has built a growing distillery business with a work force made up almost entirely of women.',
#   'url': 'https://www.nytimes.com/2018/05/25/business/tequila-mexico-women.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1c5',
#   'date': '5_26_2018',
#   'headline': 'A Summer Bastion of Beach Culture Is Off Limits',
#   'saved': False,
#   'summary': 'New York City officials surprised beachgoers and businesses by closing a popular stretch of Rockaway Beach days before the start of beach season.',
#   'url': 'https://www.nytimes.com/2018/05/24/nyregion/nyc-erosion-rockaways-beach-closed.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1c4',
#   'date': '5_26_2018',
#   'headline': 'Five Blood Transfusions and a Bone Marrow Transplant — All Before Birth',
#   'saved': False,
#   'summary': 'In a bold experiment in fetal therapy, doctors in San Francisco treated a fetus with a severe, often fatal blood disorder. The child was saved, but the long-term prognosis is still uncertain.',
#   'url': 'https://www.nytimes.com/2018/05/25/health/fetal-bone-marrow-transplant.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1c3',
#   'date': '5_26_2018',
#   'headline': 'Champions League Final: Real Madrid vs. Liverpool',
#   'saved': False,
#   'summary': 'Real Madrid and Liverpool are meeting in Kiev, Ukraine, for Europe’s club championship. Stay here for live updates and analysis.',
#   'url': 'https://www.nytimes.com/2018/05/26/sports/champions-league-real-madrid-liverpool.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1c2',
#   'date': '5_26_2018',
#   'headline': 'Her Morgan Freeman Interview Turned Into a Bigger Story',
#   'saved': False,
#   'summary': 'After Mr. Freeman spoke to a CNN reporter, Chloe Melas, in a way she considered inappropriate, she tracked down other women who said the actor had mistreated them.',
#   'url': 'https://www.nytimes.com/2018/05/26/movies/morgan-freeman-reporter.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1c0',
#   'date': '5_26_2018',
#   'headline': 'Where Brooklyn Tenants Plead Case for Keeping Homes',
#   'saved': False,
#   'summary': 'Settlements are pushed in chaotic hallways, emergency loans are held up as cure-alls and delays are seemingly endless. Welcome to housing court. Take a number. Read Part III of our investigation.',
#   'url': 'https://www.nytimes.com/interactive/2018/05/20/nyregion/landlord-tenant-disputes-housing-court.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1bc',
#   'date': '5_26_2018',
#   'headline': 'Can 30,000 Cameras Help Solve Chicago’s Crime Problem?',
#   'saved': False,
#   'summary': 'Armed with advanced gadgets and mapping, officers can get to crime scenes “in time to see the guy still shooting.” But what does it mean for residents’ privacy?',
#   'url': 'https://www.nytimes.com/2018/05/26/us/chicago-police-surveillance.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1bb',
#   'date': '5_26_2018',
#   'headline': 'In Favor of a Criminal Justice Overhaul, but Against a Prisons Bill',
#   'saved': False,
#   'summary': 'Senior Senate authors of a long-stalled but much more comprehensive package say that a bill passed by the House falls short because it doesn’t address federal sentencing laws.',
#   'url': 'https://www.nytimes.com/2018/05/26/us/politics/criminal-justice-overhaul-prison-bill.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1ba',
#   'date': '5_26_2018',
#   'headline': 'High Stakes and No Precedent as Trump Reviles Investigators',
#   'saved': False,
#   'summary': 'President Trump’s war on the law enforcement agencies that answer to him holds great stakes for both the president and the autonomy of democratic institutions.',
#   'url': 'https://www.nytimes.com/2018/05/26/us/politics/trump-justice-fbi-russia-spy.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1b8',
#   'date': '5_26_2018',
#   'headline': 'North and South Korea Meet in Bid to Salvage U.S. Talks',
#   'saved': False,
#   'summary': 'The unexpected meeting of North Korea’s leader, Kim Jong-un, and President Moon Jae-in of South Korea on Saturday was held amid doubts over a proposed summit meeting with President Trump.',
#   'url': 'https://www.nytimes.com/2018/05/26/world/asia/korea-kim-jong-un-summit-meeting.html'},
#  {'_id': '5b09a6830b7b8a0014cbb1b7',
#   'date': '5_26_2018',
#   'headline': 'Democrats Go All-Out to Avoid Disaster in California Races',
#   'saved': False,
#   'summary': 'The party and allied groups are spending more than $4 million on a handful of races that are critical to Democrats’ strategy to win the House in November. With so many Democrats running, the fear is that the vote will be splintered, allowing Republicans to dominate some open primaries.',
#   'url': 'https://www.nytimes.com/2018/05/26/us/politics/california-primary-house.html'},
#  {'_id': '5b08c2b1a4416b00144b85e5',
#   'date': '5_26_2018',
#   'headline': 'Summer’s Great Escape',
#   'saved': False,
#   'summary': 'Reflecting on the simple joy we get from diving into water.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/swimming-summer-memorial-day.html'},
#  {'_id': '5b08c2b1a4416b00144b85e4',
#   'date': '5_26_2018',
#   'headline': 'Are We Really Still Calling This Shirt a ‘Wife Beater’?',
#   'saved': False,
#   'summary': 'Given the torrent of revelations of abuse against women in the #MeToo era, the name suddenly seems grossly inappropriate.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/are-we-really-still-calling-this-shirt-a-wife-beater.html'},
#  {'_id': '5b08c2b1a4416b00144b85e3',
#   'date': '5_26_2018',
#   'headline': 'The Populists Take Rome',
#   'saved': False,
#   'summary': 'A party founded by a comedian is helping the Italian far right lead the government in a coalition.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/populists-rome-five-star-movement.html'},
#  {'_id': '5b08bc09a4416b00144b85ca',
#   'date': '5_26_2018',
#   'headline': 'How Hard Can It Be to Grow a Garden?',
#   'saved': False,
#   'summary': 'One of the most daunting challenges that a recent suburban transplant faces is the need to immediately sprout a green thumb.',
#   'url': 'https://www.nytimes.com/2018/05/25/realestate/how-hard-can-it-be-to-grow-a-garden.html'},
#  {'_id': '5b08bc09a4416b00144b85b6',
#   'date': '5_26_2018',
#   'headline': 'U.S.C. President Will Step Down Over Gynecologist Scandal',
#   'saved': False,
#   'summary': 'The president of the University of Southern California had come under increasingly heavy fire in the last year for his handling of several scandals, the most recent of which was a campus doctor accused of abusing students under his care.',
#   'url': 'https://www.nytimes.com/2018/05/25/us/usc-nikias-tyndall.html'},
#  {'_id': '5b08bc09a4416b00144b85b5',
#   'date': '5_26_2018',
#   'headline': 'Understanding Ireland’s Vote on Its Abortion Ban',
#   'saved': False,
#   'summary': 'Results of two exit polls, which are not necessarily predictive, showed voters favored repeal by a large margin. Here’s background on the ban and the effort to repeal it.',
#   'url': 'https://www.nytimes.com/2018/05/25/world/europe/ireland-abortion-referendum-explainer.html'},
#  {'_id': '5b08bc09a4416b00144b85b0',
#   'date': '5_26_2018',
#   'headline': 'Accusers React With Tears, Disbelief, Hope and Elation',
#   'saved': False,
#   'summary': 'Women who had accused Harvey Weinstein of sexual harassment, assault and abuse swung between hope and disbelief, watching a day they thought would never come.',
#   'url': 'https://www.nytimes.com/2018/05/25/nyregion/metoo-accusers-harvey-weinstein.html'},
#  {'_id': '5b08b20da4416b00144b85aa',
#   'date': '5_26_2018',
#   'headline': 'How Neko Case Unleashed Her Feminist Rage',
#   'saved': False,
#   'summary': 'The singer and songwriter has spun tragedy into plainly angry action on her new album, “Hell-On.”',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/music/neko-case-interview-hell-on.html'},
#  {'_id': '5b08b20da4416b00144b85a1',
#   'date': '5_26_2018',
#   'headline': '‘Uncle Drew’: Branding Vehicle or Feature Film? Yes',
#   'saved': False,
#   'summary': 'The comedy was spun from a series of viral ads for Pepsi, believed to be the first time a movie plot has been based on a commercial.',
#   'url': 'https://www.nytimes.com/2018/05/24/movies/uncle-drew-movie-kyrie-irving.html'},
#  {'_id': '5b08b20da4416b00144b859f',
#   'date': '5_26_2018',
#   'headline': 'Pruitt’s Security Budget Double That of His Predecessors',
#   'saved': False,
#   'summary': 'Scott Pruitt, the head of the Environmental Protection Agency, spent nearly $3.5 million in taxpayer funds on personal security.',
#   'url': 'https://www.nytimes.com/interactive/2018/05/25/climate/epa-pruitt-security-costs.html'},
#  {'_id': '5b08863ea4416b00144b856f',
#   'date': '5_25_2018',
#   'headline': 'Mexican Food Struggles to Find Footing in Australia',
#   'saved': False,
#   'summary': 'Bar Patrón, from Neil Perry and the Rockpool Dining Group in Sydney, offers margaritas and tacos that mostly miss the mark.',
#   'url': 'https://www.nytimes.com/2018/05/24/dining/bar-patron-rockpool-review-sydney.html'},
#  {'_id': '5b08863ea4416b00144b856e',
#   'date': '5_25_2018',
#   'headline': '‘Solo: A Star Wars Story’: What the Critics Say',
#   'saved': False,
#   'summary': 'It’s entertaining! It’s not! Alden Ehrenreich is terrific! He’s no Harrison Ford! The reviews are all over the map, and here’s a sampling.',
#   'url': 'https://www.nytimes.com/2018/05/24/movies/solo-a-star-wars-story-what-do-critics-say-what-do-you-say.html'},
#  {'_id': '5b08863ea4416b00144b8564',
#   'date': '5_25_2018',
#   'headline': '‘Wrath of Coastal Erosion’ Is Devouring Senegal’s Coast',
#   'saved': False,
#   'summary': 'Saint-Louis, on Senegal’s Atlantic coast, has Unesco-protected architecture and a bustling fishing community. But coastal erosion threatens, and is accelerating.',
#   'url': 'https://www.nytimes.com/2018/05/23/world/africa/senegal-erosion-fisherman.html'},
#  {'_id': '5b08863ea4416b00144b855a',
#   'date': '5_25_2018',
#   'headline': 'Trump Weakens Job Protections for Federal Workers',
#   'saved': False,
#   'summary': 'In a series of executive orders, President Trump made it easier to fire civil servants and curbed the power of their unions, which assailed the actions.',
#   'url': 'https://www.nytimes.com/2018/05/25/business/economy/trump-federal-workers.html'},
#  {'_id': '5b087843a4416b00144b8556',
#   'date': '5_25_2018',
#   'headline': 'Baby TripAdvisor',
#   'saved': False,
#   'summary': 'I don’t usually leave reviews, both because I’ve never been on vacation before and because I’m a baby who can’t speak or type.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/sunday/baby-tripadvisor.html'},
#  {'_id': '5b087843a4416b00144b8555',
#   'date': '5_25_2018',
#   'headline': 'Save the People’s Beach at Rockaway',
#   'saved': False,
#   'summary': 'New York’s leaders should push harder to save the city’s vulnerable, beautiful coastline.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/editorials/rockaway-beach-new-york.html'},
#  {'_id': '5b087843a4416b00144b8554',
#   'date': '5_25_2018',
#   'headline': 'Trump’s Attack on the Amazon Job Machine',
#   'saved': False,
#   'summary': 'Unrestrained strongmen use the state to punish — or silence — their enemies.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/america-first-trump-jobs-fail.html'},
#  {'_id': '5b087843a4416b00144b8548',
#   'date': '5_25_2018',
#   'headline': '9 Readers on a Time They Racially Stereotyped a Stranger',
#   'saved': False,
#   'summary': 'After a string of episodes in which black people were treated unjustly while simply going about their business, we asked readers to tell us their stories.',
#   'url': 'https://www.nytimes.com/2018/05/25/reader-center/racial-stereotypes.html'},
#  {'_id': '5b087843a4416b00144b853c',
#   'date': '5_25_2018',
#   'headline': 'Trump Removes Job Protections for Federal Workers',
#   'saved': False,
#   'summary': 'In a series of executive orders, President Trump made it easier to fire civil servants and curbed the power of their unions, which assailed the actions.',
#   'url': 'https://www.nytimes.com/2018/05/25/business/economy/trump-federal-workers.html'},
#  {'_id': '5b086e2ca4416b00144b8537',
#   'date': '5_25_2018',
#   'headline': 'The Rise of the Muslim Woman Tech Entrepreneur',
#   'saved': False,
#   'summary': 'Across the Muslim world, a new generation is poised to make an impact on their countries’ prosperity.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/muslim-women-tech-entrepreneurs.html'},
#  {'_id': '5b086e2ca4416b00144b8535',
#   'date': '5_25_2018',
#   'headline': 'The Alex Jones Presidency',
#   'saved': False,
#   'summary': 'President Trump brought this noxious fantasist into the mainstream and is now using his techniques.',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/trump-alex-jones-conspiracy.html'},
#  {'_id': '5b086e2ca4416b00144b8534',
#   'date': '5_25_2018',
#   'headline': 'A Burger, Please: Hold the Tetracycline',
#   'saved': False,
#   'summary': 'Is the ban on the use of antibiotics for growth promotion in animals being ignored?',
#   'url': 'https://www.nytimes.com/2018/05/25/opinion/sunday/meat-antibiotics-organic-farming.html'},
#  {'_id': '5b086e2ca4416b00144b8533',
#   'date': '5_25_2018',
#   'headline': 'Review: Another Spooky Hike Up ‘Hanging Rock’',
#   'saved': False,
#   'summary': 'The six-episode series on Amazon retells a tale of Victorian-era repression and vanishing Australian schoolgirls.',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/television/picnic-at-hanging-rock-amazon-review.html'},
#  {'_id': '5b086e2ca4416b00144b8532',
#   'date': '5_25_2018',
#   'headline': 'Reviving Old Vineyards, Building New Traditions',
#   'saved': False,
#   'summary': 'In the hills outside of Madrid, the label Comando G prospects for old vines of garnacha at high altitudes, and makes fresh, distinctive wines.',
#   'url': 'https://www.nytimes.com/2018/05/24/dining/drinks/spanish-wine-comando-g.html'},
#  {'_id': '5b086e2ca4416b00144b8531',
#   'date': '5_25_2018',
#   'headline': 'Robert Indiana’s Best: A Mini Retrospective',
#   'saved': False,
#   'summary': 'Herman Melville and Mae West. Pinball machines and a slave ship. Mr. Indiana drew deeply personal inspiration from American sources.',
#   'url': 'https://www.nytimes.com/2018/05/23/arts/design/barbara-haskell-robert-indiana.html'},
#  {'_id': '5b086e2ca4416b00144b8529',
#   'date': '5_25_2018',
#   'headline': 'O’Keeffe’s Paradise, Lost and Found',
#   'saved': False,
#   'summary': '“Georgia O’Keeffe: Visions of Hawaiʻi,” a collection of the artist’s largely unknown Hawaiian paintings and sketches, is on display at the New York Botanical Garden.',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/okeeffes-hawaii-paintings.html'},
#  {'_id': '5b086e2ca4416b00144b8528',
#   'date': '5_25_2018',
#   'headline': 'The Spotted Pig Restaurant Empire Is Fracturing',
#   'saved': False,
#   'summary': 'Since Ken Friedman was accused of sexual harassment, the business he started with April Bloomfield has shed one restaurant and several key employees.',
#   'url': 'https://www.nytimes.com/2018/05/25/dining/ken-friedman-april-bloomfield-restaurants.html'},
#  {'_id': '5b086e2ca4416b00144b8527',
#   'date': '5_25_2018',
#   'headline': 'Less Service, Fewer Train Delays. It’s a Perception of Time.',
#   'saved': False,
#   'summary': 'Subway officials in New York want to take away service on long segments of several lines at a time on nights and weekends in return for less time stuck on trains.',
#   'url': 'https://www.nytimes.com/2018/05/25/nyregion/nyc-subway-train-delays.html'},
#  {'_id': '5b086e2ca4416b00144b8521',
#   'date': '5_25_2018',
#   'headline': 'Cohen Met Oligarch at Trump Tower to Discuss Russia',
#   'saved': False,
#   'summary': 'The meeting, which took place 11 days before the inauguration, preceded a $1 million contract that Michael D. Cohen, Mr. Trump’s lawyer, received from a firm tied to the Russian oligarch.',
#   'url': 'https://www.nytimes.com/2018/05/25/us/politics/michael-cohen-viktor-vekselberg-trump-tower.html'},
#  {'_id': '5b086e2ca4416b00144b851c',
#   'date': '5_25_2018',
#   'headline': '‘We Got You, Harvey’: Weinstein’s Accusers React',
#   'saved': False,
#   'summary': 'Asia Argento, Mira Sorvino, Annabella Sciorra and others expressed satisfaction and relief as Mr. Weinstein was arrested.',
#   'url': 'https://www.nytimes.com/2018/05/25/us/weinstein-arrest-reactions-women.html'},
#  {'_id': '5b082358a4416b00144b84e0',
#   'date': '5_25_2018',
#   'headline': 'Trump Deal-Making Playbook’s Biggest Test: North Korea',
#   'saved': False,
#   'summary': 'President Trump had sought to deal with Kim Jong-un the same way he had handled real estate negotiations — with threats and flattery. It didn’t work.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/trumps-gamble-hits-reality-check-in-north-korea-negotiations.html'},
#  {'_id': '5b08109aa4416b00144b847f',
#   'date': '5_25_2018',
#   'headline': 'Want a Warehouse of Art? Try the Installment Plan',
#   'saved': False,
#   'summary': 'Ron Pizzuti fell in love with a work by Frank Stella. He soon found he could buy Stella as well as Willem de Kooning, Franz Kline, Agnes Martin and Cy Twombly.',
#   'url': 'https://www.nytimes.com/2018/05/22/arts/design/show-us-your-wall-ron-and-ann-pizzuti.html'},
#  {'_id': '5b08109aa4416b00144b847d',
#   'date': '5_25_2018',
#   'headline': 'How Student Debt Can Ruin Home Buying',
#   'saved': False,
#   'summary': 'Graduating from college may increase your income, but higher student debt levels have kept many millennials out of the home buying market.',
#   'url': 'https://www.nytimes.com/2018/05/25/business/how-student-debt-can-ruin-home-buying-dreams.html'},
#  {'_id': '5b08109aa4416b00144b847a',
#   'date': '5_25_2018',
#   'headline': 'Aboriginal Youth Are Disproportionately Jailed, Report Finds',
#   'saved': False,
#   'summary': 'The number of Indigenous Australian juveniles in detention or on parole is increasing, even as the total number of children accused of crimes is decreasing.',
#   'url': 'https://www.nytimes.com/2018/05/25/world/australia/aboriginal-youth-juveniles-jail-report.html'},
#  {'_id': '5b08109aa4416b00144b8477',
#   'date': '5_25_2018',
#   'headline': 'When Living Your Truth Can Mean Losing Your Children',
#   'saved': False,
#   'summary': 'A case involving a former Ultra-Orthodox mother who came out as a lesbian emphasizes the legal conflict between personal freedoms and agreements made in Jewish courts.',
#   'url': 'https://www.nytimes.com/2018/05/25/nyregion/orthodox-jewish-divorce-custody-ny.html'},
#  {'_id': '5b08109aa4416b00144b8476',
#   'date': '5_25_2018',
#   'headline': 'The Flourishing Coyote: a Tough Little Canid That Could',
#   'saved': False,
#   'summary': 'How did coyotes thrive while most of the continent’s other predators faded? New maps published by researchers document their spread.',
#   'url': 'https://www.nytimes.com/2018/05/24/science/coyotes-americas-spread.html'},
#  {'_id': '5b08109aa4416b00144b8475',
#   'date': '5_25_2018',
#   'headline': 'Review: ‘Mary Shelley’ Twists Pain Into a Monster',
#   'saved': False,
#   'summary': 'The film expands on the origin story of “Frankenstein,” suggesting various streams of the writer’s experience that feed into her chronicle of a misunderstood monster.',
#   'url': 'https://www.nytimes.com/2018/05/23/movies/mary-shelley-review-elle-fanning-frankenstein.html'},
#  {'_id': '5b08109aa4416b00144b8472',
#   'date': '5_25_2018',
#   'headline': 'Want to Make Money Like a C.E.O.? Work for 275 Years',
#   'saved': False,
#   'summary': 'For the first time, companies in the U.S. are disclosing how their C.E.O.’s compensation compares with the pay of employees. The results are eye-opening.',
#   'url': 'https://www.nytimes.com/2018/05/25/business/highest-paid-ceos-2017.html'},
#  {'_id': '5b08109aa4416b00144b846e',
#   'date': '5_25_2018',
#   'headline': 'Bombing at Ontario Restaurant Wounds at Least a Dozen',
#   'saved': False,
#   'summary': 'The police were looking for two suspects after the blast at Bombay Bhel in Mississauga, a city just west of Toronto.',
#   'url': 'https://www.nytimes.com/2018/05/25/world/americas/explosion-mississauga-ontario-canada.html'},
#  {'_id': '5b08109aa4416b00144b846d',
#   'date': '5_25_2018',
#   'headline': 'They Shared Drugs. Someone Died. Who Is Responsible?',
#   'saved': False,
#   'summary': 'Prosecutors are increasingly treating overdose deaths as homicides, but they aren’t just going after dealers. Friends, family and fellow users are going to prison.',
#   'url': 'https://www.nytimes.com/2018/05/25/us/drug-overdose-prosecution-crime.html'},
#  {'_id': '5b08109aa4416b00144b8469',
#   'date': '5_25_2018',
#   'headline': 'Trump Cancels Meeting With Kim',
#   'saved': False,
#   'summary': 'Mr. Trump said the meeting “will not take place.” But he later said it could still happen.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-trump-summit.html'},
#  {'_id': '5b08109aa4416b00144b8468',
#   'date': '5_25_2018',
#   'headline': 'Analysis: Trump’s Korea Gamble Hits a Reality Check',
#   'saved': False,
#   'summary': 'President Trump had sought to deal with Kim Jong-un the same way he had handled real estate negotiations — with threats and flattery. It didn’t work.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/trumps-gamble-hits-reality-check-in-north-korea-negotiations.html'},
#  {'_id': '5b08109aa4416b00144b8467',
#   'date': '5_25_2018',
#   'headline': 'Weinstein Is Arrested on Rape Charges in New York',
#   'saved': False,
#   'summary': 'Harvey Weinstein turned himself in to be arrested by New York City detectives on charges that he raped one woman and forced another to perform oral sex on him. The Hollywood mogul’s fall last year set off a worldwide reckoning over sexual misconduct.',
#   'url': 'https://www.nytimes.com/2018/05/25/nyregion/harvey-weinstein-arrested.html'},
#  {'_id': '5b07900be4b0fb0014699711',
#   'date': '5_25_2018',
#   'headline': 'Great Mexican Food in Australia Is Scarce. Bar Patrón Isn’t Helping.',
#   'saved': False,
#   'summary': 'The restaurant, from Neil Perry and the Rockpool Dining Group, offers margaritas and tacos that mostly miss the mark.',
#   'url': 'https://www.nytimes.com/2018/05/24/dining/bar-patron-rockpool-review-sydney.html'},
#  {'_id': '5b078fd7e4b0fb00146996f6',
#   'date': '5_25_2018',
#   'headline': 'North Korea, Malaysia Airlines, Deutsche Bank: Your Friday Briefing',
#   'saved': False,
#   'summary': 'Here’s what you need to know to start your day.',
#   'url': 'https://www.nytimes.com/2018/05/24/briefing/north-korea-malaysia-airlines-deutsche-bank.html'},
#  {'_id': '5b078fd7e4b0fb00146996f0',
#   'date': '5_25_2018',
#   'headline': 'Where Disaster Strikes in the U.S., Again and Again',
#   'saved': False,
#   'summary': 'In the last 16 years, most of the damage caused by catastrophes like wildfires and hurricanes have been concentrated in just a few areas.',
#   'url': 'https://www.nytimes.com/interactive/2018/05/24/us/disasters-hurricanes-wildfires-storms.html'},
#  {'_id': '5b078fd7e4b0fb00146996ee',
#   'date': '5_25_2018',
#   'headline': '‘How Not to Get Too Sad’: Santa Fe Students Turn to Parkland for Advice',
#   'saved': False,
#   'summary': 'As students at Santa Fe High take their first steps toward a public response to the shooting at their school, students from Parkland, Fla., are quietly advising them.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/santa-fe-shooting-students-parkland.html'},
#  {'_id': '5b078fd7e4b0fb00146996e8',
#   'date': '5_25_2018',
#   'headline': 'Prisons Chief Quit Over Kushner and Sessions Turf War',
#   'saved': False,
#   'summary': 'Some see Mark S. Inch’s departure as an opening for the Trump administration to endorse sentencing reform — one of the few issues that offer the possibility of a bipartisan deal.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/politics/mark-inch-kushner-sessions-federal-prisons.html'},
#  {'_id': '5b078fd7e4b0fb00146996e6',
#   'date': '5_25_2018',
#   'headline': 'Ireland Abortion Vote Shows Family and Gender Divides',
#   'saved': False,
#   'summary': 'Women are expected to vote in greater numbers in Friday’s referendum. But turnout among male Irish voters — who tend to consider abortion a women’s issue — may be critical.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/europe/ireland-abortion-referendum.html'},
#  {'_id': '5b078fd7e4b0fb00146996e1',
#   'date': '5_25_2018',
#   'headline': 'North Korea Says It Remains ‘Willing to Sit Down’ With U.S.',
#   'saved': False,
#   'summary': 'President Trump sent a letter to Kim Jong-un, North Korea’s leader, that cited the North’s “tremendous anger and open hostility” as the reason for canceling.Mr. Trump said later that the meeting could still happen, and North Korea issued a conciliatory response.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-trump-summit.html'},
#  {'_id': '5b0762b9e4b0fb00146996df',
#   'date': '5_25_2018',
#   'headline': 'Would You Go to a Republican Doctor?',
#   'saved': False,
#   'summary': 'Our political leanings distort our assessment of unrelated expertise.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/sunday/politics-distorts-judgment.html'},
#  {'_id': '5b0762b9e4b0fb00146996de',
#   'date': '5_25_2018',
#   'headline': 'Mourning My White Husband in the Age of Trump',
#   'saved': False,
#   'summary': 'I grieve for Alan and the clarity he brought to the issue of race not just as my husband but as a white man in America.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/sunday/interracial-marriage-trump-mourning.html'},
#  {'_id': '5b0762b9e4b0fb00146996dd',
#   'date': '5_25_2018',
#   'headline': 'The Off-Again Meeting With North Korea',
#   'saved': False,
#   'summary': 'President Trump now needs to corral his renegade advisers and resist the name-calling to get diplomacy back on track.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/trump-cancels-korea-summit.html'},
#  {'_id': '5b0762b9e4b0fb00146996db',
#   'date': '5_25_2018',
#   'headline': 'A Revolutionary ‘Sinfonia’ at the Philharmonic',
#   'saved': False,
#   'summary': 'Luciano Berio’s 1968 harbinger of postmodernism will feature Roomful of Teeth and be conducted by the maestro Semyon Bychkov.',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/music/new-york-philharmonic-berio-sinfonia-bychkov.html'},
#  {'_id': '5b0762b9e4b0fb00146996d1',
#   'date': '5_25_2018',
#   'headline': 'U.S. Forces vs. Russian Mercenaries: A Deadly 4 Hours',
#   'saved': False,
#   'summary': 'Interviews and newly obtained documents provide the Pentagon’s first public on-the-ground account of one of the bloodiest battles the military has faced in Syria since deploying to fight ISIS.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/middleeast/american-commandos-russian-mercenaries-syria.html'},
#  {'_id': '5b0762b9e4b0fb00146996c8',
#   'date': '5_25_2018',
#   'headline': 'Trump Proxies Drop by Briefings on Use of F.B.I. Informant',
#   'saved': False,
#   'summary': 'The presence of Emmet T. Flood, a lawyer representing the president in the Russia investigation, and John F. Kelly, the chief of staff, at the start of the classified meetings infuriated Democrats.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/politics/fbi-informant-russia-congress-briefings.html'},
#  {'_id': '5b0762b9e4b0fb00146996c7',
#   'date': '5_25_2018',
#   'headline': 'New Laws Make Europe the World’s Top Tech Watchdog',
#   'saved': False,
#   'summary': 'The European Union on Friday puts the world’s toughest data privacy rules into effect. The regulations are set to have an outsize impact far beyond Europe.',
#   'url': 'https://www.nytimes.com/2018/05/24/technology/europe-gdpr-privacy.html'},
#  {'_id': '5b0762b9e4b0fb00146996c4',
#   'date': '5_25_2018',
#   'headline': 'North Korea Offers ‘Time and Opportunity’ to Reconsider',
#   'saved': False,
#   'summary': 'With a carefully worded statement, North Korea tried to create an impression that Mr. Kim was the mature statesman trying to salvage the diplomatic process.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-trump-reconsider.html'},
#  {'_id': '5b0762b9e4b0fb00146996c3',
#   'date': '5_25_2018',
#   'headline': 'Trump’s Big Gamble Hits a Reality Check',
#   'saved': False,
#   'summary': 'The president attempted a revolutionary approach to North Korea. It didn’t work.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/trumps-gamble-hits-reality-check-in-north-korea-negotiations.html'},
#  {'_id': '5b072a01e4b0fb00146996bd',
#   'date': '5_24_2018',
#   'headline': 'Was Slavery a Factor in the Second Amendment?',
#   'saved': False,
#   'summary': 'The formation of what many call a “safeguard against tyranny” was, in part, a way to preserve the slave system.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/second-amendment-slavery-james-madison.html'},
#  {'_id': '5b072a01e4b0fb00146996bc',
#   'date': '5_24_2018',
#   'headline': 'Think Military Strikes Could Stop North Korea?',
#   'saved': False,
#   'summary': 'This simulation shows it’s not so simple.',
#   'url': 'https://www.nytimes.com/interactive/2018/05/24/opinion/north-korea-trump-military-strikes.html'},
#  {'_id': '5b072a01e4b0fb00146996bb',
#   'date': '5_24_2018',
#   'headline': 'Trump’s Relationship With North Korea Just Got More Dangerous',
#   'saved': False,
#   'summary': 'The cancellation of the meeting with Kim Jong-un creates a risk that the U.S. will revert to military options.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/north-korea-trump-kim-summit.html'},
#  {'_id': '5b072a01e4b0fb00146996b9',
#   'date': '5_24_2018',
#   'headline': 'André Leon Talley’s Next Act',
#   'saved': False,
#   'summary': 'The former Vogue creative director and “America’s Next Top Model” judge is taking care of himself. “Fashion does not take care of its people.”',
#   'url': 'https://www.nytimes.com/2018/05/24/style/andre-leon-talley-documentary.html'},
#  {'_id': '5b072a01e4b0fb00146996b8',
#   'date': '5_24_2018',
#   'headline': 'What Philip Roth Meant to an American Jew',
#   'saved': False,
#   'summary': 'His books answered the question of how a Jewish education would translate into the real world after surviving the ordeal of childhood.',
#   'url': 'https://www.nytimes.com/2018/05/24/books/philip-roth-jewish-education.html'},
#  {'_id': '5b072a01e4b0fb00146996b3',
#   'date': '5_24_2018',
#   'headline': 'Fun Things to Do in New York for Memorial Day Weekend',
#   'saved': False,
#   'summary': 'Music, bars and movies on rooftops. It’s Memorial Day weekend. Finally.',
#   'url': 'https://www.nytimes.com/2018/05/24/arts/things-to-do-in-nyc.html'},
#  {'_id': '5b072a01e4b0fb00146996b0',
#   'date': '5_24_2018',
#   'headline': 'The Language of Letting Go',
#   'saved': False,
#   'summary': 'Solving crossword puzzles helps a mother bond with her adult child in a new way.',
#   'url': 'https://www.nytimes.com/2018/05/23/crosswords/the-language-of-letting-go.html'},
#  {'_id': '5b072a01e4b0fb00146996af',
#   'date': '5_24_2018',
#   'headline': 'California’s ‘Top-Two’ Primary: Here’s How It All Works',
#   'saved': False,
#   'summary': 'California’s open primary system was supposed to favor moderates, but there’s a problem: some races in November may have two candidates from the same party.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/california-primary-election-rules-system.html'},
#  {'_id': '5b072a01e4b0fb00146996ac',
#   'date': '5_24_2018',
#   'headline': 'California Today: U.S.C.’s President Called On to Resign',
#   'saved': False,
#   'summary': 'Plus a Mexican Mafia crackdown in L.A. jails, and more.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/california-today-usc-president-gynecologist-scandal.html'},
#  {'_id': '5b072a01e4b0fb00146996aa',
#   'date': '5_24_2018',
#   'headline': 'Lawmakers Briefed on F.B.I. Informant in Russia Inquiry',
#   'saved': False,
#   'summary': 'It was not clear how much will be shared with lawmakers, some of whom have demanded information about the informant for weeks.',
#   'url': 'https://www.nytimes.com/2018/05/24/us/politics/fbi-informant-russia-congress-briefings.html'},
#  {'_id': '5b072a01e4b0fb00146996a9',
#   'date': '5_24_2018',
#   'headline': 'The Risky Business of Speaking for President Trump',
#   'saved': False,
#   'summary': 'Flacks in this White House press office are getting enormous exposure — but potentially at a long-term cost to their credibility.',
#   'url': 'https://www.nytimes.com/2018/05/23/magazine/the-risky-business-of-speaking-for-president-trump.html'},
#  {'_id': '5b072a01e4b0fb00146996a8',
#   'date': '5_24_2018',
#   'headline': 'What’s Worse Than a Crowded Airport? An Empty Airport',
#   'saved': False,
#   'summary': 'A spacious terminal in Memphis, built for when the city was a bustling air travel hub, has become a half-deserted white elephant that the airport is spending millions to shrink.',
#   'url': 'https://www.nytimes.com/2018/05/23/us/memphis-airport.html'},
#  {'_id': '5b072a01e4b0fb00146996a7',
#   'date': '5_24_2018',
#   'headline': 'The Cast of ‘Arrested Development’ Talked With Us. It Got Raw.',
#   'saved': False,
#   'summary': 'In a wide-ranging conversation about the new season, cast members became emotional as they discussed accusations of sexual misconduct against Jeffrey Tambor.',
#   'url': 'https://www.nytimes.com/2018/05/23/arts/television/arrested-development-netflix-interview-jeffrey-tambor.html'},
#  {'_id': '5b072a01e4b0fb00146996a6',
#   'date': '5_24_2018',
#   'headline': 'U.S. Commandos vs. Russian Mercenaries: Inside a Deadly Battle',
#   'saved': False,
#   'summary': 'Interviews and newly obtained documents provide the Pentagon’s first public on-the-ground accounting of one of the bloodiest battles the military has faced in Syria since deploying to fight ISIS.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/middleeast/american-commandos-russian-mercenaries-syria.html'},
#  {'_id': '5b072a01e4b0fb00146996a5',
#   'date': '5_24_2018',
#   'headline': 'Trump Pardons Boxing Champion Convicted in 1913',
#   'saved': False,
#   'summary': 'Decades after the heavyweight champion Jack Johnson’s legacy was tarnished by a racially charged conviction, his case drew attention as a gross miscarriage of justice.',
#   'url': 'https://www.nytimes.com/2018/05/24/sports/jack-johnson-pardon-trump.html'},
#  {'_id': '5b072a01e4b0fb00146996a4',
#   'date': '5_24_2018',
#   'headline': 'Weinstein, Accused of Sex Assault, Is Facing Arrest',
#   'saved': False,
#   'summary': 'Investigators in Manhattan were preparing to arrest Harvey Weinstein on Friday after an inquiry into allegations that he sexually assaulted numerous women. Mr. Weinstein is expected to surrender to authorities on Friday morning, according to two law enforcement officials.',
#   'url': 'https://www.nytimes.com/2018/05/24/nyregion/harvey-weinstein-arrest-new-york.html'},
#  {'_id': '5b072a01e4b0fb00146996a3',
#   'date': '5_24_2018',
#   'headline': 'Canceling of Meeting Upends Asia but Could Help China',
#   'saved': False,
#   'summary': 'The move will disappoint some, hearten others and perhaps benefit China. Much will depend on how North Korea reacts.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/trump-xi-jinping-north-korea.html'},
#  {'_id': '5b072a01e4b0fb00146996a2',
#   'date': '5_24_2018',
#   'headline': 'Trump Upends North Korea’s Big Moment',
#   'saved': False,
#   'summary': 'North Korea said it detonated its only known nuclear test site in a show of good faith. Then came Mr. Trump’s letter.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-shuts-nuclear-test-site.html'},
#  {'_id': '5b072a01e4b0fb00146996a1',
#   'date': '5_24_2018',
#   'headline': 'Letter to Leader of North Korea Cites Its ‘Open Hostility’',
#   'saved': False,
#   'summary': 'President Trump has notified Kim Jong-un, the North Korean leader, that he has canceled their meeting, which was set for June 12.In a letter to Mr. Kim, Mr. Trump cited “tremendous anger and open hostility displayed in your most recent statement.”',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-trump-summit.html'},
#  {'_id': '5b06b4b4e4b0fb001469969d',
#   'date': '5_24_2018',
#   'headline': 'Did the F.B.I. Save Trump’s Presidency?',
#   'saved': False,
#   'summary': 'President Trump should have welcomed the surveillance.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/james-clapper-fbi-trump.html'},
#  {'_id': '5b06b4b4e4b0fb001469969c',
#   'date': '5_24_2018',
#   'headline': 'President Trump Is a Very Political Animal',
#   'saved': False,
#   'summary': '“The least racist person” ever doesn’t bother with dog-whistling. He just lets it all hang out.',
#   'url': 'https://www.nytimes.com/2018/05/24/opinion/trump-animals-immigrants-politics.html'},
#  {'_id': '5b06b4b4e4b0fb001469969a',
#   'date': '5_24_2018',
#   'headline': 'After Viral Song, Clairo Learns Perils of Fame',
#   'saved': False,
#   'summary': 'With her song “Pretty Girl,” the 19-year-old bedroom pop singer and songwriter is getting a taste of the hardships that come with fame.',
#   'url': 'https://www.nytimes.com/2018/05/23/arts/music/clairo-pretty-girl-diary-001.html'},
#  {'_id': '5b06b4b4e4b0fb0014699699',
#   'date': '5_24_2018',
#   'headline': 'Philip Roth, a Born Spellbinder',
#   'saved': False,
#   'summary': 'Roth’s work had more rage, more wit, more lust, more talk, and more crosscurrents of thought and emotion than any writer of his time.',
#   'url': 'https://www.nytimes.com/2018/05/23/books/philip-roth-apprasial.html'},
#  {'_id': '5b06b4b4e4b0fb0014699698',
#   'date': '5_24_2018',
#   'headline': '36 Hours in Chattanooga',
#   'saved': False,
#   'summary': 'Nearly geeky in its optimism — and all the better for it — this friendly Tennessee city is a breath of fresh air.',
#   'url': 'https://www.nytimes.com/2018/05/24/travel/what-to-do-chattanooga.html'},
#  {'_id': '5b06b4b4e4b0fb0014699695',
#   'date': '5_24_2018',
#   'headline': 'Small-Town Wisdom for You and Me',
#   'saved': False,
#   'summary': 'It takes a lot to create a community that reflects the Enlightenment principle of equality for all. Are pig farmers better at it than urban professionals?',
#   'url': 'https://www.nytimes.com/2018/05/24/world/australia/immigration-small-towns-letter59.html'},
#  {'_id': '5b06b4b4e4b0fb0014699692',
#   'date': '5_24_2018',
#   'headline': '‘This Is His Turf’: Nixon Works a Tough Convention Crowd',
#   'saved': False,
#   'summary': 'Cynthia Nixon faces a challenge to expand her appeal beyond the faction of die-hard activists who dislike Gov. Andrew Cuomo.',
#   'url': 'https://www.nytimes.com/2018/05/24/nyregion/cynthia-nixon-cuomo-governor-ny.html'},
#  {'_id': '5b06b4b4e4b0fb0014699691',
#   'date': '5_24_2018',
#   'headline': 'Big Discovery in Tiny Skull Found Under Dinosaur’s Foot',
#   'saved': False,
#   'summary': 'Paleontologists found a 130 million-year-old haramiyid fossil in Utah, suggesting that the ancient relatives of modern mammals spread farther across the globe than thought.',
#   'url': 'https://www.nytimes.com/2018/05/23/science/haramiyid-skull-utah.html'},
#  {'_id': '5b06b4b4e4b0fb001469968f',
#   'date': '5_24_2018',
#   'headline': 'There Are Two Georgias. One Just Made History.',
#   'saved': False,
#   'summary': 'The victory of Stacey Abrams, the first black woman to win a major party’s nomination for governor in the U.S., highlights the divide between Georgia’s diverse cities, led by Atlanta, and its conservative countryside.',
#   'url': 'https://www.nytimes.com/2018/05/23/us/georgia-governor-stacey-abrams.html'},
#  {'_id': '5b06b4b4e4b0fb0014699688',
#   'date': '5_24_2018',
#   'headline': 'When U.S. Troops Battled Russian Mercenaries in Syria',
#   'saved': False,
#   'summary': 'Interviews and newly obtained documents provide the Pentagon’s first public on-the-ground accounting of one of the bloodiest battles the military has faced in Syria since deploying to fight ISIS.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/middleeast/american-commandos-russian-mercenaries-syria.html'},
#  {'_id': '5b06b4b4e4b0fb0014699685',
#   'date': '5_24_2018',
#   'headline': 'China May Be Happy as Prospects Dim for Trump-Kim Meeting',
#   'saved': False,
#   'summary': 'A delay in the meeting may benefit President Xi Jinping, who could use his influence with North Korea as leverage while China negotiates a trade deal with Washington.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/trump-xi-jinping-north-korea.html'},
#  {'_id': '5b06b4b4e4b0fb0014699684',
#   'date': '5_24_2018',
#   'headline': 'North Korea Says It Has Destroyed Nuclear Test Site',
#   'saved': False,
#   'summary': 'The event, three weeks before Kim Jong-un is scheduled to meet with President Trump, was captured by foreign journalists.North Korea did not invite any independent nuclear monitors to verify the dismantlement.',
#   'url': 'https://www.nytimes.com/2018/05/24/world/asia/north-korea-shuts-nuclear-test-site.html'},
#  {'_id': '5b067a1ce4b0fb0014699683',
#   'date': '5_24_2018',
#   'headline': 'House Hunting in … Spain',
#   'saved': False,
#   'summary': 'While some parts of Spain’s real estate market remain depressed, demand and prices are rising in major cities and tourist destinations like Seville.',
#   'url': 'https://www.nytimes.com/2018/05/23/realestate/house-hunting-in-seville-spain.html'},
#  {'_id': '5b0654943c459f0014c05571',
#   'date': '5_24_2018',
#   'headline': 'The N.F.L. Kneels to Trump',
#   'saved': False,
# ...
#   'url': 'https://www.nytimes.com/2018/05/02/world/europe/spain-eta-disbands-basque.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa15',
#   'date': '5_2_2018',
#   'headline': 'These 7 People Sought U.S. Asylum. Their Cases Say a Lot.',
#   'saved': False,
#   'summary': 'Thousands of applicants are seeking asylum in America, claiming persecution in their homelands. But fearing for your life is not enough. What kinds of cases have been successful?',
#   'url': 'https://www.nytimes.com/2018/05/02/us/what-it-takes-to-get-asylum-us.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa12',
#   'date': '5_2_2018',
#   'headline': 'California Today: Challenges for Los Angeles Schools',
#   'saved': False,
#   'summary': 'Plus, California sues the Trump administration over emissions.',
#   'url': 'https://www.nytimes.com/2018/05/02/us/california-today-los-angeles-schools-superintendent.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa10',
#   'date': '5_2_2018',
#   'headline': 'Revelations Over Koch Gifts Prompt Inquiry at University',
#   'saved': False,
#   'summary': 'George Mason University ordered an investigation after documents were released showing that the Charles Koch Foundation had been given a voice in hiring faculty.',
#   'url': 'https://www.nytimes.com/2018/05/01/us/koch-george-mason-university.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0f',
#   'date': '5_2_2018',
#   'headline': 'G.O.P. Obamacare Repeal Vote Becomes Democratic Weapon',
#   'saved': False,
#   'summary': 'Democratic candidates for the House say voters will punish Republicans for voting last year to repeal and replace the Affordable Care Act, even though the law survived.',
#   'url': 'https://www.nytimes.com/2018/05/02/us/politics/house-obamacare-repeal-vote-anniversary.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0e',
#   'date': '5_2_2018',
#   'headline': 'U.S. Breaks With Europe Over Israel’s Claims on Iran',
#   'saved': False,
#   'summary': 'The starkly divergent reactions suggested how the debate over the Iran deal was likely to play out should President Trump decide to reimpose sanctions on Tehran.',
#   'url': 'https://www.nytimes.com/2018/05/01/us/politics/israel-iran-deal-united-states.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0d',
#   'date': '5_2_2018',
#   'headline': 'Lobbyist Who Steered Pruitt’s Morocco Trip Was Hired There',
#   'saved': False,
#   'summary': 'Scott Pruitt let a lobbyist play an unusually influential role in setting his agenda during a visit to Morocco. The Moroccan government later hired the man.',
#   'url': 'https://www.nytimes.com/2018/05/01/us/pruitt-epa-trips-lobbyists.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0c',
#   'date': '5_2_2018',
#   'headline': '‘We’ll See,’ Trump Says on North Korea. And Iran. And So On.',
#   'saved': False,
#   'summary': 'The president’s verbal tic seems to have gone into overdrive, and those who study his speech patterns are starting to wonder: What happens when we finally see what happens?',
#   'url': 'https://www.nytimes.com/2018/05/02/us/politics/trump-well-see-what-happens.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0b',
#   'date': '5_2_2018',
#   'headline': 'Trump’s Ex-Doctor Says He Was Raided by Trump Aides',
#   'saved': False,
#   'summary': 'President Trump’s longtime physician said that he was cut out of the Trump orbit last year and that two aides seized Mr. Trump’s medical records without authorization.',
#   'url': 'https://www.nytimes.com/2018/05/01/us/politics/trump-doctor-harold-bornstein.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa0a',
#   'date': '5_2_2018',
#   'headline': 'Clinton Impeachment Lawyer Emmett Flood to Join Trump Team',
#   'saved': False,
#   'summary': 'Ty Cobb, who had at one time persuaded President Trump not to attack the special counsel publicly, will be replaced by the more adversarial Emmet Flood, who represented Bill Clinton in his impeachment.',
#   'url': 'https://www.nytimes.com/2018/05/02/us/politics/emmet-flood-ty-cobb-white-house-lawyer-special-counsel.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa09',
#   'date': '5_2_2018',
#   'headline': 'Ukraine Halted Cooperation With Mueller Investigation',
#   'saved': False,
#   'summary': 'Ukraine, deeply dependent on the Trump administration for financial and military aid, froze its cooperation with the special counsel’s office.',
#   'url': 'https://www.nytimes.com/2018/05/02/world/europe/ukraine-mueller-manafort-missiles.html'},
#  {'_id': '5ae9f4c832b5cb0014eeaa08',
#   'date': '5_2_2018',
#   'headline': 'Why Talking to Mueller Could Be a Minefield for Trump',
#   'saved': False,
#   'summary': 'President Trump’s lawyers, who do not know everything that the special counsel, Robert S. Mueller III, has learned, have been trying to talk Mr. Trump out of agreeing to be interviewed. Mr. Mueller’s questions are so broad that Mr. Trump would need a detailed command of a range of issues.',
#   'url': 'https://www.nytimes.com/2018/05/01/us/politics/trump-mueller-interview-questions.html'},
#  {'_id': '5ae8ed1116cd0200145a9f63',
#   'date': '5_1_2018',
#   'headline': 'What Robert Mueller Knows',
#   'saved': False,
#   'summary': 'Donald Trump’s former lawyer didn’t want him to speak with the special counsel. The questions published Monday explain why.',
#   'url': 'https://www.nytimes.com/2018/05/01/opinion/robert-mueller-russia-investigation.html'},
#  {'_id': '5ae8ed1116cd0200145a9f62',
#   'date': '5_1_2018',
#   'headline': 'Don Nelson Talks Hoops, Poker and, Uh, Weed',
#   'saved': False,
#   'summary': 'The N.B.A. maverick emeritus, now 77 and living on Maui, discussed winning, losing and dulling the pain of aging.',
#   'url': 'https://www.nytimes.com/2018/04/30/style/don-nelson-nba-weed.html'},
#  {'_id': '5ae8ed1116cd0200145a9f61',
#   'date': '5_1_2018',
#   'headline': 'Woodrow Wilson and the Hazards of Idealism',
#   'saved': False,
#   'summary': 'Patricia O’Toole’s book “The Moralist” examines the 28th president’s long-lasting effect on American foreign policy.',
#   'url': 'https://www.nytimes.com/2018/05/01/books/review-moralist-woodrow-wilson-patricia-otoole.html'},
#  {'_id': '5ae8ed1116cd0200145a9f60',
#   'date': '5_1_2018',
#   'headline': 'Oral History of Frat House Classic ‘Animal House’',
#   'saved': False,
#   'summary': 'Richard Pryor may have saved the film when an executive demanded changes, so say the director and cast members.',
#   'url': 'https://www.nytimes.com/2018/05/01/movies/animal-house-oral-history.html'},
#  {'_id': '5ae8ed1116cd0200145a9f5a',
#   'date': '5_1_2018',
#   'headline': 'Test for New Chancellor: Middle School Desegregation Plan',
#   'saved': False,
#   'summary': 'Just four weeks into his tenure as New York City schools chancellor, Richard Carranza caused an uproar with a tweet on the issue of segregation in the city’s schools.',
#   'url': 'https://www.nytimes.com/2018/05/01/nyregion/new-york-school-segregation-carranza.html'},
#  {'_id': '5ae8ed1116cd0200145a9f58',
#   'date': '5_1_2018',
#   'headline': 'In a Slim Season, Tonys Show Love to Classics and Sponges',
#   'saved': False,
#   'summary': 'Our chief critics offer reaction to the nominations, which were hard on jukebox musicals and “Frozen” but good to “My Fair Lady” and “Carousel.”',
#   'url': 'https://www.nytimes.com/2018/05/01/theater/tony-nominees-critics-reaction.html'},
#  {'_id': '5ae8ed1116cd0200145a9f57',
#   'date': '5_1_2018',
#   'headline': 'When Old Left and Far Right Share a Bedroom',
#   'saved': False,
#   'summary': 'Helmut Lethen and Caroline Sommerfeld, who live in Germany, speak for two intellectual camps. They are political enemies. And they are married, having a dialogue their country is not.',
#   'url': 'https://www.nytimes.com/2018/05/01/world/europe/germany-helmut-lethen-caroline-sommerfeld.html'},
#  {'_id': '5ae8ed1116cd0200145a9f54',
#   'date': '5_1_2018',
#   'headline': 'Britain’s Wedding-Mad Tabloids Get a Royal Cold Shoulder',
#   'saved': False,
#   'summary': 'The wedding of Prince Harry and Meghan Markle may be the event of the year for the popular press, but only one reporter will be present for the ceremony.',
#   'url': 'https://www.nytimes.com/2018/05/01/world/europe/uk-royal-wedding-tabloids.html'},
#  {'_id': '5ae8ed1116cd0200145a9f4e',
#   'date': '5_1_2018',
#   'headline': 'Why NASA Will Explore One of Mars’s Most Boring Spots',
#   'saved': False,
#   'summary': 'Moving away from NASA’s Mars mantra of “follow the water,” InSight will instead help answer geophysical questions.',
#   'url': 'https://www.nytimes.com/2018/04/30/science/mars-insight-launch.html'},
#  {'_id': '5ae8ed1116cd0200145a9f4d',
#   'date': '5_1_2018',
#   'headline': 'Europe Is Annoyed, Not Grateful, After Trump Delays Tariffs',
#   'saved': False,
#   'summary': 'European officials expressed disappointment that an exemption to steel and aluminum tariffs was not permanent, leaving the global economy in limbo.',
#   'url': 'https://www.nytimes.com/2018/05/01/business/trade-tariffs-trump-europe.html'},
#  {'_id': '5ae8ed1116cd0200145a9f4c',
#   'date': '5_1_2018',
#   'headline': 'Two Top Aides to Scott Pruitt Quit the E.P.A. Unexpectedly',
#   'saved': False,
#   'summary': 'Mr. Pruitt’s security chief and his Superfund administrator have resigned amid inquiries into the agency’s spending and management practices.',
#   'url': 'https://www.nytimes.com/2018/05/01/climate/epa-kelly-perrotta-resignations.html'},
#  {'_id': '5ae8ed1116cd0200145a9f4b',
#   'date': '5_1_2018',
#   'headline': 'California Sues E.P.A. Over Car Emissions Rules',
#   'saved': False,
#   'summary': 'The state’s move escalates a revolt against a proposed rollback of fuel economy standards that threatens to split the country’s auto market.',
#   'url': 'https://www.nytimes.com/2018/05/01/climate/california-sues-trump-administration.html'},
#  {'_id': '5ae8ed1116cd0200145a9f4a',
#   'date': '5_1_2018',
#   'headline': 'R. Kelly Faces a #MeToo Reckoning After Years of Claims',
#   'saved': False,
#   'summary': 'Time’s Up has thrown its support behind the grass-roots protest campaign #MuteRKelly, putting new pressure on the once-untouchable R&B musician after more than two decades of allegations of sexual misconduct.',
#   'url': 'https://www.nytimes.com/2018/05/01/arts/music/r-kelly-timesup-metoo-muterkelly.html'},
#  {'_id': '5ae8ed1116cd0200145a9f48',
#   'date': '5_1_2018',
#   'headline': 'Mosquito and Tick Infections Are Surging, C.D.C. Says',
#   'saved': False,
#   'summary': 'Americans are getting Zika, dengue and Lyme diseases in increasing numbers. Warming weather and a lack of vaccines are among the causes, according to the Centers for Disease Control and Prevention.',
#   'url': 'https://www.nytimes.com/2018/05/01/health/ticks-mosquitoes-diseases.html'},
#  {'_id': '5ae87fdb16cd0200145a9f44',
#   'date': '5_1_2018',
#   'headline': 'The Real Villain Behind Our New Gilded Age',
#   'saved': False,
#   'summary': 'It’s not globalization or automation but the lopsided monopoly power that favors corporations.',
#   'url': 'https://www.nytimes.com/2018/05/01/opinion/monopoly-power-new-gilded-age.html'},
#  {'_id': '5ae87fdb16cd0200145a9f43',
#   'date': '5_1_2018',
#   'headline': 'The Implausible Promises of a T-Mobile-Sprint Merger',
#   'saved': False,
#   'summary': 'The wireless companies are trying to win over regulators with a laundry list of assurances.',
#   'url': 'https://www.nytimes.com/2018/04/30/opinion/tmobile-sprint-merger-implausible.html'},
#  {'_id': '5ae87fdb16cd0200145a9f42',
#   'date': '5_1_2018',
#   'headline': 'Letting Sprint and T-Mobile Merge Is a Terrible Idea',
#   'saved': False,
#   'summary': 'Consolidation would end the “wireless wars” that have lowered prices and improved service for consumers.',
#   'url': 'https://www.nytimes.com/2018/05/01/opinion/sprint-t-mobile-merger.html'},
#  {'_id': '5ae87fdb16cd0200145a9f41',
#   'date': '5_1_2018',
#   'headline': 'The Odd Couple That Created Modern Musicals',
#   'saved': False,
#   'summary': 'In “Something Wonderful: Rodgers and Hammerstein’s Broadway Revolution,” Todd S. Purdum analyzes the legacy of two brilliant songwriters.',
#   'url': 'https://www.nytimes.com/2018/05/01/books/review/something-wonderful-todd-s-purdum.html'},
#  {'_id': '5ae87fdb16cd0200145a9f40',
#   'date': '5_1_2018',
#   'headline': 'The Duplass Brothers Recall Getting Cable TV',
#   'saved': False,
#   'summary': 'Dark dramas on HBO inspired Mark and Jay Duplass to make their first movie, at ages 8 and 12, about a karate master who battles a robber.',
#   'url': 'https://www.nytimes.com/2018/04/30/movies/first-time-mark-duplass-jay-duplass-got-cable.html'},
#  {'_id': '5ae87fdb16cd0200145a9f3f',
#   'date': '5_1_2018',
#   'headline': 'Haven for Flight Personnel After Touching Down',
#   'saved': False,
#   'summary': 'Kew Gardens in Queens is known as “Crew Gardens” for its popularity with airline crew members who work at the two nearby airports.',
#   'url': 'https://www.nytimes.com/2018/04/30/nyregion/kew-gardens-crew-gardens-queens-airline-workers.html'},
#  {'_id': '5ae87fdb16cd0200145a9f3e',
#   'date': '5_1_2018',
#   'headline': 'Kabul, Netanyahu, North Korea: Your Tuesday Briefing',
#   'saved': False,
#   'summary': 'Here’s what you need to know to start your day.',
#   'url': 'https://www.nytimes.com/2018/04/30/briefing/kabul-netanyahu-north-korea.html'},
#  {'_id': '5ae87fdb16cd0200145a9f3d',
#   'date': '5_1_2018',
#   'headline': 'Cardinal George Pell to Stand Trial on Historical Sex Offenses',
#   'saved': False,
#   'summary': 'An Australian court has ruled that the cardinal, the Vatican’s No. 3 official, can be prosecuted, but the most serious charges were dismissed.',
#   'url': 'https://www.nytimes.com/2018/04/30/world/australia/cardinal-george-pell-trial-sexual-abuse.html'},
#  {'_id': '5ae87fdb16cd0200145a9f39',
#   'date': '5_1_2018',
#   'headline': 'Was Silver Corrupt, or Was It Just Politics as Usual?',
#   'saved': False,
#   'summary': 'Sheldon Silver, the once powerful Assembly speaker in New York, is being retried on public corruption charges, after an early conviction was overturned.',
#   'url': 'https://www.nytimes.com/2018/04/30/nyregion/sheldon-silver-corruption-retrial-assembly-speaker.html'},
#  {'_id': '5ae87fdb16cd0200145a9f38',
#   'date': '5_1_2018',
#   'headline': 'Your Privacy Concerns Probably Reflect Your Politics',
#   'saved': False,
#   'summary': 'A new study on surveillance finds that Republicans tend to feel pleased about tracking, both online and in real life, while Democrats often feel bad about it.',
#   'url': 'https://www.nytimes.com/2018/04/30/technology/privacy-concerns-politics.html'},
#  {'_id': '5ae87fdb16cd0200145a9f37',
#   'date': '5_1_2018',
#   'headline': '‘Mean Girls’ and ‘SpongeBob’ Lead Tony Nominations',
#   'saved': False,
#   'summary': 'A pair of two-part productions, “Harry Potter and the Cursed Child” and the revival of “Angels in America,” were also showered with affection.',
#   'url': 'https://www.nytimes.com/2018/05/01/theater/tony-award-nominations.html'},
#  {'_id': '5ae87fdb16cd0200145a9f36',
#   'date': '5_1_2018',
#   'headline': 'A Week Inside a Soccer Club When the Money Runs Out',
#   'saved': False,
#   'summary': 'Every year, through careless management or reckless ambition, a handful of soccer clubs drift uncomfortably close to collapse. In February, Denmark’s Lyngby B.K. came closer than most.',
#   'url': 'https://www.nytimes.com/2018/04/30/sports/soccer/lyngby-bk-bankruptcy.html'},
#  {'_id': '5ae87fdb16cd0200145a9f35',
#   'date': '5_1_2018',
#   'headline': 'Meet the Schlapps, Washington’s Trump-Era ‘It Couple’',
#   'saved': False,
#   'summary': 'Matt and Mercedes Schlapp, conservatives who scrambled aboard the Trump juggernaut, have made money, lost friends and become a symbol of the deep divide in the G.O.P.',
#   'url': 'https://www.nytimes.com/2018/04/30/us/politics/schlapp-trump.html'},
#  {'_id': '5ae87fdb16cd0200145a9f34',
#   'date': '5_1_2018',
#   'headline': 'Photojournalist Killed in Kabul Left a Legacy of Images',
#   'saved': False,
#   'summary': 'Shah Marai bore witness to years of bloodshed. On Monday, he was among 25 people, nine of them journalists, killed in a pair of bombings in the Afghan capital. Here is a selection of his work.',
#   'url': 'https://www.nytimes.com/2018/04/30/world/asia/shah-marai-afghan-photographer-killed.html'},
#  ...]

# %%
# Print first and last articles
# CODE HERE
print(variable[0])
print(variable[-1]) #!!!!!!!!!!!!!! index of -1 does the last!!
# Out:
# 2724
# {'_id': '5b0a10420b7b8a0014cbb3d0', 'headline': 'Cuomo’s So-Called Women’s Party', 'summary': 'Four years ago Gov. Andrew M. Cuomo invented a political party to attract female voters. In the #MeToo era, our columnist asks, will women fall for a political shell company?', 'url': 'https://www.nytimes.com/2018/05/24/nyregion/cuomos-so-called-womens-party.html', 'date': '5_27_2018', 'saved': True}
# {'_id': '5ab3c9449dfb600014f246d9', 'headline': 'What We Know About the Suspect', 'summary': 'Mark Conditt is believed to be linked to six bombs or explosions that killed at least two people and injured several others.', 'url': 'https://www.nytimes.com/2018/03/21/us/mark-anthony-conditt-austin-bomber.html', 'date': '3_22_2018', 'saved': False}

# %%
#Print the number of responses received.
# CODE HERE
print(len(variable))
# Out:
# 2724

# %% [markdown]
# # Instructor Turn Activity 3 Open Weather Request

# %%
# Dependencies
import json
import requests
from config import api_key

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
# Get the temperature from the response
print(f"The weather API responded with: {json.dumps(weather_json, indent=2)}.")
# Out:
# The weather API responded with: {
#   "coord": {
#     "lon": -0.13,
#     "lat": 51.51
#   },
#   "weather": [
#     {
#       "id": 500,
#       "main": "Rain",
#       "description": "light rain",
#       "icon": "10n"
#     },
#     {
#       "id": 721,
#       "main": "Haze",
#       "description": "haze",
#       "icon": "50n"
#     }
#   ],
#   "base": "stations",
#   "main": {
#     "temp": 289.27,
#     "pressure": 1016,
#     "humidity": 88,
#     "temp_min": 288.15,
#     "temp_max": 290.15
#   },
#   "visibility": 8000,
#   "wind": {
#     "speed": 2.6
#   },
#   "clouds": {
#     "all": 56
#   },
#   "dt": 1527384000,
#   "sys": {
#     "type": 1,
#     "id": 5091,
#     "message": 0.0118,
#     "country": "GB",
#     "sunrise": 1527393217,
#     "sunset": 1527451350
#   },
#   "id": 2643743,
#   "name": "London",
#   "cod": 200
# }.

# %% [markdown]
# # Students Turn Activity 4 Weather in Bujumbura
#
# This activity gives students practice with making API calls and handling responses.
#
# ## Instructions
#
# * Save all of your "config" information—i.e., your API key; the base URL; etc.—before moving on.
#
# * Build your query URL. Check the documentation to figure out how to request temperatures in Celsius.
#
# * Make your request, and save the API's response.
#
# * Retrieve the current temperature in Bujumbura from the JSON response.
#
# * Print the temperature to the console.
#
# ## Bonus
#
# * Augment your code to report the temperature in both Fahrenheit _and_ Celsius.

# %%
# Dependencies
import requests
from config import api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Bujumbura"
units = "metric"

# %%
# Build query URL and request your results in Celsius
# CODE HERE
query = url + "appid=" + api_key + "&q=" + city + "&units=metric"
# Get weather data
# CODE HERE
weather_bermuda = requests.get(query).json()
weather_bermuda
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -3.36, 'lon': 29.37},
#  'dt': 1527389142,
#  'id': 425378,
#  'main': {'grnd_level': 857.8,
#   'humidity': 100,
#   'pressure': 857.8,
#   'sea_level': 1024.63,
#   'temp': 13.92,
#   'temp_max': 13.92,
#   'temp_min': 13.92},
#  'name': 'Bujumbura',
#  'sys': {'country': 'BI',
#   'message': 0.0032,
#   'sunrise': 1527393679,
#   'sunset': 1527436681},
#  'weather': [{'description': 'few clouds',
#    'icon': '02n',
#    'id': 801,
#    'main': 'Clouds'}],
#  'wind': {'deg': 52.5055, 'speed': 0.96}}

# %%
# Get temperature from JSON response
# CODE HERE
temp = weather_bermuda["main"]["temp"]

# %%
# Report temperature
# CODE HERE
print(f"The temperature is {temp} degrees Celsius")
# Out:
# The temperature is 13.92 degrees Celsius

# %%
# BONUS

# %% [markdown]
# # Instructor Turn Activity 5 Open Weather DataFrame

# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
lat = []
temp = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [48.86, 51.51, 59.91, 39.91]
# The temperature information received is: [18.49, 15.62, 13, 29]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#       city    lat   temp
# 0    Paris  48.86  18.49
# 1   London  51.51  15.62
# 2     Oslo  59.91  13.00
# 3  Beijing  39.91  29.00

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ### Students Turn Activity 6 TV Ratings
#
# In this activity, you will create an application that reads in a list of TV shows, makes multiple requests from an API to retrieve rating information, creates a pandas dataframe, and a visually displays the data.
#
# ## Instructions:
#
# * You may use the list provided in the starter file or create your own.
#
# * Request information from the TVmaze API's Show Search endpoint (https://www.tvmaze.com/api#show-search) on each show and store the name and rating information into lists.
#
# * Put this data into a dictionary, and load that dict into a Pandas DataFrame.
#
# * Use matplotlib to create a bar chart comparing the ratings of each show.

# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#list of tv show titles to query
tv_shows = ["Altered Carbon", "Grey's Anatomy", "This is Us", "The Flash", "Vikings", "Shameless", "Arrow", "Peaky Blinders", "Dirk Gently"]
# make iterative requests to TVmaze search endpoint

# tv maze show search base url
base_url = "http://api.tvmaze.com/search/shows?q="

name = []
rating = []


for show in tv_shows: 
    request = base_url + show
    tvmaze = requests.get(request).json()
    name.append(tvmaze[0]["show"]["name"])
    rating.append(tvmaze[0]["show"]["rating"]["average"])

# set up lists to hold response data for name and rating


# loop through tv show titles, make requests and parse


print(name)
print(rating)
# Out:
# ['Altered Carbon', "Grey's Anatomy", 'This Is Us', 'The Flash', 'Vikings', 'Shameless', 'Arrow', 'Peaky Blinders', 'Dirk Gently']
# [8.3, 8.2, 8.2, 8.1, 8.9, 8.8, 7.6, 9, 7.5]

# %%
# create dataframe
# CODE HERE 
shows_dict = {
    "name": name,
    "rating": rating,
}

shows_data = pd.DataFrame(shows_dict)
shows_data.head()
# Out:
# {'name': ['Altered Carbon', "Grey's Anatomy", 'This Is Us', 'The Flash', 'Vikings', 'Shameless', 'Arrow', 'Peaky Blinders', 'Dirk Gently'], 'rating': [8.3, 8.2, 8.2, 8.1, 8.9, 8.8, 7.6, 9, 7.5]}
#              name  rating
# 0  Altered Carbon     8.3
# 1  Grey's Anatomy     8.2
# 2      This Is Us     8.2
# 3       The Flash     8.1
# 4         Vikings     8.9

# %%
# use matplotlib to create a bar chart from the dataframe
#CODE HERE


shows_data.plot(kind="bar")
# create a list of numbers for x values
plt.xticks = (len(shows_data["name"]), shows_data["name"])
# create bar chart and set the values of xticks
shows_data["name"]
# Out:
# 0    Altered Carbon
# 1    Grey's Anatomy
# 2        This Is Us
# 3         The Flash
# 4           Vikings
# 5         Shameless
# 6             Arrow
# 7    Peaky Blinders
# 8       Dirk Gently
# Name: name, dtype: object

# %% [markdown]
# # Instructor Turn Activity 7 Exception Handling

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

print(students["Jezebel"])

print("This line will never print.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-c4b070079987> in <module>()
#       6 }
#       7
# ----> 8 print(students["Jezebel"])
#       9
#      10 print("This line will never print.")
#
# KeyError: 'Jezebel'

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

# Try to access key that doesn't exist
try:
    students["Jezebel"]
except KeyError:
    print("Oops, that key doesn't exist.")

# "Catching" the error lets the rest of our code execute
print("...But the program doesn't die early!")
# Out:
# Oops, that key doesn't exist.
# ...But the program doesn't die early!

# %% [markdown]
# # Student Turn Activity
# ## Making Exceptions
#
# ### Instructions:
#
#   * Without removing any of the lines from the starter code provided, create `try` and `except` blocks that will allow the application to run without terminating.

# %%
# Your assignment is to get the last line to print without changing any
# of the code below. Instead, wrap each line that throws an error in a
# try/except block.
try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except ZeroDivisionError:
    print("error")
try:
    print("I think her name was + " + name + "?")
except TypeError:
    print("error")    
try:
    print("Your name is a nonsense number. Look: " + int("Gabriel"))
except ValueError:
    print("error")
    
    print("You made it through the gauntlet--the message survived!")
# Out:
# error
# error
# error
# You made it through the gauntlet--the message survived!

# %%
# Your assignment is to get the last line to print without changing any
# of the code below. Instead, wrap each line that throws an error in a
# try/exept block.
# CODE HERE

# %% [markdown]
# # Instructor Turn Activity 9 Open Weather Wrapper

# %%
# !pip install openweathermapy
# Out:
# Collecting openweathermapy
#   Downloading https://files.pythonhosted.org/packages/41/ea/eda328e60ffc8ee201c6743ecb463ef122f10f9d13ec9fcaa0028736ce4e/openweathermapy-0.6.6.tar.gz
# Building wheels for collected packages: openweathermapy
#   Running setup.py bdist_wheel for openweathermapy: started
#   Running setup.py bdist_wheel for openweathermapy: finished with status 'done'
#   Stored in directory: C:\Users\Laura\AppData\Local\pip\Cache\wheels\c4\1d\0d\1a3bfa432ec120fcc8d8dcf316bc17b1e779fcbfb17e78a2ec
# Successfully built openweathermapy
# Installing collected packages: openweathermapy
# Successfully installed openweathermapy-0.6.6
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies
import openweathermapy.core as owm

#config
from config import api_key

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}

# %%
# Get current weather
current_weather_paris = owm.get_current("Paris", **settings)
print(f"Current weather object for Paris: {current_weather_paris}.")
# Out:
# Current weather object for Paris: {'coord': {'lon': 2.35, 'lat': 48.86}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 18.74, 'pressure': 1014, 'humidity': 88, 'temp_min': 17, 'temp_max': 21}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1527388200, 'sys': {'type': 1, 'id': 5610, 'message': 0.0041, 'country': 'FR', 'sunrise': 1527393336, 'sunset': 1527450036}, 'id': 2988507, 'name': 'Paris', 'cod': 200}.

# %%
summary = ["name", "main.temp"]

data = current_weather_paris(*summary)
print(f"The current weather summary for Paris is: {data}.")
# Out:
# The current weather summary for Paris is: ('Paris', 18.74).

# %% [markdown]
# # Students Turn Activity 10 Map Wrap
#
# This activity demonstrates the additional ease of use afforded by API wrappers.
#
# ## Instructions
#
#   * Install the openweathermapy API wrapper.
#
#   * Create a settings object with your API key and preferred units of measurement.
#
#   * Get data for each city that is listed within `cities.csv`.
#
#   * Create a list to get the temperature, latitude, and longitude in each city
#
#   * Create a Pandas DataFrame with the results.
#
#   * Print your summaries to verify that everything went smoothly.
#
# Hint: Don't forget to utilize the openweathermapy documentation where needed: http://openweathermapy.readthedocs.io/en/latest/
#
# ## Bonus:
#
#   * If you finish early, read about and experiment with the `*` syntax.
#
#   * Pass a `columns` keyword argument to `pd.DataFrame`, and provide labels for the temperature and coordinate data.

# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd

# import api_key from config file
from config import api_key

# %%
# Create a settings object with your API key and preferred units
settings = {"units": "metric", "appid": api_key}

# %%
# Get data for each city in cities.csv
city_data = pd.read_csv("Resources/cities.csv", header=None)

city_names = city_data[0].tolist()
city_names

city_temp = []

for city in city_names:
    current_weather = owm.get_current(city, **settings)
    #print(f"Current weather object for {city}: {current_weather}.")
    city_temp.append(current_weather)

print(city_temp)
# Out:
# [{'coord': {'lon': 2.35, 'lat': 48.86}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 18.74, 'pressure': 1014, 'humidity': 88, 'temp_min': 17, 'temp_max': 21}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1527388200, 'sys': {'type': 1, 'id': 5610, 'message': 0.0041, 'country': 'FR', 'sunrise': 1527393336, 'sunset': 1527450036}, 'id': 2988507, 'name': 'Paris', 'cod': 200}, {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 14.66, 'pressure': 1016, 'humidity': 82, 'temp_min': 12, 'temp_max': 17}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 60}, 'clouds': {'all': 56}, 'dt': 1527389400, 'sys': {'type': 1, 'id': 5091, 'message': 0.0073, 'country': 'GB', 'sunrise': 1527393212, 'sunset': 1527451356}, 'id': 2643743, 'name': 'London', 'cod': 200}, {'coord': {'lon': 10.74, 'lat': 59.91}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 14, 'pressure': 1028, 'humidity': 71, 'temp_min': 14, 'temp_max': 14}, 'wind': {'speed': 1}, 'clouds': {'all': 0}, 'dt': 1527391200, 'sys': {'type': 1, 'id': 5325, 'message': 0.0038, 'country': 'NO', 'sunrise': 1527387317, 'sunset': 1527452072}, 'id': 3143244, 'name': 'Oslo', 'cod': 200}, {'coord': {'lon': 116.39, 'lat': 39.91}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 31, 'pressure': 1008, 'humidity': 20, 'temp_min': 31, 'temp_max': 31}, 'visibility': 10000, 'wind': {'speed': 2}, 'clouds': {'all': 0}, 'dt': 1527390000, 'sys': {'type': 1, 'id': 7405, 'message': 0.0053, 'country': 'CN', 'sunrise': 1527367839, 'sunset': 1527420775}, 'id': 1816670, 'name': 'Beijing', 'cod': 200}, {'coord': {'lon': 37.62, 'lat': 55.75}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 10.33, 'pressure': 1029, 'humidity': 66, 'temp_min': 10, 'temp_max': 11}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1527388200, 'sys': {'type': 1, 'id': 7323, 'message': 0.0037, 'country': 'RU', 'sunrise': 1527382754, 'sunset': 1527443707}, 'id': 524901, 'name': 'Moscow', 'cod': 200}, {'coord': {'lon': 131.89, 'lat': 43.12}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 15, 'pressure': 1011, 'humidity': 58, 'temp_min': 15, 'temp_max': 15}, 'visibility': 10000, 'wind': {'speed': 5, 'deg': 180}, 'clouds': {'all': 40}, 'dt': 1527390000, 'sys': {'type': 1, 'id': 7251, 'message': 0.0033, 'country': 'RU', 'sunrise': 1527363531, 'sunset': 1527417647}, 'id': 2013348, 'name': 'Vladivostok', 'cod': 200}, {'coord': {'lon': 135.5, 'lat': 34.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 24.47, 'pressure': 1011, 'humidity': 36, 'temp_min': 21, 'temp_max': 27}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1527390000, 'sys': {'type': 1, 'id': 7583, 'message': 0.0051, 'country': 'JP', 'sunrise': 1527364086, 'sunset': 1527415350}, 'id': 1853909, 'name': 'Osaka', 'cod': 200}, {'coord': {'lon': -157.86, 'lat': 21.3}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 25.99, 'pressure': 1016, 'humidity': 57, 'temp_min': 24, 'temp_max': 27}, 'visibility': 16093, 'wind': {'speed': 10.8, 'deg': 80, 'gust': 12.3}, 'clouds': {'all': 75}, 'dt': 1527389820, 'sys': {'type': 1, 'id': 819, 'message': 0.0039, 'country': 'US', 'sunrise': 1527436177, 'sunset': 1527484073}, 'id': 5856195, 'name': 'Honolulu', 'cod': 200}, {'coord': {'lon': -95.72, 'lat': 44.94}, 'weather': [{'id': 800, 'main': 'Clear', 'des ...

# %%
# Create an "extracts" object to get the temperature, latitude,
# and longitude in each city
summary = ["name", "main.temp", "coord.lat"]
for city in city_temp:
data = city_temp[0](*summary)
print(f"The current weather summary for Paris is: {data}.")
# Create a Pandas DataFrame with the results
# Out:
# The current weather summary for Paris is: ('Paris', 18.74, 48.86).

# %%
# BONUS:

# %% [markdown]
# # Instructor Turn Activity 11 World Bank

# %%
# Dependencies
import requests

url = "http://api.worldbank.org/v2/"
format = "json"

# Get country information in JSON format
countries_response = requests.get(f"{url}countries?format={format}").json()
print(countries_response)
# First element is general information, second is countries themselves
countries = countries_response[1]
# Out:
# [{'page': 1, 'pages': 7, 'per_page': '50', 'total': 304}, [{'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}, {'id': 'AFG', 'iso2Code': 'AF', 'name': 'Afghanistan', 'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'}, 'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}, 'capitalCity': 'Kabul', 'longitude': '69.1761', 'latitude': '34.5228'}, {'id': 'AFR', 'iso2Code': 'A9', 'name': 'Africa', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AGO', 'iso2Code': 'AO', 'name': 'Angola', 'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}, 'adminregion': {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-Saharan Africa (excluding high income)'}, 'incomeLevel': {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lower middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Luanda', 'longitude': '13.242', 'latitude': '-8.81155'}, {'id': 'ALB', 'iso2Code': 'AL', 'name': 'Albania', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': 'ECA', 'iso2code': '7E', 'value': 'Europe & Central Asia (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Tirane', 'longitude': '19.8172', 'latitude': '41.3317'}, {'id': 'AND', 'iso2Code': 'AD', 'name': 'Andorra', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Andorra la Vella', 'longitude': '1.5218', 'latitude': '42.5075'}, {'id': 'ANR', 'iso2Code': 'L5', 'name': 'Andean Region', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'ARB', 'iso2Code': '1A', 'name': 'Arab World', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'ARE', 'iso2Code': 'AE', 'name': 'United Arab Emirates', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East & North Africa'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Abu Dhabi', 'longitude': '54.3705', 'latitude': '24.4764'}, {'id': 'ARG', 'iso2Code': 'AR', 'name': 'Argentina', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Latin America & Caribbean (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'U ...

# %%
# Report the names
for country in countries:
    print(country["name"])
# Out:
# Aruba
# Afghanistan
# Africa
# Angola
# Albania
# Andorra
# Andean Region
# Arab World
# United Arab Emirates
# Argentina
# Armenia
# American Samoa
# Antigua and Barbuda
# Australia
# Austria
# Azerbaijan
# Burundi
# East Asia & Pacific (IBRD-only countries)
# Europe & Central Asia (IBRD-only countries)
# Belgium
# Benin
# Burkina Faso
# Bangladesh
# Bulgaria
# IBRD countries classified as high income
# Bahrain
# Bahamas, The
# Bosnia and Herzegovina
# Latin America & the Caribbean (IBRD-only countries)
# Belarus
# Belize
# Middle East & North Africa (IBRD-only countries)
# Bermuda
# Bolivia
# Brazil
# Barbados
# Brunei Darussalam
# Sub-Saharan Africa (IBRD-only countries)
# Bhutan
# Botswana
# Sub-Saharan Africa (IFC classification)
# Central African Republic
# Canada
# East Asia and the Pacific (IFC classification)
# Central Europe and the Baltics
# Europe and Central Asia (IFC classification)
# Switzerland
# Channel Islands
# Chile
# China

# %% [markdown]
# # Students Turn Activity 11 Lending Types
#
# This activity provides an opportunity to practice making two API calls in sequence in which the second API call depends on the response of the first.
#
# ## Instructions
#
# * Retrieve a list of the lending types the world bank keeps track of, and extract the ID key from each of them.
#
# * Next, determine how many countries are categorized under each lending type. Use a dict to store this information.
#
#   * This data is stored as the first element of the response array.
#
# * Finally, print the number of countries of each lending type.

# %%
# Dependencies
import requests

url = "http://api.worldbank.org/v2/"
format = "json"

# %%
# Get the list of lending types the world bank has
# CODE HERE 
lending_types = requests.get(f"{url}lendingTypes?format={format}").json()
types = lending_types[1]

for type in types:
    print(type["value"])
# Out:
# IBRD
# Blend
# IDA
# Not classified

# %%
# Next, determine how many countries fall into each lending type.
# Hint: Look at the first element of the response array.
# CODE HERE
IBRD = []
Blend = []
IDA = []
Not_classified = []
#print(countries)
for country in countries:
    if country["lendingType"]["value"] == "IBRD":
        IBRD.append(country["name"])
    elif country["lendingType"]["value"] == "Blend":
        Blend.append(country["name"])
    elif country["lendingType"]["value"] == "IDA":
        IDA.append(country["name"])
    else:
        Not_classified.append(country["name"])        
print(IBRD, Blend, IDA, Not_classified)
# Out:
# ['Angola', 'Albania', 'Argentina', 'Armenia', 'Antigua and Barbuda', 'Azerbaijan', 'Bulgaria', 'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Botswana', 'Chile', 'China'] [] ['Afghanistan', 'Burundi', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bhutan', 'Central African Republic'] ['Aruba', 'Africa', 'Andorra', 'Andean Region', 'Arab World', 'United Arab Emirates', 'American Samoa', 'Australia', 'Austria', 'East Asia & Pacific (IBRD-only countries)', 'Europe & Central Asia (IBRD-only countries)', 'Belgium', 'IBRD countries classified as high income', 'Bahrain', 'Bahamas, The', 'Latin America & the Caribbean (IBRD-only countries)', 'Middle East & North Africa (IBRD-only countries)', 'Bermuda', 'Barbados', 'Brunei Darussalam', 'Sub-Saharan Africa (IBRD-only countries)', 'Sub-Saharan Africa (IFC classification)', 'Canada', 'East Asia and the Pacific (IFC classification)', 'Central Europe and the Baltics', 'Europe and Central Asia (IFC classification)', 'Switzerland', 'Channel Islands']

# %%
# Print the number of countries of each lending type
# CODE HERE

# %% [markdown]
# # Instructor Turn 12 Activity CityPy

# %%
# !pip install openweathermapy
# Out:
# Requirement already satisfied: openweathermapy in c:\users\laura\anaconda3.1\lib\site-packages
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-177-965abd0981cf> in <module>()
#       1 # Dependencies
# ----> 2 from citipy import citipy
#
# ModuleNotFoundError: No module named 'citipy'

# %%
# Some random coordinates
coordinates = [(200, 200), (23, 200), (42, 100)]

# %%
cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))

# %%
for city in cities:
    country_code = city.country_code
    name = city.city_name
    print(f"The country code of {name} is '{country_code}'.")
