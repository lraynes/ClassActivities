# %% [markdown]
# # Instructor Turn Get Home Tweets

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\laura\anaconda3.1\lib\site-packages
# Requirement already satisfied: six>=1.10.0 in c:\users\laura\anaconda3.1\lib\site-packages (from tweepy)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\laura\anaconda3.1\lib\site-packages (from tweepy)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\laura\anaconda3.1\lib\site-packages (from tweepy)
# Requirement already satisfied: requests>=2.11.1 in c:\users\laura\anaconda3.1\lib\site-packages (from tweepy)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\users\laura\anaconda3.1\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=2.11.1->tweepy)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=2.11.1->tweepy)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=2.11.1->tweepy)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laura\anaconda3.1\lib\site-packages (from requests>=2.11.1->tweepy)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies
import json
import tweepy

# %%
# Import Twitter API Keys
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Get all tweets from home feed
public_tweets = api.home_timeline()

# %%
# Loop through all tweets
for tweet in public_tweets:
    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 16:27:16 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/moments/1002\u2026",
#                 "expanded_url": "https://twitter.com/i/moments/1002910694038228992",
#                 "indices": [
#                     19,
#                     42
#                 ],
#                 "url": "https://t.co/YAUADfQgGH"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 74,
#     "favorited": false,
#     "geo": null,
#     "id": 1002949782233604097,
#     "id_str": "1002949782233604097",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 7,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "I...just...what?\n\n https://t.co/YAUADfQgGH",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Jul 24 00:50:01 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Author of the children's book \"Piggy and Pug.\" Rescue pet advocate, wife, mom, dad joke aficionado.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "piggyandpug.com",
#                         "expanded_url": "http://piggyandpug.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6erOXpzbMl"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5771,
#         "follow_request_sent": false,
#         "followers_count": 102448,
#         "following": true,
#         "friends_count": 390,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 341218443,
#         "id_str": "341218443",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1869,
#         "location": "Los Angeles",
#         "name": "Anne Wheaton",
#         "notifications": false,
#         "profile_background_color": "022330",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/341218443/1520786861",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "A8C7F7",
#         "profile_sidebar_fill_color": "C0DFEC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AnneWheaton",
#         "statuses_count": 74690,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6erOXpzbMl",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 16:01:55 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002943400226668544",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/AeQiBVg8yy"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 2425,
#     "favorited": false,
#     "geo": null,
#     "id": 1002943400226668544,
#     "id_str": "1002943400226668544",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 219,
#     "retweeted": false,
#     "source": "<a href=\"http://www.echofon.com/\" rel=\"nofollow\">Echofon</a>",
#     "text": "has anyone been to a US airport recently? apparently they are all just bars now...like the whole airport is just an\u2026 https://t.co/AeQiBVg8yy",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Nov 18 21:09:29 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "NJ ColdCore\u2122 / NJ CoatCore\u2122 unkillable. The New EP 'Keep The Coffins Coming' Out Now. https://t.co/nbfLC61wJ1",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "smarturl.it/KTCC",
#                         "expanded_url": "http://smarturl.it/KTCC",
#                         "indices": [
#                             86,
#                             109
#                         ],
#                         "url": "https://t.co/nbfLC61wJ1"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "frank-iero.com",
#                         "expanded_url": "http://www.frank-iero.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/cFWWmRzggL"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 3826,
#         "follow_request_sent": false,
#         "followers_count": 664434,
#         "following": true,
#         "friends_count": 602,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 17471554,
#         "id_str": "17471554",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 4700,
#         "location": "NJ",
#         "name": "frnkiero: Party Dad",
#         "notifications": false,
#         "profile_background_color": "1A1B1F",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/17471554/1506060767",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/911110956419186688/Rz1E1CkR_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/911110956419186688/Rz1E1CkR_normal.jpg",
#         "profile_link_color": "1366AA",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "252429",
#         "profile_text_color": "666666",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "FrankIero",
#         "statuses_count": 9633,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/cFWWmRzggL",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:41:26 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/EROe479PRt",
#                 "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                 "id": 1002920789883179008,
#                 "id_str": "1002920789883179008",
#                 "indices": [
#                     21,
#                     44
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "medium": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002920791690895360,
#                 "source_status_id_str": "1002920791690895360",
#                 "source_user_id": 2896099018,
#                 "source_user_id_str": "2896099018",
#                 "type": "photo",
#                 "url": "https://t.co/EROe479PRt"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2896099018,
#                 "id_str": "2896099018",
#                 "indices": [
#                     3,
#                     13
#                 ],
#                 "name": "Awwwww",
#                 "screen_name": "AwwwwCats"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/EROe479PRt",
#                 "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                 "id": 1002920789883179008,
#                 "id_str": "1002920789883179008",
#                 "indices": [
#                     21,
#                     44
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "medium": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002920791690895360,
#                 "source_status_id_str": "1002920791690895360",
#                 "source_user_id": 2896099018,
#                 "source_user_id_str": "2896099018",
#                 "type": "photo",
#                 "url": "https://t.co/EROe479PRt"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002923148268847104,
#     "id_str": "1002923148268847104",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 120,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 14:32:04 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/EROe479PRt",
#                     "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                     "id": 1002920789883179008,
#                     "id_str": "1002920789883179008",
#                     "indices": [
#                         6,
#                         29
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "medium": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "small": {
#                             "h": 680,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/EROe479PRt"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/EROe479PRt",
#                     "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                     "id": 1002920789883179008,
#                     "id_str": "1002920789883179008",
#                     "indices": [
#                         6,
#                         29
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "medium": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "small": {
#                             "h": 680,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/EROe479PRt"
#                 }
#             ]
#         },
#         "favorite_count": 549,
#         "favorited": false,
#         "geo": null,
#         "id": 1002920791690895360,
#         "id_str": "1002920791690895360",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "und",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 120,
#         "retweeted": false,
#         "source": "<a href=\"http://cutecatphotohelper.com\" rel=\"nofollow\">cutecatphotohelper</a>",
#         "text": "\u2764\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c https://t.co/EROe479PRt",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Nov 28 15:40:42 +0000 2014",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Adorable photos from all around the world (in their original context).",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "awwwcats.com",
#                             "expanded_url": "http://awwwcats.com/",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/C2S479Yqii"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 20762,
#             "follow_request_sent": false,
#             "followers_count": 106255,
#             "following": false,
#             "friends_count": 23846,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 2896099018,
#             "id_str": "2896099018",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 647,
#             "location": "",
#             "name": "Awwwww",
#             "notifications": false,
#             "profile_background_color": "D22930",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2896099018/1417383043",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/538460485985632256/cQalWnL5_normal.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/538460485985632256/cQalWnL5_normal.jpeg",
#             "profile_link_color": "4A913C",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AwwwwCats",
#             "statuses_count": 17747,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/C2S479Yqii",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AwwwwCats: \u2764\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c https://t.co/EROe479PRt",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 11 02:59:07 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Proud: Husband|Canadian|Nerd|Cat Dad|Member of #TeamRegulars|Transmasculine (he/him)|Ace \ud83c\udf31| \u2764\ufe0f\ud83e\udde1\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c\ud83d\udda4\ud83d\udc96 Sloth Obsessed Tea Addict",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 13336,
#         "follow_request_sent": false,
#         "followers_count": 325,
#         "following": true,
#         "friends_count": 573,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 23711617,
#         "id_str": "23711617",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 7,
#         "location": "Canada",
#         "name": "Logan \ud83d\udc99\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23711617/1526610850",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_link_color": "ABB8C2",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "Logan0291",
#         "statuses_count": 4560,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:40:31 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 101129043,
#                 "id_str": "101129043",
#                 "indices": [
#                     3,
#                     14
#                 ],
#                 "name": "Ash Hardell",
#                 "screen_name": "AshHardell"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002922915765993474,
#     "id_str": "1002922915765993474",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 33,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 00:34:38 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1002710042829905920",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/8fdvoIBnmq"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 449,
#         "favorited": false,
#         "geo": null,
#         "id": 1002710042829905920,
#         "id_str": "1002710042829905920",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 33,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "text": "A quarter of a million views IN TWO DAYS?! Are Ace people so starved for representation they shared this video WITH\u2026 https://t.co/8fdvoIBnmq",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sat Jan 02 03:53:01 +0000 2010",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Queer. Youtuber. Author. Wifey. Pronoun indifferent.",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "youtube.com/user/HeyThere0\u2026",
#                             "expanded_url": "http://www.youtube.com/user/HeyThere005?feature=mhee",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/ivRXDUO1Zr"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 16103,
#             "follow_request_sent": false,
#             "followers_count": 55930,
#             "following": false,
#             "friends_count": 1365,
#             "geo_enabled": true,
#             "has_extended_profile": false,
#             "id": 101129043,
#             "id_str": "101129043",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 307,
#             "location": "Minneapolis",
#             "name": "Ash Hardell",
#             "notifications": false,
#             "profile_background_color": "022330",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/101129043/1493758375",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/859481638966882306/ecmGX17y_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/859481638966882306/ecmGX17y_normal.jpg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "A8C7F7",
#             "profile_sidebar_fill_color": "C0DFEC",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AshHardell",
#             "statuses_count": 32059,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/ivRXDUO1Zr",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AshHardell: A quarter of a million views IN TWO DAYS?! Are Ace people so starved for representation they shared this video WITH EVERYON\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 11 02:59:07 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Proud: Husband|Canadian|Nerd|Cat Dad|Member of #TeamRegulars|Transmasculine (he/him)|Ace \ud83c\udf31| \u2764\ufe0f\ud83e\udde1\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c\ud83d\udda4\ud83d\udc96 Sloth Obsessed Tea Addict",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 13336,
#         "follow_request_sent": false,
#         "followers_count": 325,
#         "following": true,
#         "friends_count": 573,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 23711617,
#         "id_str": "23711617",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 7,
#         "location": "Canada",
#         "name": "Logan \ud83d\udc99\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23711617/1526610850",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_link_color": "ABB8C2",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "Logan0291",
#         "statuses_count": 4560,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:17:33 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002917137428680704",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/0xXQDK9YbJ"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 2282232272,
#                 "id_str": "2282232272",
#                 "indices": [
#                     25,
#                     36
#                 ],
#                 "name": "BookCon",
#                 "screen_name": "thebookcon"
#             }
#         ]
#     },
#     "favorite_count": 151,
#     "favorited": false,
#     "geo": null,
#     "id": 1002917137428680704,
#     "id_str": "1002917137428680704",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 8,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "Tweety buddies attending @thebookcon! I'm at booth 1341 all day today except when I dart over to Family HQ at 3pm t\u2026 https://t.co/0xXQDK9YbJ",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Jul 24 00:50:01 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Author of the children's book \"Piggy and Pug.\" Rescue pet advocate, wife, mom, dad joke aficionado.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "piggyandpug.com",
#                         "expanded_url": "http://piggyandpug.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6erOXpzbMl"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5771,
#         "follow_request_sent": false,
#         "followers_count": 102448,
#         "following": true,
#         "friends_count": 390,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 341218443,
#         "id_str": "341218443",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1869,
#         "location": "Los Angeles",
#         "name": "Anne Wheaton",
#         "notifications": false,
#         "profile_background_color": "022330",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/341218443/1520786861",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "A8C7F7",
#         "profile_sidebar_fill_color": "C0DFEC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AnneWheaton",
#         "statuses_count": 74690,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6erOXpzbMl",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 08:51:24 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/AtdwJP0m9o",
#                 "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                 "id": 1002832314676760576,
#                 "id_str": "1002832314676760576",
#                 "indices": [
#                     16,
#                     39
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "medium": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "small": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002832353415360512,
#                 "source_status_id_str": "1002832353415360512",
#                 "source_user_id": 2262798529,
#                 "source_user_id_str": "2262798529",
#                 "type": "photo",
#                 "url": "https://t.co/AtdwJP0m9o"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2262798529,
#                 "id_str": "2262798529",
#                 "indices": [
#                     3,
#                     14
#                 ],
#                 "name": "Pretty Gifs",
#                 "screen_name": "PrettyGifs"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/AtdwJP0m9o",
#                 "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                 "id": 1002832314676760576,
#                 "id_str": "1002832314676760576",
#                 "indices": [
#                     16,
#                     39
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "medium": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "small": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002832353415360512,
#                 "source_status_id_str": "1002832353415360512",
#                 "source_user_id": 2262798529,
#                 "source_user_id_str": "2262798529",
#                 "type": "animated_gif",
#                 "url": "https://t.co/AtdwJP0m9o",
#                 "video_info": {
#                     "aspect_ratio": [
#                         135,
#                         73
#                     ],
#                     "variants": [
#                         {
#                             "bitrate": 0,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/tweet_video/DerGrU2XUAA88QT.mp4"
#                         }
#                     ]
#                 }
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002835059018256384,
#     "id_str": "1002835059018256384",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 314,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 08:40:39 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/AtdwJP0m9o",
#                     "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                     "id": 1002832314676760576,
#                     "id_str": "1002832314676760576",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "medium": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "small": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/AtdwJP0m9o"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/AtdwJP0m9o",
#                     "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                     "id": 1002832314676760576,
#                     "id_str": "1002832314676760576",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "medium": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "small": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "animated_gif",
#                     "url": "https://t.co/AtdwJP0m9o",
#                     "video_info": {
#                         "aspect_ratio": [
#                             135,
#                             73
#                         ],
#                         "variants": [
#                             {
#                                 "bitrate": 0,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/tweet_video/DerGrU2XUAA88QT.mp4"
#                             }
#                         ]
#                     }
#                 }
#             ]
#         },
#         "favorite_count": 689,
#         "favorited": false,
#         "geo": null,
#         "id": 1002832353415360512,
#         "id_str": "1002832353415360512",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "und",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 314,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "https://t.co/AtdwJP0m9o",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Dec 26 12:35:31 +0000 2013",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Pretty Anime Gifs \u2661",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/loveyou",
#                             "expanded_url": "https://twitter.com/loveyou",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/2CZ3WIHnAk"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 447,
#             "follow_request_sent": false,
#             "followers_count": 243477,
#             "following": false,
#             "friends_count": 5898,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 2262798529,
#             "id_str": "2262798529",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 23,
#             "location": "Japan",
#             "name": "Pretty Gifs",
#             "notifications": false,
#             "profile_background_color": "EFF1F1",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2262798529/1527449865",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1000823389349539840/Y_TQo0Pe_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1000823389349539840/Y_TQo0Pe_normal.jpg",
#             "profile_link_color": "FAB81E",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "PrettyGifs",
#             "statuses_count": 117,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/2CZ3WIHnAk",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "RT @PrettyGifs: https://t.co/AtdwJP0m9o",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Jun 24 16:13:55 +0000 2011",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Deep space is my dwelling place, The stars my destination.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 1213,
#         "follow_request_sent": false,
#         "followers_count": 84,
#         "following": true,
#         "friends_count": 156,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 323305575,
#         "id_str": "323305575",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 4,
#         "location": "LA (currently traveling)",
#         "name": "Tito Catnik",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/323305575/1527597395",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989470088565809152/epx0-Rln_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989470088565809152/epx0-Rln_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "TitoSilvey",
#         "statuses_count": 3469,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 08:27:05 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002828941525180416",
#                 "indices": [
#                     116,
#                     139
#                 ],
#                 "url": "https://t.co/BIAxePnSlf"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 10,
#     "favorited": false,
#     "geo": null,
#     "id": 1002828941525180416,
#     "id_str": "1002828941525180416",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 3,
#     "retweeted": false,
#     "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>",
# ...
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 02:17:59 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 195832496,
#                 "id_str": "195832496",
#                 "indices": [
#                     3,
#                     18
#                 ],
#                 "name": "andrew",
#                 "screen_name": "AndrewChamings"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002736052161863682,
#     "id_str": "1002736052161863682",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 1844,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Tue Jan 16 23:32:09 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "favorite_count": 8414,
#         "favorited": false,
#         "geo": null,
#         "id": 953409569325072384,
#         "id_str": "953409569325072384",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 1844,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "Let your date know you\u2019re cultured by taking her to the symphony and saying \u201coh okay cool they\u2019re doing it that way\u201d when the oboes kick in",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Mon Sep 27 17:48:06 +0000 2010",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "this is my final fit, my fiiiiiiiiiiiiiiinal bellyache. as seen in @theatlantic @thebolditalic @sfweekly @sfgate @drownedinsound",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "andrewwallacechamings.com",
#                             "expanded_url": "http://www.andrewwallacechamings.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/v3uQ0R8YWH"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 33890,
#             "follow_request_sent": false,
#             "followers_count": 13878,
#             "following": false,
#             "friends_count": 499,
#             "geo_enabled": false,
#             "has_extended_profile": true,
#             "id": 195832496,
#             "id_str": "195832496",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 253,
#             "location": "California, USA",
#             "name": "andrew",
#             "notifications": false,
#             "profile_background_color": "131516",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/195832496/1481406516",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/941712098572173312/kVE2Gd1B_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/941712098572173312/kVE2Gd1B_normal.jpg",
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "EFEFEF",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AndrewChamings",
#             "statuses_count": 5826,
#             "time_zone": null,
#             "translator_type": "regular",
#             "url": "https://t.co/v3uQ0R8YWH",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AndrewChamings: Let your date know you\u2019re cultured by taking her to the symphony and saying \u201coh okay cool they\u2019re doing it that way\u201d wh\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Feb 26 01:54:14 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "bass player singer person in the blink-182",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "himynameismark.com",
#                         "expanded_url": "http://www.himynameismark.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/XfsyYwLkcI"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 12932,
#         "follow_request_sent": false,
#         "followers_count": 3129730,
#         "following": true,
#         "friends_count": 582,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 21955058,
#         "id_str": "21955058",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 13643,
#         "location": "Ravenclaw",
#         "name": "snddo\u0265 \u029e\u0279\u0250\u026f",
#         "notifications": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/21955058/1480014548",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "BDDCAD",
#         "profile_sidebar_fill_color": "6FCCF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 02:17:16 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3409193855,
#                 "id_str": "3409193855",
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "name": "John Darby",
#                 "screen_name": "mrjohndarby"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002735871475380224,
#     "id_str": "1002735871475380224",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 14223,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Mon Apr 02 15:05:03 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/980823429560590337",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/cWTl8t6oVx"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 59087,
#         "favorited": false,
#         "geo": null,
#         "id": 980823429560590337,
#         "id_str": "980823429560590337",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 14223,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "text": "[my funeral service] \nmy widow: he will surely be remembered for being such a terrible liar who faked his own death\u2026 https://t.co/cWTl8t6oVx",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sat Aug 08 21:11:19 +0000 2015",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "Recent tweets: https://t.co/Lv1NCkPpoN",
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/search?q=from%\u2026",
#                             "expanded_url": "https://twitter.com/search?q=from%3Amrjohndarby%2Fexclude%3Areplies&s=09",
#                             "indices": [
#                                 15,
#                                 38
#                             ],
#                             "url": "https://t.co/Lv1NCkPpoN"
#                         }
#                     ]
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "favstar.fm/users/mrjohnda\u2026",
#                             "expanded_url": "https://favstar.fm/users/mrjohndarby",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/sMqfD9lD2K"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 43815,
#             "follow_request_sent": false,
#             "followers_count": 11376,
#             "following": false,
#             "friends_count": 1000,
#             "geo_enabled": false,
#             "has_extended_profile": true,
#             "id": 3409193855,
#             "id_str": "3409193855",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 186,
#             "location": "",
#             "name": "John Darby",
#             "notifications": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3409193855/1505007309",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/824653209935478784/7wcDOThc_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/824653209935478784/7wcDOThc_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "mrjohndarby",
#             "statuses_count": 24162,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/sMqfD9lD2K",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @mrjohndarby: [my funeral service] \nmy widow: he will surely be remembered for being such a terrible liar who faked his own death severa\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Feb 26 01:54:14 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "bass player singer person in the blink-182",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "himynameismark.com",
#                         "expanded_url": "http://www.himynameismark.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/XfsyYwLkcI"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 12932,
#         "follow_request_sent": false,
#         "followers_count": 3129730,
#         "following": true,
#         "friends_count": 582,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 21955058,
#         "id_str": "21955058",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 13643,
#         "location": "Ravenclaw",
#         "name": "snddo\u0265 \u029e\u0279\u0250\u026f",
#         "notifications": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/21955058/1480014548",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "BDDCAD",
#         "profile_sidebar_fill_color": "6FCCF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }

# %% [markdown]
# # Students Turn Activity 2
# # Get My Tweets
#
# ## Instructions
#
# * In this activity, you will retrieve the most recent tweets sent out from your Twitter account using the Tweepy library.
#
#   * Import the necessary libraries needed to talk to Twitter's API.
#
#   * Import your keys from your `config.py` file.
#
#   * Set up Tweepy authentication.
#
#   * Write code to fetch all tweets from your home feed.
#
#   * Loop through and print out tweets.
#
# ## Hint:
#
# * Consult the [Tweepy](http://docs.tweepy.org/en/v3.5.0/api.html?) documentation for the method used to accomplish this task.
#
# ## Bonus
#
# * If you finish the activity early, try tweaking the parameters. For example, can you fetch ten tweets with the script? If you haven't yet sent out more than ten tweets from your account, do that first.

# %%
# Dependencies
import tweepy
import json

# %%
# Import Twitter API Keys
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
# YOUR CODE HERE
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Get all tweets from home feed
# YOUR CODE HERE
public_tweets = api.home_timeline()

# %%
# Loop through all tweets and print a prettified JSON of each tweet
# YOUR CODE HERE
for tweet in public_tweets:
    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 16:27:16 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/moments/1002\u2026",
#                 "expanded_url": "https://twitter.com/i/moments/1002910694038228992",
#                 "indices": [
#                     19,
#                     42
#                 ],
#                 "url": "https://t.co/YAUADfQgGH"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 74,
#     "favorited": false,
#     "geo": null,
#     "id": 1002949782233604097,
#     "id_str": "1002949782233604097",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 7,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "I...just...what?\n\n https://t.co/YAUADfQgGH",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Jul 24 00:50:01 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Author of the children's book \"Piggy and Pug.\" Rescue pet advocate, wife, mom, dad joke aficionado.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "piggyandpug.com",
#                         "expanded_url": "http://piggyandpug.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6erOXpzbMl"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5771,
#         "follow_request_sent": false,
#         "followers_count": 102448,
#         "following": true,
#         "friends_count": 390,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 341218443,
#         "id_str": "341218443",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1869,
#         "location": "Los Angeles",
#         "name": "Anne Wheaton",
#         "notifications": false,
#         "profile_background_color": "022330",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/341218443/1520786861",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "A8C7F7",
#         "profile_sidebar_fill_color": "C0DFEC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AnneWheaton",
#         "statuses_count": 74690,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6erOXpzbMl",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 16:01:55 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002943400226668544",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/AeQiBVg8yy"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 2430,
#     "favorited": false,
#     "geo": null,
#     "id": 1002943400226668544,
#     "id_str": "1002943400226668544",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 219,
#     "retweeted": false,
#     "source": "<a href=\"http://www.echofon.com/\" rel=\"nofollow\">Echofon</a>",
#     "text": "has anyone been to a US airport recently? apparently they are all just bars now...like the whole airport is just an\u2026 https://t.co/AeQiBVg8yy",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Nov 18 21:09:29 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "NJ ColdCore\u2122 / NJ CoatCore\u2122 unkillable. The New EP 'Keep The Coffins Coming' Out Now. https://t.co/nbfLC61wJ1",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "smarturl.it/KTCC",
#                         "expanded_url": "http://smarturl.it/KTCC",
#                         "indices": [
#                             86,
#                             109
#                         ],
#                         "url": "https://t.co/nbfLC61wJ1"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "frank-iero.com",
#                         "expanded_url": "http://www.frank-iero.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/cFWWmRzggL"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 3826,
#         "follow_request_sent": false,
#         "followers_count": 664434,
#         "following": true,
#         "friends_count": 602,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 17471554,
#         "id_str": "17471554",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 4700,
#         "location": "NJ",
#         "name": "frnkiero: Party Dad",
#         "notifications": false,
#         "profile_background_color": "1A1B1F",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/17471554/1506060767",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/911110956419186688/Rz1E1CkR_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/911110956419186688/Rz1E1CkR_normal.jpg",
#         "profile_link_color": "1366AA",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "252429",
#         "profile_text_color": "666666",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "FrankIero",
#         "statuses_count": 9633,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/cFWWmRzggL",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:41:26 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/EROe479PRt",
#                 "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                 "id": 1002920789883179008,
#                 "id_str": "1002920789883179008",
#                 "indices": [
#                     21,
#                     44
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "medium": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002920791690895360,
#                 "source_status_id_str": "1002920791690895360",
#                 "source_user_id": 2896099018,
#                 "source_user_id_str": "2896099018",
#                 "type": "photo",
#                 "url": "https://t.co/EROe479PRt"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2896099018,
#                 "id_str": "2896099018",
#                 "indices": [
#                     3,
#                     13
#                 ],
#                 "name": "Awwwww",
#                 "screen_name": "AwwwwCats"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/EROe479PRt",
#                 "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                 "id": 1002920789883179008,
#                 "id_str": "1002920789883179008",
#                 "indices": [
#                     21,
#                     44
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "medium": {
#                         "h": 1172,
#                         "resize": "fit",
#                         "w": 1068
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 620
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002920791690895360,
#                 "source_status_id_str": "1002920791690895360",
#                 "source_user_id": 2896099018,
#                 "source_user_id_str": "2896099018",
#                 "type": "photo",
#                 "url": "https://t.co/EROe479PRt"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002923148268847104,
#     "id_str": "1002923148268847104",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 120,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 14:32:04 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/EROe479PRt",
#                     "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                     "id": 1002920789883179008,
#                     "id_str": "1002920789883179008",
#                     "indices": [
#                         6,
#                         29
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "medium": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "small": {
#                             "h": 680,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/EROe479PRt"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/EROe479PRt",
#                     "expanded_url": "https://twitter.com/AwwwwCats/status/1002920791690895360/photo/1",
#                     "id": 1002920789883179008,
#                     "id_str": "1002920789883179008",
#                     "indices": [
#                         6,
#                         29
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DesXJQrXUAAwlhS.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "medium": {
#                             "h": 1172,
#                             "resize": "fit",
#                             "w": 1068
#                         },
#                         "small": {
#                             "h": 680,
#                             "resize": "fit",
#                             "w": 620
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/EROe479PRt"
#                 }
#             ]
#         },
#         "favorite_count": 549,
#         "favorited": false,
#         "geo": null,
#         "id": 1002920791690895360,
#         "id_str": "1002920791690895360",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "und",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 120,
#         "retweeted": false,
#         "source": "<a href=\"http://cutecatphotohelper.com\" rel=\"nofollow\">cutecatphotohelper</a>",
#         "text": "\u2764\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c https://t.co/EROe479PRt",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Nov 28 15:40:42 +0000 2014",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Adorable photos from all around the world (in their original context).",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "awwwcats.com",
#                             "expanded_url": "http://awwwcats.com/",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/C2S479Yqii"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 20762,
#             "follow_request_sent": false,
#             "followers_count": 106255,
#             "following": false,
#             "friends_count": 23846,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 2896099018,
#             "id_str": "2896099018",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 647,
#             "location": "",
#             "name": "Awwwww",
#             "notifications": false,
#             "profile_background_color": "D22930",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2896099018/1417383043",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/538460485985632256/cQalWnL5_normal.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/538460485985632256/cQalWnL5_normal.jpeg",
#             "profile_link_color": "4A913C",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AwwwwCats",
#             "statuses_count": 17747,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/C2S479Yqii",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AwwwwCats: \u2764\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c https://t.co/EROe479PRt",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 11 02:59:07 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Proud: Husband|Canadian|Nerd|Cat Dad|Member of #TeamRegulars|Transmasculine (he/him)|Ace \ud83c\udf31| \u2764\ufe0f\ud83e\udde1\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c\ud83d\udda4\ud83d\udc96 Sloth Obsessed Tea Addict",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 13336,
#         "follow_request_sent": false,
#         "followers_count": 325,
#         "following": true,
#         "friends_count": 573,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 23711617,
#         "id_str": "23711617",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 7,
#         "location": "Canada",
#         "name": "Logan \ud83d\udc99\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23711617/1526610850",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_link_color": "ABB8C2",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "Logan0291",
#         "statuses_count": 4560,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:40:31 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 101129043,
#                 "id_str": "101129043",
#                 "indices": [
#                     3,
#                     14
#                 ],
#                 "name": "Ash Hardell",
#                 "screen_name": "AshHardell"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002922915765993474,
#     "id_str": "1002922915765993474",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 33,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 00:34:38 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1002710042829905920",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/8fdvoIBnmq"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 449,
#         "favorited": false,
#         "geo": null,
#         "id": 1002710042829905920,
#         "id_str": "1002710042829905920",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 33,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "text": "A quarter of a million views IN TWO DAYS?! Are Ace people so starved for representation they shared this video WITH\u2026 https://t.co/8fdvoIBnmq",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sat Jan 02 03:53:01 +0000 2010",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Queer. Youtuber. Author. Wifey. Pronoun indifferent.",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "youtube.com/user/HeyThere0\u2026",
#                             "expanded_url": "http://www.youtube.com/user/HeyThere005?feature=mhee",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/ivRXDUO1Zr"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 16103,
#             "follow_request_sent": false,
#             "followers_count": 55930,
#             "following": false,
#             "friends_count": 1365,
#             "geo_enabled": true,
#             "has_extended_profile": false,
#             "id": 101129043,
#             "id_str": "101129043",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 307,
#             "location": "Minneapolis",
#             "name": "Ash Hardell",
#             "notifications": false,
#             "profile_background_color": "022330",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/101129043/1493758375",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/859481638966882306/ecmGX17y_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/859481638966882306/ecmGX17y_normal.jpg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "A8C7F7",
#             "profile_sidebar_fill_color": "C0DFEC",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AshHardell",
#             "statuses_count": 32059,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/ivRXDUO1Zr",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AshHardell: A quarter of a million views IN TWO DAYS?! Are Ace people so starved for representation they shared this video WITH EVERYON\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Mar 11 02:59:07 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Proud: Husband|Canadian|Nerd|Cat Dad|Member of #TeamRegulars|Transmasculine (he/him)|Ace \ud83c\udf31| \u2764\ufe0f\ud83e\udde1\ud83d\udc9b\ud83d\udc9a\ud83d\udc99\ud83d\udc9c\ud83d\udda4\ud83d\udc96 Sloth Obsessed Tea Addict",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 13336,
#         "follow_request_sent": false,
#         "followers_count": 325,
#         "following": true,
#         "friends_count": 573,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 23711617,
#         "id_str": "23711617",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 7,
#         "location": "Canada",
#         "name": "Logan \ud83d\udc99\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23711617/1526610850",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/999051307141885952/QNvxOa6T_normal.jpg",
#         "profile_link_color": "ABB8C2",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "Logan0291",
#         "statuses_count": 4560,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:17:33 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002917137428680704",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/0xXQDK9YbJ"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 2282232272,
#                 "id_str": "2282232272",
#                 "indices": [
#                     25,
#                     36
#                 ],
#                 "name": "BookCon",
#                 "screen_name": "thebookcon"
#             }
#         ]
#     },
#     "favorite_count": 151,
#     "favorited": false,
#     "geo": null,
#     "id": 1002917137428680704,
#     "id_str": "1002917137428680704",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 8,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "Tweety buddies attending @thebookcon! I'm at booth 1341 all day today except when I dart over to Family HQ at 3pm t\u2026 https://t.co/0xXQDK9YbJ",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Jul 24 00:50:01 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Author of the children's book \"Piggy and Pug.\" Rescue pet advocate, wife, mom, dad joke aficionado.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "piggyandpug.com",
#                         "expanded_url": "http://piggyandpug.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6erOXpzbMl"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5771,
#         "follow_request_sent": false,
#         "followers_count": 102448,
#         "following": true,
#         "friends_count": 390,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 341218443,
#         "id_str": "341218443",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 1869,
#         "location": "Los Angeles",
#         "name": "Anne Wheaton",
#         "notifications": false,
#         "profile_background_color": "022330",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/341218443/1520786861",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/925739904490803201/DwMHW4r0_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "A8C7F7",
#         "profile_sidebar_fill_color": "C0DFEC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AnneWheaton",
#         "statuses_count": 74690,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6erOXpzbMl",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 08:51:24 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/AtdwJP0m9o",
#                 "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                 "id": 1002832314676760576,
#                 "id_str": "1002832314676760576",
#                 "indices": [
#                     16,
#                     39
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "medium": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "small": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002832353415360512,
#                 "source_status_id_str": "1002832353415360512",
#                 "source_user_id": 2262798529,
#                 "source_user_id_str": "2262798529",
#                 "type": "photo",
#                 "url": "https://t.co/AtdwJP0m9o"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2262798529,
#                 "id_str": "2262798529",
#                 "indices": [
#                     3,
#                     14
#                 ],
#                 "name": "Pretty Gifs",
#                 "screen_name": "PrettyGifs"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/AtdwJP0m9o",
#                 "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                 "id": 1002832314676760576,
#                 "id_str": "1002832314676760576",
#                 "indices": [
#                     16,
#                     39
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "medium": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "small": {
#                         "h": 292,
#                         "resize": "fit",
#                         "w": 540
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 1002832353415360512,
#                 "source_status_id_str": "1002832353415360512",
#                 "source_user_id": 2262798529,
#                 "source_user_id_str": "2262798529",
#                 "type": "animated_gif",
#                 "url": "https://t.co/AtdwJP0m9o",
#                 "video_info": {
#                     "aspect_ratio": [
#                         135,
#                         73
#                     ],
#                     "variants": [
#                         {
#                             "bitrate": 0,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/tweet_video/DerGrU2XUAA88QT.mp4"
#                         }
#                     ]
#                 }
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002835059018256384,
#     "id_str": "1002835059018256384",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 314,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 08:40:39 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/AtdwJP0m9o",
#                     "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                     "id": 1002832314676760576,
#                     "id_str": "1002832314676760576",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "medium": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "small": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/AtdwJP0m9o"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/AtdwJP0m9o",
#                     "expanded_url": "https://twitter.com/PrettyGifs/status/1002832353415360512/photo/1",
#                     "id": 1002832314676760576,
#                     "id_str": "1002832314676760576",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DerGrU2XUAA88QT.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "medium": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "small": {
#                             "h": 292,
#                             "resize": "fit",
#                             "w": 540
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "animated_gif",
#                     "url": "https://t.co/AtdwJP0m9o",
#                     "video_info": {
#                         "aspect_ratio": [
#                             135,
#                             73
#                         ],
#                         "variants": [
#                             {
#                                 "bitrate": 0,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/tweet_video/DerGrU2XUAA88QT.mp4"
#                             }
#                         ]
#                     }
#                 }
#             ]
#         },
#         "favorite_count": 689,
#         "favorited": false,
#         "geo": null,
#         "id": 1002832353415360512,
#         "id_str": "1002832353415360512",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "und",
#         "place": null,
#         "possibly_sensitive": false,
#         "possibly_sensitive_appealable": false,
#         "retweet_count": 314,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "https://t.co/AtdwJP0m9o",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Dec 26 12:35:31 +0000 2013",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Pretty Anime Gifs \u2661",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/loveyou",
#                             "expanded_url": "https://twitter.com/loveyou",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/2CZ3WIHnAk"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 447,
#             "follow_request_sent": false,
#             "followers_count": 243477,
#             "following": false,
#             "friends_count": 5898,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 2262798529,
#             "id_str": "2262798529",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 23,
#             "location": "Japan",
#             "name": "Pretty Gifs",
#             "notifications": false,
#             "profile_background_color": "EFF1F1",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2262798529/1527449865",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1000823389349539840/Y_TQo0Pe_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1000823389349539840/Y_TQo0Pe_normal.jpg",
#             "profile_link_color": "FAB81E",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "PrettyGifs",
#             "statuses_count": 117,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/2CZ3WIHnAk",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "RT @PrettyGifs: https://t.co/AtdwJP0m9o",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Jun 24 16:13:55 +0000 2011",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Deep space is my dwelling place, The stars my destination.",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 1213,
#         "follow_request_sent": false,
#         "followers_count": 84,
#         "following": true,
#         "friends_count": 156,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 323305575,
#         "id_str": "323305575",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 4,
#         "location": "LA (currently traveling)",
#         "name": "Tito Catnik",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/323305575/1527597395",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989470088565809152/epx0-Rln_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989470088565809152/epx0-Rln_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "TitoSilvey",
#         "statuses_count": 3469,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 08:27:05 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1002828941525180416",
#                 "indices": [
#                     116,
#                     139
#                 ],
#                 "url": "https://t.co/BIAxePnSlf"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 10,
#     "favorited": false,
#     "geo": null,
#     "id": 1002828941525180416,
#     "id_str": "1002828941525180416",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 3,
#     "retweeted": false,
#     "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>",
# ...
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 02:17:59 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 195832496,
#                 "id_str": "195832496",
#                 "indices": [
#                     3,
#                     18
#                 ],
#                 "name": "andrew",
#                 "screen_name": "AndrewChamings"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002736052161863682,
#     "id_str": "1002736052161863682",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 1844,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Tue Jan 16 23:32:09 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "favorite_count": 8414,
#         "favorited": false,
#         "geo": null,
#         "id": 953409569325072384,
#         "id_str": "953409569325072384",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 1844,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "Let your date know you\u2019re cultured by taking her to the symphony and saying \u201coh okay cool they\u2019re doing it that way\u201d when the oboes kick in",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Mon Sep 27 17:48:06 +0000 2010",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "this is my final fit, my fiiiiiiiiiiiiiiinal bellyache. as seen in @theatlantic @thebolditalic @sfweekly @sfgate @drownedinsound",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "andrewwallacechamings.com",
#                             "expanded_url": "http://www.andrewwallacechamings.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/v3uQ0R8YWH"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 33890,
#             "follow_request_sent": false,
#             "followers_count": 13878,
#             "following": false,
#             "friends_count": 499,
#             "geo_enabled": false,
#             "has_extended_profile": true,
#             "id": 195832496,
#             "id_str": "195832496",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 253,
#             "location": "California, USA",
#             "name": "andrew",
#             "notifications": false,
#             "profile_background_color": "131516",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/195832496/1481406516",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/941712098572173312/kVE2Gd1B_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/941712098572173312/kVE2Gd1B_normal.jpg",
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "EFEFEF",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AndrewChamings",
#             "statuses_count": 5826,
#             "time_zone": null,
#             "translator_type": "regular",
#             "url": "https://t.co/v3uQ0R8YWH",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @AndrewChamings: Let your date know you\u2019re cultured by taking her to the symphony and saying \u201coh okay cool they\u2019re doing it that way\u201d wh\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Feb 26 01:54:14 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "bass player singer person in the blink-182",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "himynameismark.com",
#                         "expanded_url": "http://www.himynameismark.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/XfsyYwLkcI"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 12932,
#         "follow_request_sent": false,
#         "followers_count": 3129730,
#         "following": true,
#         "friends_count": 582,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 21955058,
#         "id_str": "21955058",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 13643,
#         "location": "Ravenclaw",
#         "name": "snddo\u0265 \u029e\u0279\u0250\u026f",
#         "notifications": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/21955058/1480014548",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "BDDCAD",
#         "profile_sidebar_fill_color": "6FCCF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 02:17:16 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3409193855,
#                 "id_str": "3409193855",
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "name": "John Darby",
#                 "screen_name": "mrjohndarby"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1002735871475380224,
#     "id_str": "1002735871475380224",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 14223,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Mon Apr 02 15:05:03 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/980823429560590337",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/cWTl8t6oVx"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 59087,
#         "favorited": false,
#         "geo": null,
#         "id": 980823429560590337,
#         "id_str": "980823429560590337",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 14223,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "text": "[my funeral service] \nmy widow: he will surely be remembered for being such a terrible liar who faked his own death\u2026 https://t.co/cWTl8t6oVx",
#         "truncated": true,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sat Aug 08 21:11:19 +0000 2015",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "Recent tweets: https://t.co/Lv1NCkPpoN",
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/search?q=from%\u2026",
#                             "expanded_url": "https://twitter.com/search?q=from%3Amrjohndarby%2Fexclude%3Areplies&s=09",
#                             "indices": [
#                                 15,
#                                 38
#                             ],
#                             "url": "https://t.co/Lv1NCkPpoN"
#                         }
#                     ]
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "favstar.fm/users/mrjohnda\u2026",
#                             "expanded_url": "https://favstar.fm/users/mrjohndarby",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/sMqfD9lD2K"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 43815,
#             "follow_request_sent": false,
#             "followers_count": 11376,
#             "following": false,
#             "friends_count": 1000,
#             "geo_enabled": false,
#             "has_extended_profile": true,
#             "id": 3409193855,
#             "id_str": "3409193855",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 186,
#             "location": "",
#             "name": "John Darby",
#             "notifications": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3409193855/1505007309",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/824653209935478784/7wcDOThc_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/824653209935478784/7wcDOThc_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "mrjohndarby",
#             "statuses_count": 24162,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/sMqfD9lD2K",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @mrjohndarby: [my funeral service] \nmy widow: he will surely be remembered for being such a terrible liar who faked his own death severa\u2026",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Feb 26 01:54:14 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "bass player singer person in the blink-182",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "himynameismark.com",
#                         "expanded_url": "http://www.himynameismark.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/XfsyYwLkcI"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 12932,
#         "follow_request_sent": false,
#         "followers_count": 3129730,
#         "following": true,
#         "friends_count": 582,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 21955058,
#         "id_str": "21955058",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 13643,
#         "location": "Ravenclaw",
#         "name": "snddo\u0265 \u029e\u0279\u0250\u026f",
#         "notifications": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/21955058/1480014548",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/996973088863469569/stcMm5-8_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "BDDCAD",
#         "profile_sidebar_fill_color": "6FCCF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "markhoppus",
#         "statuses_count": 2947,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/XfsyYwLkcI",
#         "utc_offset": null,
#         "verified": true
#     }
# }

# %% [markdown]
# # Students Turn Activity 3
# # Get Other Tweets
#
# * In this activity, we will retrieve tweets sent out by any account of our choosing!
#
# ## Instructions
#
# * Choose a twitter account and save the screen name to a variable.
#
# * Retrieve the latest tweets sent out from that account.
#
# * Use the code from the previous activities to get you started!
#
# * Consult the [Tweepy Docs](http://docs.tweepy.org/en/v3.5.0/api.html) as needed.

# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
# CODE HERE
user_id = "hankgreen"

# %%
# Get all tweets from home feed
# CODE HERE
hank_tweets = api.user_timeline(user_id, count=5)

# %%
# Loop through all tweets
# CODE HERE
for tweet in hank_tweets:
    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 17:35:27 +0000 2018",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     72,
#                     98
#                 ],
#                 "text": "AbsolutelyRemarkableThing"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/thelindsayelli\u2026",
#                 "expanded_url": "https://twitter.com/thelindsayellis/status/1002965348520546304",
#                 "indices": [
#                     99,
#                     122
#                 ],
#                 "url": "https://t.co/sh0BBmKiA7"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 38,
#     "favorited": false,
#     "geo": null,
#     "id": 1002966942532005888,
#     "id_str": "1002966942532005888",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": true,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "quoted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 02 17:29:07 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/tQ0B2BW47a",
#                     "expanded_url": "https://twitter.com/thelindsayellis/status/1002965348520546304/photo/1",
#                     "id": 1002965340215652352,
#                     "id_str": "1002965340215652352",
#                     "indices": [
#                         38,
#                         61
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Des_qbmVMAArfKr.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/Des_qbmVMAArfKr.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1538,
#                             "resize": "fit",
#                             "w": 2048
#                         },
#                         "medium": {
#                             "h": 901,
#                             "resize": "fit",
#                             "w": 1200
#                         },
#                         "small": {
#                             "h": 511,
#                             "resize": "fit",
#                             "w": 680
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/tQ0B2BW47a"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/tQ0B2BW47a",
#                     "expanded_url": "https://twitter.com/thelindsayellis/status/1002965348520546304/photo/1",
#                     "id": 1002965340215652352,
#                     "id_str": "1002965340215652352",
#                     "indices": [
#                         38,
#                         61
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Des_qbmVMAArfKr.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/Des_qbmVMAArfKr.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 1538,
#                             "resize": "fit",
#                             "w": 2048
#                         },
#                         "medium": {
#                             "h": 901,
#                             "resize": "fit",
#                             "w": 1200
#                         },
#                         "small": {
#                             "h": 511,
#                             "resize": "fit",
#                             "w": 680
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/tQ0B2BW47a"
#                 }
#             ]
#         },
#         "favorite_count": 162,
#         "favorited": false,
#         "geo": null,
#         "id": 1002965348520546304,
#         "id_str": "1002965348520546304",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": {
#             "attributes": {},
#             "bounding_box": {
#                 "coordinates": [
#                     [
#                         [
#                             -74.026675,
#                             40.683935
#                         ],
#                         [
#                             -73.910408,
#                             40.683935
#                         ],
#                         [
#                             -73.910408,
#                             40.877483
#                         ],
#                         [
#                             -74.026675,
#                             40.877483
#                         ]
#                     ]
#                 ],
#                 "type": "Polygon"
#             },
#             "contained_within": [],
#             "country": "United States",
#             "country_code": "US",
#             "full_name": "Manhattan, NY",
#             "id": "01a9a39529b27f36",
#             "name": "Manhattan",
#             "place_type": "city",
#             "url": "https://api.twitter.com/1.1/geo/id/01a9a39529b27f36.json"
#         },
#         "possibly_sensitive": false,
#         "retweet_count": 3,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "text": "Just joshin\u2019 around with my pal here! https://t.co/tQ0B2BW47a",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Sun Dec 28 17:45:24 +0000 2008",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Transformers scholar and national embarrassment. Inquiries: namebrandlindsay@gmail.com",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "youtube.com/chezapoctube",
#                             "expanded_url": "http://youtube.com/chezapoctube",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/8bfLswuOdj"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 19768,
#             "follow_request_sent": false,
#             "followers_count": 97442,
#             "following": false,
#             "friends_count": 673,
#             "geo_enabled": true,
#             "has_extended_profile": true,
#             "id": 18430758,
#             "id_str": "18430758",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 1040,
#             "location": "Los Angeles, CA",
#             "name": "Lindsay Ellis \ud83d\udd77\ud83c\udf46",
#             "notifications": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/18430758/1488318140",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/958470624804069376/QZWomAGM_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/958470624804069376/QZWomAGM_normal.jpg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "thelindsayellis",
#             "statuses_count": 48542,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/8bfLswuOdj",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     "quoted_status_id": 1002965348520546304,
#     "quoted_status_id_str": "1002965348520546304",
#     "retweet_count": 2,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "If you're at BookCon, send me photos of you with my giant robot please! #AbsolutelyRemarkableThing https://t.co/sh0BBmKiA7",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Jul 30 20:36:34 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Crash Course, SciShow, Vlogbrothers, https://t.co/AxYpeXxCJc, VidCon, etc.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "DFTBA.com",
#                         "expanded_url": "http://DFTBA.com",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "url": "https://t.co/AxYpeXxCJc"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18880,
#         "follow_request_sent": false,
#         "followers_count": 801515,
#         "following": true,
#         "friends_count": 719,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 61592079,
#         "id_str": "61592079",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 5537,
#         "location": "Missoula, MT",
#         "name": "Hank Green",
#         "notifications": false,
#         "profile_background_color": "4DB3C8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/61592079/1520017512",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "858585",
#         "profile_sidebar_fill_color": "C0DDE0",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hankgreen",
#         "statuses_count": 25774,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:37:18 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 340644602,
#                 "id_str": "340644602",
#                 "indices": [
#                     0,
#                     10
#                 ],
#                 "name": "Stagger Lee Shot First",
#                 "screen_name": "elongreen"
#             },
#             {
#                 "id": 16043620,
#                 "id_str": "16043620",
#                 "indices": [
#                     11,
#                     26
#                 ],
#                 "name": "Kristen Arnett",
#                 "screen_name": "Kristen_Arnett"
#             }
#         ]
#     },
#     "favorite_count": 2,
#     "favorited": false,
#     "geo": null,
#     "id": 1002922107347451904,
#     "id_str": "1002922107347451904",
#     "in_reply_to_screen_name": "elongreen",
#     "in_reply_to_status_id": 1002921620225318912,
#     "in_reply_to_status_id_str": "1002921620225318912",
#     "in_reply_to_user_id": 340644602,
#     "in_reply_to_user_id_str": "340644602",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@elongreen @Kristen_Arnett Welp! Let me know if anyone is offering him gobs of money!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Jul 30 20:36:34 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Crash Course, SciShow, Vlogbrothers, https://t.co/AxYpeXxCJc, VidCon, etc.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "DFTBA.com",
#                         "expanded_url": "http://DFTBA.com",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "url": "https://t.co/AxYpeXxCJc"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18880,
#         "follow_request_sent": false,
#         "followers_count": 801515,
#         "following": true,
#         "friends_count": 719,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 61592079,
#         "id_str": "61592079",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 5537,
#         "location": "Missoula, MT",
#         "name": "Hank Green",
#         "notifications": false,
#         "profile_background_color": "4DB3C8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/61592079/1520017512",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "858585",
#         "profile_sidebar_fill_color": "C0DDE0",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hankgreen",
#         "statuses_count": 25774,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 14:34:56 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 340644602,
#                 "id_str": "340644602",
#                 "indices": [
#                     0,
#                     10
#                 ],
#                 "name": "Stagger Lee Shot First",
#                 "screen_name": "elongreen"
#             },
#             {
#                 "id": 16043620,
#                 "id_str": "16043620",
#                 "indices": [
#                     11,
#                     26
#                 ],
#                 "name": "Kristen Arnett",
#                 "screen_name": "Kristen_Arnett"
#             }
#         ]
#     },
#     "favorite_count": 2,
#     "favorited": false,
#     "geo": null,
#     "id": 1002921514088316929,
#     "id_str": "1002921514088316929",
#     "in_reply_to_screen_name": "elongreen",
#     "in_reply_to_status_id": 1002885154820575232,
#     "in_reply_to_status_id_str": "1002885154820575232",
#     "in_reply_to_user_id": 340644602,
#     "in_reply_to_user_id_str": "340644602",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@elongreen @Kristen_Arnett Hahah. What's your dad's name?",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Jul 30 20:36:34 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Crash Course, SciShow, Vlogbrothers, https://t.co/AxYpeXxCJc, VidCon, etc.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "DFTBA.com",
#                         "expanded_url": "http://DFTBA.com",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "url": "https://t.co/AxYpeXxCJc"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18880,
#         "follow_request_sent": false,
#         "followers_count": 801515,
#         "following": true,
#         "friends_count": 719,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 61592079,
#         "id_str": "61592079",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 5537,
#         "location": "Missoula, MT",
#         "name": "Hank Green",
#         "notifications": false,
#         "profile_background_color": "4DB3C8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/61592079/1520017512",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "858585",
#         "profile_sidebar_fill_color": "C0DDE0",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hankgreen",
#         "statuses_count": 25774,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 05:18:18 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 16043620,
#                 "id_str": "16043620",
#                 "indices": [
#                     0,
#                     15
#                 ],
#                 "name": "Kristen Arnett",
#                 "screen_name": "Kristen_Arnett"
#             }
#         ]
#     },
#     "favorite_count": 35,
#     "favorited": false,
#     "geo": null,
#     "id": 1002781429040730112,
#     "id_str": "1002781429040730112",
#     "in_reply_to_screen_name": "Kristen_Arnett",
#     "in_reply_to_status_id": 1002773570223788032,
#     "in_reply_to_status_id_str": "1002773570223788032",
#     "in_reply_to_user_id": 16043620,
#     "in_reply_to_user_id_str": "16043620",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@Kristen_Arnett Did you just go on a post-date crunch wrap run?!",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Jul 30 20:36:34 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Crash Course, SciShow, Vlogbrothers, https://t.co/AxYpeXxCJc, VidCon, etc.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "DFTBA.com",
#                         "expanded_url": "http://DFTBA.com",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "url": "https://t.co/AxYpeXxCJc"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18880,
#         "follow_request_sent": false,
#         "followers_count": 801515,
#         "following": true,
#         "friends_count": 719,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 61592079,
#         "id_str": "61592079",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 5537,
#         "location": "Missoula, MT",
#         "name": "Hank Green",
#         "notifications": false,
#         "profile_background_color": "4DB3C8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/61592079/1520017512",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "858585",
#         "profile_sidebar_fill_color": "C0DDE0",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hankgreen",
#         "statuses_count": 25774,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Jun 02 03:46:39 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 16043620,
#                 "id_str": "16043620",
#                 "indices": [
#                     0,
#                     15
#                 ],
#                 "name": "Kristen Arnett",
#                 "screen_name": "Kristen_Arnett"
#             }
#         ]
#     },
#     "favorite_count": 99,
#     "favorited": false,
#     "geo": null,
#     "id": 1002758367033487362,
#     "id_str": "1002758367033487362",
#     "in_reply_to_screen_name": "Kristen_Arnett",
#     "in_reply_to_status_id": 1002757329694191621,
#     "in_reply_to_status_id_str": "1002757329694191621",
#     "in_reply_to_user_id": 16043620,
#     "in_reply_to_user_id_str": "16043620",
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 2,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "@Kristen_Arnett Did you tell her that famous internet science communicator Hank Green is standing up for her?",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Jul 30 20:36:34 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Crash Course, SciShow, Vlogbrothers, https://t.co/AxYpeXxCJc, VidCon, etc.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "DFTBA.com",
#                         "expanded_url": "http://DFTBA.com",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "url": "https://t.co/AxYpeXxCJc"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18880,
#         "follow_request_sent": false,
#         "followers_count": 801515,
#         "following": true,
#         "friends_count": 719,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 61592079,
#         "id_str": "61592079",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 5537,
#         "location": "Missoula, MT",
#         "name": "Hank Green",
#         "notifications": false,
#         "profile_background_color": "4DB3C8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/61592079/1520017512",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/989665325066080257/TbXDCxBg_normal.jpg",
#         "profile_link_color": "E81C4F",
#         "profile_sidebar_border_color": "858585",
#         "profile_sidebar_fill_color": "C0DDE0",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "hankgreen",
#         "statuses_count": 25774,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": true
#     }
# }

# %% [markdown]
# # Everyone Turn Activity 4

# %%
# Dependencies
import json

# %%
# Read JSONs
sample = "./Resources/SampleX.json"

# %%
def load_json(jsonfile):
    """Load JSON from a file"""
    with open(jsonfile) as file_handle:
        return json.load(file_handle)

# %%
sample_data = load_json(sample)
print(json.dumps(sample_data[0], indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Mar 09 01:00:18 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 426802833,
#                 "id_str": "426802833",
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "name": "AP Politics",
#                 "screen_name": "AP_Politics"
#             },
#             {
#                 "id": 109377487,
#                 "id_str": "109377487",
#                 "indices": [
#                     122,
#                     130
#                 ],
#                 "name": "Lolita Baldor",
#                 "screen_name": "lbaldor"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 839641964781924400,
#     "id_str": "839641964781924353",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 36,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Wed Mar 08 23:39:33 +0000 2017",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "apne.ws/2m0yjGt",
#                     "expanded_url": "http://apne.ws/2m0yjGt",
#                     "indices": [
#                         115,
#                         138
#                     ],
#                     "url": "https://t.co/Y0WmMVL40j"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "id": 109377487,
#                     "id_str": "109377487",
#                     "indices": [
#                         105,
#                         113
#                     ],
#                     "name": "Lolita Baldor",
#                     "screen_name": "lbaldor"
#                 }
#             ]
#         },
#         "favorite_count": 14,
#         "favorited": false,
#         "geo": null,
#         "id": 839621639801274400,
#         "id_str": "839621639801274369",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 36,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Official says couple hundred Marines arrive in Syria with artillery to help with Islamic State fight, by @lbaldor \nhttps://t.co/Y0WmMVL40j",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Dec 02 18:26:10 +0000 2011",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Highlights from AP's coverage of U.S. politics and government in words, photos and video. Managed by the Washington bureau. https://t.co/lTcEv1VGoB",
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "display_url": "apne.ws/1n6XgyB",
#                             "expanded_url": "http://apne.ws/1n6XgyB",
#                             "indices": [
#                                 124,
#                                 147
#                             ],
#                             "url": "https://t.co/lTcEv1VGoB"
#                         }
#                     ]
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "apne.ws/1p2OXkb",
#                             "expanded_url": "http://apne.ws/1p2OXkb",
#                             "indices": [
#                                 0,
#                                 22
#                             ],
#                             "url": "http://t.co/fM8tZ84l8o"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 5,
#             "follow_request_sent": false,
#             "followers_count": 232562,
#             "following": false,
#             "friends_count": 618,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 426802833,
#             "id_str": "426802833",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 4051,
#             "location": "Washington, D.C.",
#             "name": "AP Politics",
#             "notifications": false,
#             "profile_background_color": "333333",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/734513135/b3be603514207db70cb0a991c26f2718.jpeg",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/734513135/b3be603514207db70cb0a991c26f2718.jpeg",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/426802833/1462395539",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1848262680/APLogo_Twitter_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1848262680/APLogo_Twitter_normal.jpg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "AP_Politics",
#             "statuses_count": 55243,
#             "time_zone": "Central Time (US & Canada)",
#             "translator_type": "none",
#             "url": "http://t.co/fM8tZ84l8o",
#             "utc_offset": -21600,
#             "verified": true
#         }
#     },
#     "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#     "text": "RT @AP_Politics: Official says couple hundred Marines arrive in Syria with artillery to help with Islamic State fight, by @lbaldor \nhttps:/\u00e2\u20ac\u00a6",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Jun 26 21:48:52 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "News from The Associated Press, and a taste of the great journalism produced by AP members and customers. Managed 24/7 by these editors: http://t.co/BibaTN49vB",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "apne.ws/J2EPJ5",
#                         "expanded_url": "http://apne.ws/J2EPJ5",
#                         "indices": [
#                             137,
#                             159
#                         ],
#                         "url": "http://t.co/BibaTN49vB"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "ap.org",
#                         "expanded_url": "http://www.ap.org",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/2QmQWtmJc7"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 10,
#         "follow_request_sent": false,
#         "followers_count": 10149654,
#         "following": false,
#         "friends_count": 7252,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 51241574,
#         "id_str": "51241574",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 85727,
#         "location": "Global",
#         "name": "The Associated Press",
#         "notifications": false,
#         "profile_background_color": "333333",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/734506342/b3be603514207db70cb0a991c26f2718.jpeg",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/734506342/b3be603514207db70cb0a991c26f2718.jpeg",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/51241574/1475250875",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/461964160838803457/8z9FImcv_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/461964160838803457/8z9FImcv_normal.png",
#         "profile_link_color": "CC3300",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "CCCCCC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AP",
#         "statuses_count": 168829,
#         "time_zone": "Eastern Time (US & Canada)",
#         "translator_type": "none",
#         "url": "http://t.co/2QmQWtmJc7",
#         "utc_offset": -18000,
#         "verified": true
#     }
# }

# %%
print("------------------------------------------------------------------")

# Using the Sample_Data provided above, write code to answer each of the
# following questions:
# Out:
# ------------------------------------------------------------------

# %%
# Question 1: What user account is the tweets in the Sample associated
# with?
user_account = sample_data[0]["user"]["name"]
print(f"User Account: {user_account}")
# Out:
# User Account: The Associated Press

# %%
# Question 2: How many followers does this account have associated with it?
follower_count = sample_data[0]["user"]["followers_count"]
print(f"Follower Count: {follower_count}")
# Out:
# Follower Count: 10149654

# %%
# Question 3: How many tweets are included in the Sample?
print(f"Tweet Count (In Sample): {len(sample_data)}")
# Out:
# Tweet Count (In Sample): 20

# %%
# Question 4: How many tweets total has this account made?
total_tweets = sample_data[0]["user"]["statuses_count"]
print(f"Tweet Count (Total): {total_tweets}")
# Out:
# Tweet Count (Total): 168829

# %%
# Question 5: What was the text in the most recent tweet?
recent_tweet = sample_data[0]["text"]
print(f"Most Recent Tweet: {recent_tweet}")
# Out:
# Most Recent Tweet: RT @AP_Politics: Official says couple hundred Marines arrive in Syria with artillery to help with Islamic State fight, by @lbaldor
# https:/â€¦

# %%
# Question 6: What was the text associated with each of the tweets
# included in this sample data?
print("All Tweets:")
for tweet in sample_data:
    print(f'{tweet["text"]}')
# Out:
# All Tweets:
# RT @AP_Politics: Official says couple hundred Marines arrive in Syria with artillery to help with Islamic State fight, by @lbaldor
# https:/â€¦
# RT @APWestRegion: Uber's self-driving cars are coming back to California streets, but don't look for them on the app right away https://t.câ€¦
# RT @APCentralRegion: #Chicago police take a page from #NYCâ€™s police playbook: Focus on building community trust. https://t.co/CbkSSIHNAp htâ€¦
# RT @APEastRegion: "Fearless Girl" statue stares down Wall Street's iconic bull, stirring conversation on #InternationalWomensDay. https://tâ€¦
# RT @AP_Politics: #APFactCheck: How accurate are the Congressional Budget Office estimates? https://t.co/CLSWguXTmN https://t.co/nsREGVQmkS
# RT @APHealthScience: More than 11,700 daily U.S. heat records were set last month, the second warmest February on record. @borenbears httpsâ€¦
# RT @APWestRegion: To meet Trump's order to hire 5,000 agents, Border Patrol considers letting some applicants skip lie-detector tests httpsâ€¦
# RT @APSouthRegion: Woman tells 911 operator her boss will kill her if she leaves the mansion where she works. https://t.co/Cq2TOQdZsE httpsâ€¦
# RT @AP_Oddities: Florida city's former website taken over by someone hosting pornographic content. https://t.co/f4rivs71Db #odd
# RT @APCentralRegion: It may take until Thanksgiving to repair a sewer line that caused a football field-sized sinkhole in Michigan. https:/â€¦
# RT @AP_Sports: From 4-0 down, Barcelona completes amazing comeback against Paris Saint-Germain with 3 goals after the 88th minute https://tâ€¦
# RT @AP_Politics: Meet White House Counsel Don McGahn, President Donald Trump's in-house guard rail. https://t.co/AM7GSpyy6E https://t.co/Kkâ€¦
# RT @APEastRegion: WATCH: FBI Director James Comey says cyber threats facing U.S. are enormous, require cooperation. Video by @ngowi. https:â€¦
# Should you trust your gut instincts? @OhioState weighs the research. (By @ConversationUS, a source of news from acaâ€¦ https://t.co/F3faisEfEr
# RT @AP_Oddities: 'Hey, look, I got a new piercing:' Ski instructor tries to jump between trees while snowboarding, impales lip. https://t.câ€¦
# AP FACT CHECK: A former inmate didn't murder his girlfriend after receiving a pardon from President Obama. https://t.co/UyzL6T260n
# Female artists in Rio de Janeiro promote women's rights through their painting and graffiti. https://t.co/PQybjQ2wgA https://t.co/0Bcw8zRkdM
# With her hands firmly planted on her waist, 'Fearless Girl' statue stares down Wall Street's iconic bull. https://t.co/DTmaDzY62M
# Heritage reduced to rubble - @AP gets first look inside Mosul museum post IS destruction. https://t.co/lLRBir27dE https://t.co/Hy18VMtw1z
# RT @APSouthRegion: More from @AP's interview with #CaseyAnthony: The Florida woman, shown now and then, in her own words on Caylee. https:/â€¦

# %%
# Question 7 (Bonus): Which of the user's tweets was most frequently
# retweeted? How many retweets were there?
top_tweet = ""
top_tweet_follower_count = 0

for tweet in sample_data:
    if(tweet["retweet_count"] > top_tweet_follower_count):
        top_tweet = tweet["text"]
        top_tweet_follower_count = tweet["retweet_count"]
print(f"Most Popular Tweet: {top_tweet}")
print(f"Number of Retweets: {top_tweet_follower_count}")
# Out:
# Most Popular Tweet: With her hands firmly planted on her waist, 'Fearless Girl' statue stares down Wall Street's iconic bull. https://t.co/DTmaDzY62M
# Number of Retweets: 466

# %% [markdown]
# # Students Activity 5
# ### Popular Users
#
# ### Instructions
#
# * In this activity, you are given an incomplete CSV file of Twitter's most popular accounts. You will use this CSV file in conjunction with Tweepy's API to create a pandas DataFrame.
#
# * Consult the Jupyter Notebook file for instructions, but here are your tasks:
#
#   * The "PopularAccounts.csv" file has columns whose info needs to be filled in.
#
#   * Import the CSV into a pandas DataFrame.
#
#   * Iterate over the rows and use Tweepy to retrieve the info for the missing columns.  Add the information to the DataFrame.
#
#   * Export the results to a new CSV file called "PopularAccounts_New.csv"
#
#   * Calculate the averages of each column and create a DataFrame of the averages.
#
# ### Hints:
#
# * Make sure to use the appropriate method from the [Tweepy Docs](http://docs.tweepy.org/en/v3.5.0/api.html)
#
# * You may have to use try/except to avoid missing users.

# %%
# Import Dependencies
import tweepy
import json
import pandas as pd
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Import CSV file into Data Frame
twitter_acct = pd.read_csv("Resources/PopularAccounts.csv", dtype=str)
twitter_acct.head()
# Out:
#      Screen Name Real Name Tweets Followers Following Favorites Count
# 0      katyperry       NaN    NaN       NaN       NaN             NaN
# 1   justinbieber       NaN    NaN       NaN       NaN             NaN
# 2    BarackObama       NaN    NaN       NaN       NaN             NaN
# 3  Taylorswift13       NaN    NaN       NaN       NaN             NaN
# 4        rihanna       NaN    NaN       NaN       NaN             NaN

# %%
# Iterate through DataFrame
for index, row in twitter_acct.iterrows():
    #try: 
    user_id = row["Screen Name"]
    tweets = api.get_user(user_id)

    real_name = tweets["name"]
    total_tweets = tweets["statuses_count"]
    follower_count = tweets["followers_count"]
    following = tweets["friends_count"]
    favorites_count = tweets["favourites_count"]

    twitter_acct.at[index, "Real Name"] = real_name
    twitter_acct.at[index, "Tweets"] = total_tweets
    twitter_acct.at[index, "Followers"] = follower_count
    twitter_acct.at[index, "Following"] = following
    twitter_acct.at[index, "Favorites Count"] = favorites_count
    #except:
        #print(N/A) this is wrong
twitter_acct.head()
# Out:
#      Screen Name      Real Name Tweets  Followers Following Favorites Count
# 0      katyperry     KATY PERRY   9210  109504578       216            6204
# 1   justinbieber  Justin Bieber  30595  106444785    312222            3424
# 2    BarackObama   Barack Obama  15515  102828653    621882              11
# 3  Taylorswift13   Taylor Swift     99   85561136         0             453
# 4        rihanna        Rihanna  10129   88454902      1110            1020

# %%
# Export the new CSV


# View the DataFrame

# %%
# Calculate Averages
average_tweets = twitter_acct["Tweets"].mean()
print(f"Average tweets: {average_tweets}")
average_followers = twitter_acct["Followers"].mean()
average_following = twitter_acct["Following"].mean()
average_fav = twitter_acct["Favorites Count"].mean()

# Create DataFrame
new_dict = {
    "Average Followers": [average_followers],
    "Average Following": [average_following],
    "Average Favorites": [average_fav],
    "Average Tweet Count": [average_fav]
}

# Create a Dataframe of hte averages
new_df = pd.DataFrame(new_dict)
new_df
# Out:
# Average tweets: 32233.36
#    Average Favorites  Average Followers  Average Following  \
# 0             1832.1        50207998.06           31794.74
#
#    Average Tweet Count
# 0               1832.1

# %% [markdown]
# # Students Turn Activity 6
# # Plot Popular Accounts
#
# ## Instructions
#
# * In this activity, you will use MatPlotLib to render three scatterplot charts of the results from the last activity.
#
# 1. The first scatterplot will plot Tweet Counts (x-axis) vs Follower Counts (y-axis) to determine a relationship, if any, between the two sets of values. It should look like this:
#
# ![Tweet Counts vs Follower Counts](1.png)
#
# 2. Likewise, build a scatterplot for Number Following (x-axis) vs Follower Counts (y-axis).
#
# 3. Finally, build a scatterplot for Number of Favorites (x-axis) vs Follower Counts (y-axis).

# %%
# Dependencies
import tweepy
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication

# %%
# Import CSV file into Data Frame
popular_tweeters = pd.read_csv("./Resources/PopularAccounts.csv", dtype=str)

# Iterate through DataFrame
twitter_acct.head()
    
# Export the new CSV

# View the DataFrame
# Out:
#      Screen Name      Real Name Tweets  Followers Following Favorites Count
# 0      katyperry     KATY PERRY   9210  109504578       216            6204
# 1   justinbieber  Justin Bieber  30595  106444785    312222            3424
# 2    BarackObama   Barack Obama  15515  102828653    621882              11
# 3  Taylorswift13   Taylor Swift     99   85561136         0             453
# 4        rihanna        Rihanna  10129   88454902      1110            1020

# %%
# Calculate Averages


# Create DataFrame

# Create a Dataframe of hte averages

# %%
# Extract Tweet Counts and Follower Counts
tweet_follower = twitter_acct[["Tweets", "Followers"]]
# Easy preview of headers
tweet_follower.head()
# Out:
#   Tweets  Followers
# 0   9210  109504578
# 1  30595  106444785
# 2  15515  102828653
# 3     99   85561136
# 4  10129   88454902

# %%
# Tweet Counts vs Follower Counts 
plt.scatter(twitter_acct["Tweets"], twitter_acct["Followers"])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Number Following vs Follower Counts
plt.scatter(twitter_acct["Following"], twitter_acct["Followers"])

plt.title("Following vs Follower")
plt.xlabel("Following")
plt.ylabel("Follower")

plt.show()

# %%
# Number of Favorites vs Follower Counts
plt.scatter(twitter_acct["Favorites Count"], twitter_acct["Followers"])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Instructors Turn Activity 7 Pagination

# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = "GuardianData"

# Tweet Texts
tweet_texts = []

# Get all tweets from home feed
public_tweets = api.user_timeline(target_user)

# Loop through all tweets
for tweet in public_tweets:

    # Print Tweet
    print(tweet["text"])

    # Store Tweet in Array
    tweet_texts.append(tweet["text"])
# Out:
# Ucas criticised over fraud screening of black applicants https://t.co/OCyfSemOlF
# How Facebook is influencing the Irish abortion referendum https://t.co/TDqdsrFr21
# One in four Oxford colleges failed to admit a single black British student each year between 2015 and 2017 https://t.co/bjiLU0MV1D
# Swimming pools, servants' quarters and a beach...What lies beneath: the subterranean secrets of London's super-rich https://t.co/yPni6FP2pu
# Why is violent crime on the rise – and who is most at risk? https://t.co/zVKVN5WiCg https://t.co/v3m5C01u58
# The UK gender pay gap: what we have learned and how to fix it https://t.co/ARe4CnBxMF @niko_tinius @caelainnbarr… https://t.co/z5mZQfgupR
# Eight out of 10 companies and public sector bodies in the UK pay men more than women https://t.co/m43IlZ9c2o https://t.co/e4mSdkoMWh
# When will your company effectively stop paying women in 2018? Explore the #genderpaygap in our interactive calendar… https://t.co/ryIYbXMT1C
# University vice-chancellors are paid far more than public sector peers https://t.co/0esFPW4vlw @RichardA… https://t.co/d9mpC6Zjtv
# Hundreds of mental health patients dying after NHS care failures #ddj https://t.co/6dGVFnQ6xK
# What is the gender pay gap and what do the figures mean? https://t.co/Mu0jJoT0t0
# Gender pay gap: what we learned this week https://t.co/ZllTjSfMpu
# Jacob Rees-Mogg and the shadowy group of Tories shaping Brexit https://t.co/MvHGDSMRpm
# We're hiring a data journalist - come work with us on the data projects team! https://t.co/oDxZb4sZxf
# Interested in data journalism? Apply for work experience on the data projects team - closing date December 17th https://t.co/DPz7f5SgRM #ddj
# UK universities accused of complacency over sexual misconduct https://t.co/v7298shbKp
# Perception gap: survey reveals how we overestimate the bad stuff. Take the test and see how you fare.… https://t.co/7004Rz7vmx
# How Scotland reduced knife deaths among young people https://t.co/2h6p5VtYUD
# Children in poor areas exposed to five times as many fast food takeaways https://t.co/J6iCNjQRJD
# Beyond the Blade: our search for data exposed the poverty of the knife crime debate https://t.co/1bfU7rt1k5

# %%
# Print the Tweet Count
print(f"Tweet Count: {len(tweet_texts)}")
# Out:
# Tweet Count: 20

# %%
# With pagination

# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = "GuardianData"

# Tweet Texts
tweet_texts = []

# Create a loop to iteratively run API requests
for x in range(1, 11):

    # Get all tweets from home feed (for each page specified)
    public_tweets = api.user_timeline(target_user, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Print Tweet
        print(tweet["text"])

        # Store Tweet in Array
        tweet_texts.append(tweet["text"])
# Out:
# Ucas criticised over fraud screening of black applicants https://t.co/OCyfSemOlF
# How Facebook is influencing the Irish abortion referendum https://t.co/TDqdsrFr21
# One in four Oxford colleges failed to admit a single black British student each year between 2015 and 2017 https://t.co/bjiLU0MV1D
# Swimming pools, servants' quarters and a beach...What lies beneath: the subterranean secrets of London's super-rich https://t.co/yPni6FP2pu
# Why is violent crime on the rise – and who is most at risk? https://t.co/zVKVN5WiCg https://t.co/v3m5C01u58
# The UK gender pay gap: what we have learned and how to fix it https://t.co/ARe4CnBxMF @niko_tinius @caelainnbarr… https://t.co/z5mZQfgupR
# Eight out of 10 companies and public sector bodies in the UK pay men more than women https://t.co/m43IlZ9c2o https://t.co/e4mSdkoMWh
# When will your company effectively stop paying women in 2018? Explore the #genderpaygap in our interactive calendar… https://t.co/ryIYbXMT1C
# University vice-chancellors are paid far more than public sector peers https://t.co/0esFPW4vlw @RichardA… https://t.co/d9mpC6Zjtv
# Hundreds of mental health patients dying after NHS care failures #ddj https://t.co/6dGVFnQ6xK
# What is the gender pay gap and what do the figures mean? https://t.co/Mu0jJoT0t0
# Gender pay gap: what we learned this week https://t.co/ZllTjSfMpu
# Jacob Rees-Mogg and the shadowy group of Tories shaping Brexit https://t.co/MvHGDSMRpm
# We're hiring a data journalist - come work with us on the data projects team! https://t.co/oDxZb4sZxf
# Interested in data journalism? Apply for work experience on the data projects team - closing date December 17th https://t.co/DPz7f5SgRM #ddj
# UK universities accused of complacency over sexual misconduct https://t.co/v7298shbKp
# Perception gap: survey reveals how we overestimate the bad stuff. Take the test and see how you fare.… https://t.co/7004Rz7vmx
# How Scotland reduced knife deaths among young people https://t.co/2h6p5VtYUD
# Children in poor areas exposed to five times as many fast food takeaways https://t.co/J6iCNjQRJD
# Beyond the Blade: our search for data exposed the poverty of the knife crime debate https://t.co/1bfU7rt1k5
# Child knife deaths in England and Wales set for nine-year peak data obtained by the Guardian shows https://t.co/dLpVkLzTm2
# British Library project discovers two new words – thanks to Guardian readers https://t.co/6rpAifq23Y
# Russian 'troll army' tweets cited more than 80 times in UK media #ddj https://t.co/WAdGT4fGxZ
# @duncan3ross We will in the v near future. In the meantime the data was released under FOI and should be available… https://t.co/c5TAbU21ul
# Brexit vote creates surge in  EU citizenship applications by @PorcelinaD https://t.co/hd7PjorLpc
# Ethnic minorities face huge disparities compared to white  counterparts according to government stats #raceaudit… https://t.co/tSOpPjhHOK
# Male speakers outnumbered women by two-to-one on fringe panels at the Conservative party conference.… https://t.co/D7PfOHiRhg
# Number of working mothers in England rises by a million in 20 years by @sweale &amp; @caelainnbarr https://t.co/IJBDUaHVtQ
# Revealed: Britain's most powerful elite is 97% white https://t.co/eZljvora9C
# What is the average debt where you live? #ddj https://t.co/3Nd50FRYgw
# How death has changed over 100 years in Britain https://t.co/UJMmhe1eis
# Exclusive: Leaked data reveals UK companies at centre of secret $3bn Azerbaijani money laundering &amp; lobbying scheme https://t.co/1F1Zjvpu0j
# #Harvey https://t.co/hRsWe7M5du
# Revealed: England's fire services lose a quarter of safety officers since 2011 https://t.co/EeRE60ypkH
# Gender pay gap widening at one in four government bodies https://t.co/tYsXSN9zlB @caelainnbarr @GuardianAnushka https://t.co/y0hI6kDnDh
# Names of wealthy empty-home owners in Grenfell borough revealed https://t.co/h0EPikMCVF
# An insight into the work we do on the data team at the Guardian #ddj https://t.co/FAdNTuIoTU
# Two-thirds of Europeans believe EU should take hard line on Brexit – poll #ddj https://t.co/0nibrag2XT
# Young voters, class and turnout: how Britain voted in 2017 #ddj https://t.co/N13qVc1HlS
# Grenfell Tower is in one of the most deprived areas in England, where poverty and wealth exist side by side #ddj https://t.co/YlDDvRQ5av
# How did Theresa May's gamble fail? A data-driven take on where the Conservative vote was lost #ddj https://t.co/o6EXEi8AlS
# Theresa May spent more than half of election campaign in Labour-held seats by @PorcelinaD https://t.co/C6ZfsQfhVd
# A guide to inequality indexes – from wealth distribution to the World Happiness Report – &amp; how countries rank… https://t.co/kY1ZrRYK8z
# Are you rich if you earn £70,000? https://t.co/gUgZ9BqhUf https://t.co/SrFdw3nUUJ
# Immigration skills charge could hit health funding for years due to continuing reliance on foreign staff… https://t.co/Fg2g9OpFm6
# Listeria, batteries and botulism: why food products get recalled
# https://t.co/JnudQsy79F
# British banks handled vast sums of laundered Russian money
# @lukeharding1968 @nickhopkinsnews @caelainnbarr… https://t.co/pOLGAVqfP2
# The Global Laundromat: where the money went – video explainer https://t.co/5PoMVw1cnW
# British banks handled $738m of laundered Russian money
# https://t.co/sMDeP5Yffl @lukeharding1968 @nickhopkinsnews… https://t.co/IoM55SdiAv
# How to write a novel? Celebrate your milestones. Down tools now and then. Embrace the feel-good moments.… https://t.co/4O56IP0z6O
# RT @HelenaBengtsson: This is what @caelainnbarr has been analyzing lately - with @lukeharding1968 and @nickhopkinsnews - great reveal about…
# UK companies &amp; banks helped launder billions in Russian money laundering scheme linked to Russian government and KGB https://t.co/sMDeP5Yffl
# How to write a novel? Set targets. Overcome self doubt. Block social media. Celebrate your milestones. @Wylmenmuir… https://t.co/ZelStDWhAz
# Anatomy of a novel: celebrate your milestones, procrastinate (well) and accept (but overcome) self doubt… https://t.co/AHUQQUVwQW
# The death of dialect? Don't believe a word of it. Take our quiz to see which words you recognise. @britishlibrary… https://t.co/IfzgzVYehx
# If you use dialect this will be right up your ginnel/snicket/twitten/drang/closie/alley @britishlibrary @porcelinad… https://t.co/UFDip6tJDr
# If you've been called mardy, thrawn or nesh recently, congratulations. You prove the death of dialect is exaggerate… https://t.co/avKS9cU8fT
# The death of dialect? Don't believe a word of it. Take our quiz to see which words you recognise. @britishlibrary… https://t.co/Y374GBlcj2
# Sexual harassment in UK universities: number of claims per institution https://t.co/Dego1ZKcTS @HelenaBengtsson… https://t.co/UvriUXFpy8
# The RSS Christmas quiz answers are out. How did you do? https://t.co/TlUzMVXnl5 @RoyalStatSoc
# How Thatcher and May’s EU speeches compare https://t.co/Cgd83QRErg https://t.co/K7Pgrgk2dt
# How Thatcher and May’s EU speeches compare https://t.co/Cgd83R9fPQ https://t.co/feQZbdbqs8
# The Guardian is running a 24-hour climate change live blog ahead of Trump's inauguration https://t.co/xSgiRJh0Ny… https://t.co/0IiDw1zYB5
# A new DfE measure ranks schools based on pupils’ progress scores: how did your child's school fare?… https://t.co/fXUB1tYl2S
# World's best footballers: the numbers crunched https://t.co/2N3qem7VCy https://t.co/wHJn2NNeRq
# The annual RSS Christmas quiz is here: come and have a go if you think you're smart enough https://t.co/PX8BYz1k2D @RoyalStatSoc
# An Ipsos Mori survey in 40 countries uncovered some huge gaps between perception &amp; reality. Can you do better? https://t.co/vfwI76Hh38
# The perception gap: how well do you know your country? Take our quiz https://t.co/vfwI76pFEy https://t.co/4xrVrhyBlN
# Europeans greatly overestimate Muslim population, poll shows, with greatest perception gap in France… https://t.co/syzgFyLyNy
# Equal Pay Day: the UK's gender pay gap has narrowed but it will take another 62 years to close it… https://t.co/RCVn4qpQ3d
# Getting technical: how to get to the Great British Bake Off final https://t.co/yzRBueYMe6 @HelenaBengtsson… https://t.co/DiQuQx48HK
# Getting technical: how to get to the Great British Bake Off final https://t.co/yzRBueHbmy @HelenaBengtsson… https://t.co/w4Xh5WYAfL
# Getting technical: how to get to the Great British Bake Off final https://t.co/yzRBueHbmy @HelenaBengtsson… https://t.co/XYewwj1w0G
# The cost of British student housing has risen by a quarter in seven years from £120 to £147 per week https://t.co/agnv5J5Sr2 @caelainnbarr
# Dirty old town: 40% of recorded fly-tipping in England takes place in London, 12% in next nine largest cities… https://t.co/WZCxMDa4HW
# David Bowie's 50-year creative output at a glance https://t.co/236wRL3Yk3 @grbarnett @cr07cristina @CathLevett https://t.co/qU6Z4RfIbT
# David Bowie's 50-year creative output at a glance https://t.co/236wRL3Yk3 @grbarnett @cr07cristina @CathLevett https://t.co/1Sl6Um7oL6
# 25 years of UK byelections: when in power, the average swing away from the Conservatives is 22%… https://t.co/CXqhnOxPjy
# Huge increase in Britons seeking citizenship in EU states as Brexit looms https://t.co/9q12R2iNEV @SophiaSchirmer https://t.co/oqBUgXiWIa
# Huge increase in Britons seeking citizenship in EU states as Brexit looms
# https://t.co/9q12R2iNEV @sophiaschirmer https://t.co/5eDCth7nKV
# Dublin v London: what's the best bet for rich bankers? https://t.co/7DvRb261eF https://t.co/PN3iXglRBN
# How Europeans are losing trust in local democracy https://t.co/YSw0FKy726 @HelenaBengtsson/Paul Scruton https://t.co/OVaBL7nDvc
# How Europeans are losing trust in local democracy https://t.co/YSw0FKy726 @HelenaBengtsson and Paul Scruton https://t.co/8RVdi1GH3H
# Huge rise in Britons applying for Irish citizenship and passports after Brexit vote https://t.co/7axFa9txQX https://t.co/6bDe1H7797
# Reported rapes in England and Wales double in five years https://t.co/8IJxdndKcC
# Deutsche Bank’s potential $14bn penalty in 10 charts https://t.co/Gz63Q6TiPb @seanclarke @CathLevett @PorcelinaD https://t.co/zIsYLOQtBW
# Uber drivers await tribunal verdict on employment status https://t.co/ywxTdGA6LK
# One in seven UK takeaways have failed food hygiene tests. How does your area fare? https://t.co/MJJHLjVTMv https://t.co/JAqM5udzSE
# University mental health services face strain as demand rises 50% https://t.co/GKEcnAlgR4 https://t.co/RDu2VQzG3z
# RT @GuardianVisuals: Like to get serious with #dataviz, #visualstorytelling—and have fun? Join @GuardianVisuals https://t.co/F3axn1RoFx htt…
# #Oktoberfest attendees drank 70% more beer per head last year than 1980 &amp; at a higher cost https://t.co/30pA3LDQRD https://t.co/ML7p1mFZZj
# #Oktoberfest goers are drinking more beer &amp; paying more per Maß than ever https://t.co/30pA3LVsgd @SophiaSchirmer https://t.co/jZp5HqNV10
# RT @MonaChalabi: The organs we don't want to donate (via @PorcelinaD)
# https://t.co/VFzVZxPDCe https://t.co/I2CDZCQhOu
# How Strictly Come Dancing conquered the world, from Australia to Armenia @SophiaSchirmer
# https://t.co/4y2BNM9Iwm https://t.co/twX5sp41BZ
# Strictly speaking...a timeline of how the BBC dance show spread around the globe
# https://t.co/4y2BNM9Iwm https://t.co/ECEUYKImAD
# How Strictly Come Dancing conquered the world, step by step @SophiaSchirmer https://t.co/4y2BNMrjUW https://t.co/7XKmVaKarV
# Among the UK royal family Harry's is the most popular name...but George is on the up. https://t.co/yuLtc3hKIl https://t.co/6KJdEBve6E
# Boris was a more popular name than Theresa in 2015. How did your name do? https://t.co/yuLtc3hKIl https://t.co/0uoTkYIRKD
# Is your name still in fashion? And which is the only Friends name that remains popular? https://t.co/yuLtc3zm6V https://t.co/uUaODoMIl1
# Is your name popular? Find out with our interactive (&amp; see how some famous names have fared) https://t.co/yuLtc3zm6V https://t.co/1gzrVnfoZH
# Top baby names: is yours on the up and up or on the way out?https://t.co/yuLtc3zm6V https://t.co/bCrieyLsXP
# 30 years ago a little lamp called Luxo Jr hopped into our lives: a timeline of Pixar profits
# https://t.co/4bNo2ptRde https://t.co/fuDj9OZf1P
# RT @MonaChalabi: America, you're late to the party.
# https://t.co/skYiffpmM6 https://t.co/vHix6t4qZY
# European terrorist attacks in a global/historical context https://t.co/wPvDyvZHQa
# @caelainnbarr https://t.co/Lq6E4CKABv
# Europe experiencing higher numbers of terrorist attacks but lower death tolls @caelainnbarr https://t.co/wPvDyvZHQa https://t.co/9Bk6j9GZS7
# Terrorist attacks: Europe’s summer of violence in a global/historical context
# https://t.co/F2BAT2iimB @caelainnbarr https://t.co/SWG5BYwCV4
# UK growth not being converted to increased wellbeing: @bcg report https://t.co/KvqsLsnb59 @beal_douglas https://t.co/OnErK9HLfZ
# EU referendum results: every area by key demographics https://t.co/BfgbD5CnLX https://t.co/0iFqqir7Hs
# RT @PopovichN: How a drug overdose epidemic spread across America: https://t.co/1WrKPERdB8 https://t.co/ta4zAlgiO7
# London mayor: Commons speeches reveal candidates' differing issue focus https://t.co/qx6Bosubn2 https://t.co/RwKvqu7iT8
# The lawsuit against the New York Times highlights a big diversity problem https://t.co/Q3HOfVp4C1 via @MonaChalabi https://t.co/1e9u6OLW5X
# Game of Thrones: the most Googled characters – episode by episode https://t.co/dyS9UKEGGJ
# Older women feel most unsafe but are least likely to be attacked
# https://t.co/Gs3CsuWTxV https://t.co/KaxLq2jH6z
# RT @kenandavis: We're hiring for interactive team! Come join me, @Rich_Harris &amp; @PopovichN at Guardian US https://t.co/YivrF85dQo
# RT @MonaChalabi: Analysing 70m comments is data journalism at its best: revealing, transparent and accessible https://t.co/5qm7WXSbSh https…
# RT @Rich_Harris: New feature for WI primaries – desktop notifications. We'd love your feedback – try 'em out! https://t.co/PJYnF7nYZI https…
# US election delegate tracker: chart the candidates' path to the nomination https://t.co/ulpvZ7ya0A https://t.co/eyd701JEyS
# RT @kenandavis: Dear recent grads! Come join me, @PopovichN, and @Rich_Harris with our new fellowship program: https://t.co/vv8D8ztQMK
# Fewer babies called Patrick, few daily Irish speakers...huge diaspora #StPatricksDay stats https://t.co/pHB5MR6UVI https://t.co/lYkstH3GVJ
# Some lesser known Irish stats and facts to mark #StPatricksDay https://t.co/pHB5MR6UVI https://t.co/f9HwfukzOd
# RT @AlbertoNardelli: Will a #sugartax actually work? https://t.co/7beqedJIZj #Budget2016
# RT @Rich_Harris: JOIN US https://t.co/SoI4KregyG
# Noughties marriages less likely to end in divorce in early years than previous two decades https://t.co/eNsIG2ufmX https://t.co/osFxnlYvvT
# Polls suggest Brexit has (low) turnout on its side https://t.co/Z47tvFHl9B
# RT @AlbertoNardelli: What are former Lib Dem MPs doing now? https://t.co/iR8D8OfMwf
# How does money flow through the health service in England? https://t.co/WSW1FN1yWB https://t.co/g3TVTBOWt5
# How do countries' health systems compare? View our interactive graphs. #ThisIsTheNHS https://t.co/D5IgPA04o8 https://t.co/dxsCBdNF4s
# How much have you cost the NHS? Find out with our interactive calculator.
# https://t.co/lbrPQBw1Jh https://t.co/HoXNO9HGbc
# @Agarwal_Natasha the second half of the email you had was correct, so data@guardian.co.uk
# UK press most likely to be seen as rightwing in @YouGov poll of seven European countries https://t.co/yRUsi5EuPQ https://t.co/7LwoSyFam4
# @Agarwal_Natasha data@
# RT @AlbertoNardelli: One in nine "EU migrant couples" on tax credits are actually half-British https://t.co/4q1yrV5yMB
# As #SupportSyrians conference opens these 6 charts show how Europe is struggling to respond https://t.co/xF7DZ4TTmo https://t.co/TyrBdNtUco
# The "bed blockers": the stats, the people and the causes https://t.co/QOqjXHiLWw
# https://t.co/YvFQXhb9xe https://t.co/tlyiIMzw0T
# MPs ignorant of key EU institutions – poll https://t.co/8xfC9vkztd
# Almost 60% of people aged 85+ were living alone in 2011 #ThisIsTheNHS
# https://t.co/YvFQXhb9xe https://t.co/biioPYfRI4
# More than two-fifths of UK health expenditure is spent on people aged 65+ https://t.co/m0QLMEXSC3 #ThisIsTheNHS https://t.co/Cu17K2De73
# Latest figures on how the NHS is coping this winter on our data dashboard #ThisIsTheNHS https://t.co/YvFQXhb9xe https://t.co/LM8m3Rr8Oc
# 2/3s of EU Premier League footballers wouldn’t meet the visa criteria used for non-EU ones
#
# https://t.co/KGEaojbYjN
#
# https://t.co/GOpgx8UmBd
# Female prisoners more likely to self-harm than male counterparts https://t.co/37g5Uw6HAh
# The latest flu stats from the Guardian's NHS data dashboard #ThisIsTheNHS https://t.co/YvFQXhb9xe https://t.co/erb1egx1V0
# British transport police logged an average of 5.5 racially or religiously motivated hate crimes a day in 2015 https://t.co/QBI2Ij6Kld
# RT @AlbertoNardelli: Young angry white male voters are on the rise – but they won't win power without women  https://t.co/DO4SW0iqEW
# RT @MonaChalabi: The Hispanic vote could be crucial https://t.co/9xnZLimNLf https://t.co/5WzuGuwVcM
# 57m antidepressant prescriptions in England in 2014, double the 2004 figure #thisistheNHS https://t.co/YvFQXhb9xe https://t.co/qp4Bgz8U1c
# History of same-sex unions across Europe ahead of Italian senate vote on civil partnership https://t.co/7159GzjDkf https://t.co/vuButNADDF
# Same-sex unions in Europe: a timeline https://t.co/7159GzjDkf https://t.co/5zILfZXxDP
# There were 8,416 alcohol-related deaths registered in the UK in 2013 #thisistheNHS https://t.co/YvFQXhb9xe https://t.co/gI8tSFAyyN
# Over 1m alcohol-related hospital admissions = £3.5bn annual cost to NHS #thisistheNHS https://t.co/YvFQXhb9xe https://t.co/6W8De1Ydk4
# NHS data dashboard: how the NHS is coping this winter #thisistheNHS https://t.co/YvFQXhb9xe https://t.co/CLNPVt3wnS
# How well do you know the NHS? Take our quiz! https://t.co/XsDeW88zH7
# The NHS data dashboard: babies born, salaries paid, the winter crisis https://t.co/khTO3AkL1j #thisisthenhs https://t.co/F22NzIvMmj
# RT @MonaChalabi: Japan doesn't bother with alcohol guidelines for women  https://t.co/X0wo1SJgDK really interesting via @grbarnett https://…
# RT @AlbertoNardelli: UK government is failing to disclose how many British nationals claiming tax credits are being counted as migrants htt…
# How many guns in America are actually subject to background checks? https://t.co/W5TCDj9E5O via @MonaChalabi https://t.co/0RIOr3oQt7
# RT @AlbertoNardelli: Thanks to high levels of immigration Germany's population is growing again - for now, at least https://t.co/h5tjYipsbb
# How long do people keep their New Year resolutions?
# https://t.co/dQ4h5sNLF2
# Tenerife tops searches for New Year's Eve holidays from UK https://t.co/Fz3Q90yBQc
# We asked Guardian readers what they eat for Christmas dinner. Here are the results, mapped. https://t.co/phTvpJai2H https://t.co/2875C1s4VE
# RT @AlbertoNardelli: Spain votes on Sunday! Here is a guide to what will be an awesome election https://t.co/dpc0apDuZ8 #20D
# Rural hospital journeys by public transport take almost twice as long as in cities https://t.co/JrYHJHBYmt https://t.co/EDgzeXySnX
# Scotland's debt mountain: Holyrood's borrowing could hit £50bn by 2020 https://t.co/PtbaVj7XvF
# Introducing our new(ish) US data editor @MonaChalabi. She'll be covering politics, pubic hair etc etc https://t.co/6sR68aXNFf
# RT @MonaChalabi: Could more gun control have stopped 2015's deadliest mass shootings? https://t.co/thW2cxFT3F https://t.co/FTX0Q4xzkR
# RT @AlbertoNardelli: What the French election results mean for the 2017 presidential race https://t.co/KgbTwApwF3 https://t.co/TYThgTZXaE
# RT @AlbertoNardelli: Number of investor visas to the UK has collapsed https://t.co/cpPjyVryMd https://t.co/axh2o0wBd6
# RT @AlbertoNardelli: A few thoughts on France regional election and the historic FN result - and what might happen in II round and beyond h…
# Have a go at tackling the (very difficult) Royal Statistical Society Christmas quiz  https://t.co/rJ2WTzfvmh
# Why data was crucial to Burkina Faso’s first election since uprising https://t.co/6WMIvVdy9P
# RT @AlbertoNardelli: What Americans get wrong https://t.co/DgMzAyDRRN
# RT @AlbertoNardelli: How well do you really know your country? Take our quiz https://t.co/uLpYxv6mJY
# RT @IpsosMORI: New #PerilsofPerception: What the world gets wrong: @porcelinad on our global poll @GuardianData https://t.co/JzCCorrZmm #MRX
# Osborne reliant on rising immigration levels to achieve budget surplus https://t.co/qoh0HOUNev
# Britons among least knowledgeable about European Union https://t.co/EjfKLnfUbp
# RT @AlbertoNardelli: UK civil service is at its smallest since WWII - how it has changed over the past 5 years, in 10 charts https://t.co/W…
# RT @AlbertoNardelli: Delighted to welcome @PorcelinaD to the @GuardianData team
# RT @AlbertoNardelli: Germany has received nearly 50% of all asylum applications made by Syrians in EU states https://t.co/DFoQumBqHZ https:…
# RT @AlbertoNardelli: EU member states have so far relocated just 116 refugees out of 160,000 they committed to https://t.co/EtJTBfRCaZ http…
# 41 million lives recorded in one day, a country on the brink of war - a look at the 1939 Register https://t.co/evmFGrfYr3
# The impact of #China's one-child policy in charts https://t.co/qtAGFLRueU
# RT @AlbertoNardelli: Poland election on Sunday! A guide to the parties, polls and voting system https://t.co/pQaNjPb7jr
# RT @AlbertoNardelli: Canada election result in 3 maps https://t.co/A2HFQqf8Fc - why do one #Elxn42 map when you can do three https://t.co/m…
# China's relationship with Britain in numbers https://t.co/bFBU9Bz20P
# RT @AlbertoNardelli: 7% of UK couples comprise one UK national, one non-UK national. Govt classes many such couples as "migrant families" h…
# Nearly one in four UK adults – around 12 million people – do not have basic online skills http://t.co/7y91aAAUho
# RT @AlbertoNardelli: Canada votes today! Here's a guide to the election http://t.co/PfPoeupOFe #elxn42
# RT @AlbertoNardelli: Number of asylum applications in EU has broken record set in 1992 - then and now compared: http://t.co/CFEm6iuPFw http…
# EU referendum: polling reveals freedom of movement most contentious issue http://t.co/HDVjT1Vhrn
# RT @AlbertoNardelli: How do Europe's all-time top goalscorers compare to Zlatan @Ibra_official? http://t.co/QvgjkCnujY http://t.co/A1oMHLIu…
# RT @AlbertoNardelli: Nearly everything Theresa May said today about immigration is wrong http://t.co/0lF16RcQI9
# Portugal's election – a guide to the parties and politics http://t.co/u2ZzjvEJH9
# Nearly one-mass shooting a day in the US since 2013 but support for gun rights holds solid http://t.co/ju0XP8LB0n http://t.co/lle6WVYGDb
# Portugal's election is on Sunday – a guide to the parties and politics http://t.co/u2ZzjvWl5J
# Private households financial assets could settle world's sovereign debt three times over  http://t.co/d3Fo48N9Id
# RT @AlbertoNardelli: A guide to the most important #Catalonia election ever http://t.co/k7hdeWYwYh #27S
# Why going home from work on time is good for you – and your employer http://t.co/sB5TkBeehY
# RT @AndrewSparrow: Ukip most male party, Greens best educated, and Lib Dems most middle class - http://t.co/MQ0nCKUYBE
# RT @AlbertoNardelli: The #GreekElections result: the key numbers http://t.co/a0u62UYo70 #ekloges2015_round2 http://t.co/Cexb7KzhN8
# RT @AlbertoNardelli: #GreekElections result: the key numbers http://t.co/a0u62VfYYy http://t.co/VvlWkIUQix
# Angela Merkel: 10 years in 10 charts http://t.co/rJxLKSPBPs

# %%
# Print the Tweet Count# Print 
print(f"Tweet Count: {len(tweet_texts)}")
# Out:
# Tweet Count: 200

# %% [markdown]
# # Everyone Turn Activity 8 Datetime Objects

# %%
# New Dependency
from datetime import datetime

# %%
# Dependencies
import tweepy
import json
import numpy as np
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = 'latimes'

# Get all tweets from home feed
public_tweets = api.user_timeline(target_user)

# A list to hold tweet timestamps
tweet_times = []

# Loop through all tweets
for tweet in public_tweets:
    raw_time = tweet["created_at"]
    print(raw_time)
    tweet_times.append(raw_time)
# Out:
# Sat Jun 02 19:55:04 +0000 2018
# Sat Jun 02 19:36:44 +0000 2018
# Sat Jun 02 19:16:47 +0000 2018
# Sat Jun 02 18:55:06 +0000 2018
# Sat Jun 02 18:35:06 +0000 2018
# Sat Jun 02 18:15:07 +0000 2018
# Sat Jun 02 17:55:05 +0000 2018
# Sat Jun 02 17:35:05 +0000 2018
# Sat Jun 02 17:15:07 +0000 2018
# Sat Jun 02 16:35:06 +0000 2018
# Sat Jun 02 16:05:10 +0000 2018
# Sat Jun 02 15:35:06 +0000 2018
# Sat Jun 02 15:05:08 +0000 2018
# Sat Jun 02 14:35:06 +0000 2018
# Sat Jun 02 14:05:10 +0000 2018
# Sat Jun 02 13:05:10 +0000 2018
# Sat Jun 02 12:05:06 +0000 2018
# Sat Jun 02 11:38:50 +0000 2018
# Sat Jun 02 11:05:07 +0000 2018
# Sat Jun 02 10:35:12 +0000 2018

# %%
# Convert tweet timestamps to datetime objects that can be manipulated by
# Python
converted_timestamps = []
for raw_time in tweet_times:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
    converted_timestamps.append(converted_time)

# %%
print(tweet_times[0])
print(tweet_times[1])
# Out:
# Sat Jun 02 19:55:04 +0000 2018
# Sat Jun 02 19:36:44 +0000 2018

# %%
print(converted_timestamps[0])
print(converted_timestamps[1])
# Out:
# 2018-06-02 19:55:04+00:00
# 2018-06-02 19:36:44+00:00

# %%
diff = converted_timestamps[0] - converted_timestamps[1]
print("Time difference: ", diff)
print('seconds: {}'.format(diff.seconds))
# Out:
# Time difference:  0:18:20
# seconds: 1100

# %%
converted_length = len(converted_timestamps)
print(f"length of converted timestamps list: {converted_length}")

time_diffs = []

for x in range(converted_length - 1):
    time_diff = converted_timestamps[x] - converted_timestamps[x + 1]
#     print(f'time diff: {time_diff}')
#     print(f'time diff (in seconds): {time_diff.seconds}')
#     print(f'time diff (in minutes): {time_diff.seconds / 60}')
#     print(f'time diff (in hours): {time_diff.seconds / 3600}')

    # convert time_diff to hours
    time_diff = time_diff.seconds / 3600
    time_diffs.append(time_diff)

print(f"Avg. Hours Between Tweets: {np.mean(time_diffs)}")
# Out:
# length of converted timestamps list: 20
# Avg. Hours Between Tweets: 0.4911111111111111

# %% [markdown]
# # Students Turn Activity 9
# # Twitter Velocity
#
# ## Instructions
#
# * You are a political data consultant, and have been asked to evaluate how frequently Donald Trump tweets. As a savvy data visualization specialist, you decide on the following course of action: first, you will collect the timestamps of the 500 most recent tweets sent out by Trump. After making a list of the timestamps, you will convert the timestamps into datetime objects. Then you will calculate the time difference from one tweet to the next, and plot those data points in a scatterplot chart.
#
# * The tools you will use for this task are Tweepy and MatPlotLib. You will also need to use the `datetime` library to convert Twitter timestamps to Python datetime objects.
#
# * Your plot should look something like this:
#
#   ![velocity.png](velocity.png)
#
# * This handy chart visually demonstrates Trump's tweet pattern: the majority of his tweets are sent within five hours of each other, but he goes up to 24 hours without tweeting!
#
# * See, in contrast, the tweet pattern of a major news organization, the LA Times, whose tweets are sent out much more frequently:
#
#   ![velocity1.png](velocity1.png)
#
# * **Note**: Feel free to plot the tweets of another Twitter account. It does not have to be Donald Trump's!

# %%
# Dependencies
import tweepy
import json
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
user = "realDonaldTrump"

# Create array to record all date-times of tweets

tweet_times = []
counter = 0

# Loop through 500 tweets
for x in range(1,26):
    
    public_tweets = api.user_timeline(user, page=x)
    
    for tweet in public_tweets:
        raw_time = tweet["created_at"]
        tweet_times.append(raw_time)
        counter += 1
        
        # Create a counter for viewing every 100 tweets
        if counter % 100 == 0: #multiple of 100
            print(raw_time)
            
# Confirm tweet counts
print(f"Tweet Count: {len(tweet_times)}")
# Out:
# Thu May 24 00:58:04 +0000 2018
# Fri May 11 20:56:25 +0000 2018
# Fri Apr 27 10:55:48 +0000 2018
# Tue Apr 17 12:24:36 +0000 2018
# Tue Apr 03 00:24:01 +0000 2018
# Tweet Count: 500

# %%
# Convert all tweet times into datetime objects


# Add each datetime object into the array

# %%
# Calculate the time between tweets


# Calculate the time in between each tweet

# Hours Between Tweets

# %%
# Plot Time Between Tweets

# %% [markdown]
# # Instructor Turn Activity 10

# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? lindy hop
# {'search_metadata': {'completed_in': 0.032,
#   'count': 15,
#   'max_id': 1003008301364367360,
#   'max_id_str': '1003008301364367360',
#   'next_results': '?max_id=1002877926629658623&q=lindy%20hop&include_entities=1',
#   'query': 'lindy+hop',
#   'refresh_url': '?since_id=1003008301364367360&q=lindy%20hop&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 20:19:48 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'youtu.be/r5u5nxnroro?a',
#       'expanded_url': 'http://youtu.be/r5u5nxnroro?a',
#       'indices': [36, 59],
#       'url': 'https://t.co/LJYog2Z5Ba'}],
#     'user_mentions': [{'id': 10228272,
#       'id_str': '10228272',
#       'indices': [26, 34],
#       'name': 'YouTube',
#       'screen_name': 'YouTube'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1003008301364367360,
#    'id_str': '1003008301364367360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#    'text': 'Me ha gustado un vídeo de @YouTube (https://t.co/LJYog2Z5Ba - Lindy Hop Hellzapoppin).',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Oct 11 00:20:29 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Mi dedicación al trabajo como arquitecto me llena de satisfacción y sigo aportando mi granito de arena día a día para dejar huella de mi paso por esta Isla.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'arquivan.mex.tl',
#         'expanded_url': 'http://www.arquivan.mex.tl',
#         'indices': [0, 22],
#         'url': 'http://t.co/Lr4BJpDXns'}]}},
#     'favourites_count': 457,
#     'follow_request_sent': False,
#     'followers_count': 143,
#     'following': False,
#     'friends_count': 448,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 201063471,
#     'id_str': '201063471',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3,
#     'location': 'Subconciente ligado al pasado',
#     'name': 'ArQuIvAn',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/201063471/1451214865',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/665504130023075840/XUB_KMKH_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/665504130023075840/XUB_KMKH_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'btta2010',
#     'statuses_count': 15618,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/Lr4BJpDXns',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 19:51:59 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'youtu.be/r5u5nxnroro',
#       'expanded_url': 'https://youtu.be/r5u5nxnroro',
#       'indices': [23, 46],
#       'url': 'https://t.co/b0MfEGy0YQ'}],
#     'user_mentions': [{'id': 10228272,
#       'id_str': '10228272',
#       'indices': [51, 59],
#       'name': 'YouTube',
#       'screen_name': 'YouTube'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1003001299284217856,
#    'id_str': '1003001299284217856',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'is',
#    'metadata': {'iso_language_code': 'is', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Lindy Hop Hellzapoppin https://t.co/b0MfEGy0YQ vía @YouTube',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 10 19:05:20 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '↘↘@4_PO_DMT',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 12256,
#     'follow_request_sent': False,
#     'followers_count': 177,
#     'following': False,
#     'friends_count': 302,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 2914247992,
#     'id_str': '2914247992',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3,
#     'location': 'Madrid',
#     'name': 'влад',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2914247992/1503873518',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/998321087870943232/CS8FVoi8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998321087870943232/CS8FVoi8_normal.jpg',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': '___________baia',
#     'statuses_count': 11810,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 19:28:22 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 86960073,
#       'id_str': '86960073',
#       'indices': [3, 16],
#       'name': "Let's dance 🇸🇪",
#       'screen_name': 'TV4LetsDance'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002995356102209536,
#    'id_str': '1002995356102209536',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'sv',
#    'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Jun 01 18:33:32 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1002619171442757632',
#        'indices': [114, 137],
#        'url': 'https://t.co/OhEdiZvoSx'}],
#      'user_mentions': []},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 1002619171442757632,
#     'id_str': '1002619171442757632',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'sv',
#     'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'Daniel utmanar med en repris av sin Lindy Hop! 🎊🙌 Tyckte du om det? Ring 099-41402 eller sms:a DANIEL till 72400… https://t.co/OhEdiZvoSx',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Nov 02 15:09:49 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Din bästa dansshow! Fredagar 20.00 i TV4 & TV4 Play #letsdancese',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tv4play.se/program/lets-d…',
#          'expanded_url': 'http://www.tv4play.se/program/lets-dance',
#          'indices': [0, 23],
#          'url': 'https://t.co/Ne9yLh3ywB'}]}},
#      'favourites_count': 156,
#      'follow_request_sent': False,
#      'followers_count': 3404,
#      'following': False,
#      'friends_count': 63,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 86960073,
#      'id_str': '86960073',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 14,
#      'location': 'Sverige',
#      'name': "Let's dance 🇸🇪",
#      'notifications': False,
#      'profile_background_color': '0A0A0A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/86960073/1520421510',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/567774537211990016/WCaMorzV_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/567774537211990016/WCaMorzV_normal.jpeg',
#      'profile_link_color': '05BCFF',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '050505',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'TV4LetsDance',
#      'statuses_count': 2944,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/Ne9yLh3ywB',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @TV4LetsDance: Daniel utmanar med en repris av sin Lindy Hop! 🎊🙌 Tyckte du om det? Ring 099-41402 eller sms:a DANIEL till 72400 #letsdan…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 04 20:43:41 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 6677,
#     'follow_request_sent': False,
#     'followers_count': 84,
#     'following': False,
#     'friends_count': 146,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1242167910,
#     'id_str': '1242167910',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'sv',
#     'listed_count': 3,
#     'location': '',
#     'name': 'Johanna hillermo',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3341302116/803ddaeba56a12eb5270c25c96301d91_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3341302116/803ddaeba56a12eb5270c25c96301d91_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'JHillermo',
#     'statuses_count': 8612,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 19:07:27 +0000 2018',
#    'entities': {'hashtags': [{'indices': [100, 107], 'text': 'BIDF18'}],
#     'symbols': [],
#     'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#       'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#       'indices': [108, 131],
#       'url': 'https://t.co/J0eLMdMWPw'}],
#     'user_mentions': [{'id': 48148622,
#       'id_str': '48148622',
#       'indices': [3, 17],
#       'name': 'Birmingham International Dance Festival',
#       'screen_name': 'BhamDanceFest'},
#      {'id': 80530579,
#       'id_str': '80530579',
#       'indices': [20, 32],
#       'name': 'The Swing Era',
#       'screen_name': 'TheSwingEra'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002990093748129793,
#    'id_str': '1002990093748129793',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Jun 02 14:11:20 +0000 2018',
#     'entities': {'hashtags': [{'indices': [81, 88], 'text': 'BIDF18'}],
#      'symbols': [],
#      'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#        'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#        'indices': [89, 112],
#        'url': 'https://t.co/J0eLMdMWPw'}],
#      'user_mentions': [{'id': 80530579,
#        'id_str': '80530579',
#        'indices': [1, 13],
#        'name': 'The Swing Era',
#        'screen_name': 'TheSwingEra'}]},
#     'favorite_count': 7,
#     'favorited': False,
#     'geo': None,
#     'id': 1002915573683060739,
#     'id_str': '1002915573683060739',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-2.033651, 52.381063],
#         [-1.74763, 52.381063],
#         [-1.74763, 52.60687],
#         [-2.033651, 52.60687]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United Kingdom',
#      'country_code': 'GB',
#      'full_name': 'Birmingham, England',
#      'id': '53b67b1d1cc81a51',
#      'name': 'Birmingham',
#      'place_type': 'city',
#      'url': 'https://api.twitter.com/1.1/geo/id/53b67b1d1cc81a51.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '.@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jun 17 22:47:05 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Bringing Birmingham alive with of the best of British & international dance. \nProduced by @dancexchange. \n1-24 June 2018',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bidf.co.uk',
#          'expanded_url': 'http://bidf.co.uk',
#          'indices': [0, 23],
#          'url': 'https://t.co/deGtX9bFGa'}]}},
#      'favourites_count': 1019,
#      'follow_request_sent': False,
#      'followers_count': 2886,
#      'following': False,
#      'friends_count': 1370,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 48148622,
#      'id_str': '48148622',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 58,
#      'location': 'Birmingham, UK',
#      'name': 'Birmingham International Dance Festival',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48148622/1526467213',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'BhamDanceFest',
#      'statuses_count': 3598,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/deGtX9bFGa',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Nov 03 09:34:45 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'welcome 2 Raring2go! the best guide of what 2do & where 2go for parents,carers &children in &around the Bromsgrove & Redditch areas. Advertise in my nxt edition',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'raring2go.co.uk/index.php',
#         'expanded_url': 'http://www.raring2go.co.uk/index.php',
#         'indices': [0, 22],
#         'url': 'http://t.co/utgZCEphyN'}]}},
#     'favourites_count': 18744,
#     'follow_request_sent': False,
#     'followers_count': 1892,
#     'following': False,
#     'friends_count': 2186,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 211457830,
#     'id_str': '211457830',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 73,
#     'location': 'Rubery',
#     'name': 'Raring2go! Bromsgrov',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/519197242767720448/NcK8_7l1_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/519197242767720448/NcK8_7l1_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Raring2goLisa',
#     'statuses_count': 32209,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/utgZCEphyN',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 18:48:42 +0000 2018',
#    'entities': {'hashtags': [{'indices': [100, 107], 'text': 'BIDF18'}],
#     'symbols': [],
#     'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#       'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#       'indices': [108, 131],
#       'url': 'https://t.co/J0eLMdMWPw'}],
#     'user_mentions': [{'id': 48148622,
#       'id_str': '48148622',
#       'indices': [3, 17],
#       'name': 'Birmingham International Dance Festival',
#       'screen_name': 'BhamDanceFest'},
#      {'id': 80530579,
#       'id_str': '80530579',
#       'indices': [20, 32],
#       'name': 'The Swing Era',
#       'screen_name': 'TheSwingEra'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002985374774366213,
#    'id_str': '1002985374774366213',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Jun 02 14:11:20 +0000 2018',
#     'entities': {'hashtags': [{'indices': [81, 88], 'text': 'BIDF18'}],
#      'symbols': [],
#      'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#        'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#        'indices': [89, 112],
#        'url': 'https://t.co/J0eLMdMWPw'}],
#      'user_mentions': [{'id': 80530579,
#        'id_str': '80530579',
#        'indices': [1, 13],
#        'name': 'The Swing Era',
#        'screen_name': 'TheSwingEra'}]},
#     'favorite_count': 7,
#     'favorited': False,
#     'geo': None,
#     'id': 1002915573683060739,
#     'id_str': '1002915573683060739',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-2.033651, 52.381063],
#         [-1.74763, 52.381063],
#         [-1.74763, 52.60687],
#         [-2.033651, 52.60687]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United Kingdom',
#      'country_code': 'GB',
#      'full_name': 'Birmingham, England',
#      'id': '53b67b1d1cc81a51',
#      'name': 'Birmingham',
#      'place_type': 'city',
#      'url': 'https://api.twitter.com/1.1/geo/id/53b67b1d1cc81a51.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '.@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jun 17 22:47:05 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Bringing Birmingham alive with of the best of British & international dance. \nProduced by @dancexchange. \n1-24 June 2018',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bidf.co.uk',
#          'expanded_url': 'http://bidf.co.uk',
#          'indices': [0, 23],
#          'url': 'https://t.co/deGtX9bFGa'}]}},
#      'favourites_count': 1019,
#      'follow_request_sent': False,
#      'followers_count': 2886,
#      'following': False,
#      'friends_count': 1370,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 48148622,
#      'id_str': '48148622',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 58,
#      'location': 'Birmingham, UK',
#      'name': 'Birmingham International Dance Festival',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48148622/1526467213',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'BhamDanceFest',
#      'statuses_count': 3598,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/deGtX9bFGa',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 22 12:10:31 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Nearly new baby & children’s sales in South Birmingham. Working with businesses, groups and charities to reach local families @emmamylett #SmartSocial #QueenOf',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'mum2mummarket.co.uk/west-midlands-…',
#         'expanded_url': 'http://mum2mummarket.co.uk/west-midlands-nearly-new-sales.html',
#         'indices': [0, 23],
#         'url': 'https://t.co/EkFCycJu3J'}]}},
#     'favourites_count': 6488,
#     'follow_request_sent': False,
#     'followers_count': 1357,
#     'following': False,
#     'friends_count': 2138,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 745589782433112064,
#     'id_str': '745589782433112064',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 36,
#     'location': 'Birmingham, England',
#     'name': 'mum2mum market Brum',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/745589782433112064/1527712276',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1000086724184297474/CClYKHj9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000086724184297474/CClYKHj9_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'brummum2mum',
#     'statuses_count': 7014,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/EkFCycJu3J',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 18:00:21 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'youtu.be/r5u5nxnroro?a',
#       'expanded_url': 'http://youtu.be/r5u5nxnroro?a',
#       'indices': [30, 53],
#       'url': 'https://t.co/Csd4Gwfjq0'}],
#     'user_mentions': [{'id': 10228272,
#       'id_str': '10228272',
#       'indices': [21, 29],
#       'name': 'YouTube',
#       'screen_name': 'YouTube'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002973206360330240,
#    'id_str': '1002973206360330240',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#    'text': 'Me gustó un video de @YouTube https://t.co/Csd4Gwfjq0 Lindy Hop Hellzapoppin',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 07 16:56:51 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Músico y moneroso. Andaremos en contacto. Salú!',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'facebook.com/pages/Errrez',
#         'expanded_url': 'http://facebook.com/pages/Errrez',
#         'indices': [0, 23],
#         'url': 'https://t.co/7UUN6uGTwk'}]}},
#     'favourites_count': 6720,
#     'follow_request_sent': False,
#     'followers_count': 197,
#     'following': False,
#     'friends_count': 392,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2432324120,
#     'id_str': '2432324120',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 1,
#     'location': 'México',
#     'name': 'Errrez (El Raúl)',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2432324120/1527876506',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1002663169725120512/-2E5-wtM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1002663169725120512/-2E5-wtM_normal.jpg',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Errrez',
#     'statuses_count': 5899,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/7UUN6uGTwk',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 17:51:20 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1002970938290376704',
#       'indices': [117, 140],
#       'url': 'https://t.co/x4cIuwBYpc'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002970938290376704,
#    'id_str': '1002970938290376704',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Had a brilliant time in Birmingham today at the Dance Festival. Had free lessons in the Lindy Hop and Charleston wh… https://t.co/x4cIuwBYpc',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Sep 09 20:49:31 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Mother of 2 gorgeous boys, HUGE fan of Rhydian, loves dancing, music, films and theatre and food! Also a huge fan of Mrs Brown's Boys.",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 225,
#     'follow_request_sent': False,
#     'followers_count': 67,
#     'following': False,
#     'friends_count': 120,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 72947315,
#     'id_str': '72947315',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': '',
#     'name': 'Joy Nuttall',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/910965965948669952/W5k3KD9b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/910965965948669952/W5k3KD9b_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Brummiebabes',
#     'statuses_count': 1818,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 17:10:02 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1002960543571902464',
#       'indices': [117, 140],
#       'url': 'https://t.co/Qnb2U3mx1N'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002960543571902464,
#    'id_str': '1002960543571902464',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '“What did you do today?” Oh, you know... Gym, walked the dog, food, Lindy Hop event, spur-of-the-moment piercing. S… https://t.co/Qnb2U3mx1N',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Aug 28 19:09:16 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Waiting to take that hand and run.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 6279,
#     'follow_request_sent': False,
#     'followers_count': 415,
#     'following': False,
#     'friends_count': 1024,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 2753583262,
#     'id_str': '2753583262',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 8,
#     'location': 'Sheffield, England',
#     'name': 'Amelia Jean Black',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2753583262/1474582766',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/871029775393075200/_uZKA_7z_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/871029775393075200/_uZKA_7z_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ACrimsonLily',
#     'statuses_count': 4209,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 15:59:40 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1002918672275591168',
#       'indices': [81, 104],
#       'url': 'https://t.co/ctfpFqrqaT'},
#      {'display_url': 'tweetedtimes.com/v/10703?s=tnp',
#       'expanded_url': 'http://tweetedtimes.com/v/10703?s=tnp',
#       'indices': [115, 138],
#       'url': 'https://t.co/FI9qPsFvr3'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002942835816058885,
#    'id_str': '1002942835816058885',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.tweetedtimes.com" rel="nofollow">The Tweeted Times</a>',
#    'text': 'Top story: Lindy Hop Greece on Twitter: "Can you spot the Lindy Hoppers? Swing … https://t.co/ctfpFqrqaT, see more https://t.co/FI9qPsFvr3',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 13 18:50:58 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Πόσο δύσκολο είναι να κοιτάξεις πέρα από τη λεπτή κόκκινη γραμμή και να διακρίνεις το ολοφάνερο;',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 178,
#     'follow_request_sent': False,
#     'followers_count': 1258,
#     'following': False,
#     'friends_count': 2085,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 104570599,
#     'id_str': '104570599',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'el',
#     'listed_count': 71,
#     'location': 'HELLAS',
#     'name': 'ΤΑ ΚΑΛΥΤΕΡΑ',
#     'notifications': False,
#     'profile_background_color': 'FFF04D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104570599/1448936499',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/905908469659836416/mNnlGzWl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/905908469659836416/mNnlGzWl_normal.jpg',
#     'profile_link_color': '0099CC',
#     'profile_sidebar_border_color': 'FFF8AD',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'takalytera',
#     'statuses_count': 30306,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 14:26:41 +0000 2018',
#    'entities': {'hashtags': [{'indices': [100, 107], 'text': 'BIDF18'}],
#     'symbols': [],
#     'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#       'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#       'indices': [108, 131],
#       'url': 'https://t.co/J0eLMdMWPw'}],
#     'user_mentions': [{'id': 48148622,
#       'id_str': '48148622',
#       'indices': [3, 17],
#       'name': 'Birmingham International Dance Festival',
#       'screen_name': 'BhamDanceFest'},
#      {'id': 80530579,
#       'id_str': '80530579',
#       'indices': [20, 32],
#       'name': 'The Swing Era',
#       'screen_name': 'TheSwingEra'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002919435232071681,
#    'id_str': '1002919435232071681',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Jun 02 14:11:20 +0000 2018',
#     'entities': {'hashtags': [{'indices': [81, 88], 'text': 'BIDF18'}],
#      'symbols': [],
#      'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#        'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#        'indices': [89, 112],
#        'url': 'https://t.co/J0eLMdMWPw'}],
#      'user_mentions': [{'id': 80530579,
#        'id_str': '80530579',
#        'indices': [1, 13],
#        'name': 'The Swing Era',
#        'screen_name': 'TheSwingEra'}]},
#     'favorite_count': 7,
#     'favorited': False,
#     'geo': None,
#     'id': 1002915573683060739,
#     'id_str': '1002915573683060739',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-2.033651, 52.381063],
#         [-1.74763, 52.381063],
#         [-1.74763, 52.60687],
#         [-2.033651, 52.60687]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United Kingdom',
#      'country_code': 'GB',
#      'full_name': 'Birmingham, England',
#      'id': '53b67b1d1cc81a51',
#      'name': 'Birmingham',
#      'place_type': 'city',
#      'url': 'https://api.twitter.com/1.1/geo/id/53b67b1d1cc81a51.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '.@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jun 17 22:47:05 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Bringing Birmingham alive with of the best of British & international dance. \nProduced by @dancexchange. \n1-24 June 2018',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'bidf.co.uk',
#          'expanded_url': 'http://bidf.co.uk',
#          'indices': [0, 23],
#          'url': 'https://t.co/deGtX9bFGa'}]}},
#      'favourites_count': 1019,
#      'follow_request_sent': False,
#      'followers_count': 2886,
#      'following': False,
#      'friends_count': 1370,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 48148622,
#      'id_str': '48148622',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 58,
#      'location': 'Birmingham, UK',
#      'name': 'Birmingham International Dance Festival',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48148622/1526467213',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'BhamDanceFest',
#      'statuses_count': 3598,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/deGtX9bFGa',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 16 13:43:30 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "WELCOME TO THE '#WHO-#WHAT-#WHEN-#WHERE-#WHY' (& SOMETIMES '#HOW') OF #EMERGING-#ARTS TALENT.... (BUT NOT ALWAYS IN THAT ORDER)!XX",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 13160,
#     'follow_request_sent': False,
#     'followers_count': 321,
#     'following': False,
#     'friends_count': 590,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2498925456,
#     'id_str': '2498925456',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 54,
#     'location': '#ARTS-WORLD...',
#     'name': 'TiltShift',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/467350912369831936/60QL2Kdb_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/467350912369831936/60QL2Kdb_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TILT_SHIFT_',
#     'statuses_count': 11310,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 14:11:20 +0000 2018',
#    'entities': {'hashtags': [{'indices': [81, 88], 'text': 'BIDF18'}],
#     'symbols': [],
#     'urls': [{'display_url': 'pscp.tv/w/beKcvDFETEVC…',
#       'expanded_url': 'https://www.pscp.tv/w/beKcvDFETEVCQU5MQUpMakp8MWpNS2dxa1dyYVhKTDWOyyJadxEdHdewC9TpiduzmVE4z-eBOxx2_iChYGRA',
#       'indices': [89, 112],
#       'url': 'https://t.co/J0eLMdMWPw'}],
#     'user_mentions': [{'id': 80530579,
#       'id_str': '80530579',
#       'indices': [1, 13],
#       'name': 'The Swing Era',
#       'screen_name': 'TheSwingEra'}]},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 1002915573683060739,
#    'id_str': '1002915573683060739',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': {'attributes': {},
#     'bounding_box': {'coordinates': [[[-2.033651, 52.381063],
#        [-1.74763, 52.381063],
#        [-1.74763, 52.60687],
#        [-2.033651, 52.60687]]],
#      'type': 'Polygon'},
#     'contained_within': [],
#     'country': 'United Kingdom',
#     'country_code': 'GB',
#     'full_name': 'Birmingham, England',
#     'id': '53b67b1d1cc81a51',
#     'name': 'Birmingham',
#     'place_type': 'city',
#     'url': 'https://api.twitter.com/1.1/geo/id/53b67b1d1cc81a51.json'},
# ...
#    'created_at': 'Sat Jun 02 14:07:21 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1002914569562583041',
#       'indices': [117, 140],
#       'url': 'https://t.co/dxcEcxRawf'}],
#     'user_mentions': [{'id': 2600163335,
#       'id_str': '2600163335',
#       'indices': [53, 67],
#       'name': 'The Swing Era',
#       'screen_name': 'theswingeraUK'}]},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 1002914569562583041,
#    'id_str': '1002914569562583041',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': {'attributes': {},
#     'bounding_box': {'coordinates': [[[-2.033651, 52.381063],
#        [-1.74763, 52.381063],
#        [-1.74763, 52.60687],
#        [-2.033651, 52.60687]]],
#      'type': 'Polygon'},
#     'contained_within': [],
#     'country': 'United Kingdom',
#     'country_code': 'GB',
#     'full_name': 'Birmingham, England',
#     'id': '53b67b1d1cc81a51',
#     'name': 'Birmingham',
#     'place_type': 'city',
#     'url': 'https://api.twitter.com/1.1/geo/id/53b67b1d1cc81a51.json'},
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'It don’t mean a thing if you ain’t got that swing! \n\n@theswingeraUK have brought the sunshine with them for their L… https://t.co/dxcEcxRawf',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 17 22:47:05 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Bringing Birmingham alive with of the best of British & international dance. \nProduced by @dancexchange. \n1-24 June 2018',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'bidf.co.uk',
#         'expanded_url': 'http://bidf.co.uk',
#         'indices': [0, 23],
#         'url': 'https://t.co/deGtX9bFGa'}]}},
#     'favourites_count': 1019,
#     'follow_request_sent': False,
#     'followers_count': 2886,
#     'following': False,
#     'friends_count': 1370,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 48148622,
#     'id_str': '48148622',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 58,
#     'location': 'Birmingham, UK',
#     'name': 'Birmingham International Dance Festival',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48148622/1526467213',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963061106183933952/calQ6tIU_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'BhamDanceFest',
#     'statuses_count': 3598,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/deGtX9bFGa',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 13:19:04 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'youtu.be/r5u5nxnroro',
#       'expanded_url': 'https://youtu.be/r5u5nxnroro',
#       'indices': [23, 46],
#       'url': 'https://t.co/sHl2FflVAC'}],
#     'user_mentions': [{'id': 10228272,
#       'id_str': '10228272',
#       'indices': [51, 59],
#       'name': 'YouTube',
#       'screen_name': 'YouTube'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002902421201477633,
#    'id_str': '1002902421201477633',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'is',
#    'metadata': {'iso_language_code': 'is', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Lindy Hop Hellzapoppin https://t.co/sHl2FflVAC vía @YouTube',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 25 02:03:21 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1414,
#     'follow_request_sent': False,
#     'followers_count': 29,
#     'following': False,
#     'friends_count': 330,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 757395783327092737,
#     'id_str': '757395783327092737',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Miguel',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'elsideral221',
#     'statuses_count': 2112,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 13:07:48 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 848126076,
#       'id_str': '848126076',
#       'indices': [3, 16],
#       'name': 'kickingshoes',
#       'screen_name': 'kickingshoes'},
#      {'id': 20696181,
#       'id_str': '20696181',
#       'indices': [34, 40],
#       'name': '(((Neil Kaplan)))',
#       'screen_name': 'NeKap'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002899582269968384,
#    'id_str': '1002899582269968384',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 436,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 14 22:29:35 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/974049933996118017',
#        'indices': [117, 140],
#        'url': 'https://t.co/iUMLFqKVar'}],
#      'user_mentions': [{'id': 20696181,
#        'id_str': '20696181',
#        'indices': [16, 22],
#        'name': '(((Neil Kaplan)))',
#        'screen_name': 'NeKap'}]},
#     'favorite_count': 1052,
#     'favorited': False,
#     'geo': None,
#     'id': 974049933996118017,
#     'id_str': '974049933996118017',
#     'in_reply_to_screen_name': 'kickingshoes',
#     'in_reply_to_status_id': 973655297859362816,
#     'in_reply_to_status_id_str': '973655297859362816',
#     'in_reply_to_user_id': 848126076,
#     'in_reply_to_user_id_str': '848126076',
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 436,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'As requested by @NeKap here are Zarkon and Haggar dancing the Charleston and Lotor doing a Time Step (along with Ho… https://t.co/iUMLFqKVar',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Sep 26 21:10:50 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Kelly & Nichole Matthews are artists for Creature Feature, Power of the Dark Crystal, BREAKER & Toil & Trouble\nhttps://t.co/t71L5BoMoM',
#      'entities': {'description': {'urls': [{'display_url': 'kickingshoes.wixsite.com/kickingshoes',
#          'expanded_url': 'http://kickingshoes.wixsite.com/kickingshoes',
#          'indices': [111, 134],
#          'url': 'https://t.co/t71L5BoMoM'}]},
#       'url': {'urls': [{'display_url': 'kickingshoes.wix.com/kickingshoes',
#          'expanded_url': 'http://kickingshoes.wix.com/kickingshoes',
#          'indices': [0, 23],
#          'url': 'https://t.co/FaCn3fi7Vc'}]}},
#      'favourites_count': 3487,
#      'follow_request_sent': False,
#      'followers_count': 1986,
#      'following': False,
#      'friends_count': 1587,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 848126076,
#      'id_str': '848126076',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 42,
#      'location': 'Lynnwood WA',
#      'name': 'kickingshoes',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/848126076/1501080834',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/922522207351332864/sWEBdQ6j_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922522207351332864/sWEBdQ6j_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'kickingshoes',
#      'statuses_count': 3251,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/FaCn3fi7Vc',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @kickingshoes: As requested by @NeKap here are Zarkon and Haggar dancing the Charleston and Lotor doing a Time Step (along with Honerva…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 17 04:38:40 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '『Red Paladin↣Currently ❅ Blue Paladin↣Formerly』①⑦ⓨⓔⓐⓡⓢ\n╔═══════  ≪ •❈• ≫  ═══════╗\n Member of the paladins of voltron\n╚═══════  ≪ •❈• ≫  ═══════╝',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 370,
#     'follow_request_sent': False,
#     'followers_count': 562,
#     'following': False,
#     'friends_count': 616,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 953486706556243968,
#     'id_str': '953486706556243968',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3,
#     'location': 'м_α_я',
#     'name': 'Lคภςє ≪•คย ץยгเ•≫',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/953486706556243968/1526470608',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/996762724922200064/3S6npH69_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/996762724922200064/3S6npH69_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Bluepaladin_VLG',
#     'statuses_count': 663,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Jun 02 11:41:44 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1002877926629658624',
#       'indices': [117, 140],
#       'url': 'https://t.co/NcKmp07G1K'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1002877926629658624,
#    'id_str': '1002877926629658624',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.myswingmoves.com" rel="nofollow">myswingmoves</a>',
#    'text': 'New post (5/31/18 Swing 1 (swingouts, charleston, slide, big kick, itches, more)) has been published on Lindy Hop S… https://t.co/NcKmp07G1K',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Aug 06 11:52:57 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'myswingmoves.com',
#         'expanded_url': 'http://www.myswingmoves.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/m5NjoAVeGy'}]}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 3,
#     'following': False,
#     'friends_count': 91,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 894164389099585539,
#     'id_str': '894164389099585539',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Singapore',
#     'name': 'Frank',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/894164389099585539/1502023002',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/894175456697565184/GS6vN6FZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/894175456697565184/GS6vN6FZ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'myswingmoves',
#     'statuses_count': 278,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/m5NjoAVeGy',
#     'utc_offset': None,
#     'verified': False}}]}

# %%
# View Search Object
# print(public_tweets)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# Me ha gustado un vídeo de @YouTube (https://t.co/LJYog2Z5Ba - Lindy Hop Hellzapoppin).
# Lindy Hop Hellzapoppin https://t.co/b0MfEGy0YQ vía @YouTube
# RT @TV4LetsDance: Daniel utmanar med en repris av sin Lindy Hop! 🎊🙌 Tyckte du om det? Ring 099-41402 eller sms:a DANIEL till 72400 #letsdan…
# RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw
# RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw
# Me gustó un video de @YouTube https://t.co/Csd4Gwfjq0 Lindy Hop Hellzapoppin
# Had a brilliant time in Birmingham today at the Dance Festival. Had free lessons in the Lindy Hop and Charleston wh… https://t.co/x4cIuwBYpc
# “What did you do today?” Oh, you know... Gym, walked the dog, food, Lindy Hop event, spur-of-the-moment piercing. S… https://t.co/Qnb2U3mx1N
# Top story: Lindy Hop Greece on Twitter: "Can you spot the Lindy Hoppers? Swing … https://t.co/ctfpFqrqaT, see more https://t.co/FI9qPsFvr3
# RT @BhamDanceFest: .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw
# .@theswingera leading a mass Charleston &amp; Lindy Hop class on Victoria Square #BIDF18 https://t.co/J0eLMdMWPw
# It don’t mean a thing if you ain’t got that swing!
#
# @theswingeraUK have brought the sunshine with them for their L… https://t.co/dxcEcxRawf
# Lindy Hop Hellzapoppin https://t.co/sHl2FflVAC vía @YouTube
# RT @kickingshoes: As requested by @NeKap here are Zarkon and Haggar dancing the Charleston and Lotor doing a Time Step (along with Honerva…
# New post (5/31/18 Swing 1 (swingouts, charleston, slide, big kick, itches, more)) has been published on Lindy Hop S… https://t.co/NcKmp07G1K

# %% [markdown]
# # Students Turn Activity 11
# # Hashtag Popularity
#
# ## Instructions
#
# * In this activity, you will calculate the frequency of tweets containing the following hashtags: **#bigdata, #ai, #vr, #foreverchuck**
#
# * Accomplish this task by using Tweepy to search for tweets containing these search terms (Hint: use a loop), then identifying how frequently tweets are sent that contain these keywords.
#
# * You may, of course, use other hashtags.
#
# * You can do this. Good luck!

# %%
# Dependencies
import tweepy
import json
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Hashtags
search_term = ["bigdata", "ai", "vr", "foreverchuck"]
time_btn_tweets = []

# Search for all tweets
for term in search_term:
    print(term)
    public_tweets = api.search(term)
    print(public_tweets)
# Out:
# bigdata
# {'statuses': [{'created_at': 'Sat Jun 02 20:48:49 +0000 2018', 'id': 1003015603710451712, 'id_str': '1003015603710451712', 'text': 'Working with #WA #State &amp; #Local #Government offices focusing on #technology\n\n#NASPO #SVAR #Technology #Blockchain… https://t.co/WPlO4QtUsi', 'truncated': True, 'entities': {'hashtags': [{'text': 'WA', 'indices': [13, 16]}, {'text': 'State', 'indices': [17, 23]}, {'text': 'Local', 'indices': [30, 36]}, {'text': 'Government', 'indices': [37, 48]}, {'text': 'technology', 'indices': [69, 80]}, {'text': 'NASPO', 'indices': [82, 88]}, {'text': 'SVAR', 'indices': [89, 94]}, {'text': 'Technology', 'indices': [95, 106]}, {'text': 'Blockchain', 'indices': [107, 118]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/WPlO4QtUsi', 'expanded_url': 'https://twitter.com/i/web/status/1003015603710451712', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [120, 143]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 828774937640841216, 'id_str': '828774937640841216', 'name': 'WA State & Local', 'screen_name': 'CDWGWAGov', 'location': 'Bellevue, WA', 'description': "Working closely with WA State & Local Gov't stakeholders, focusing on new technology solutions and initiatives, driving positive changes in their environment.", 'url': 'https://t.co/LZXT3JGo0m', 'entities': {'url': {'urls': [{'url': 'https://t.co/LZXT3JGo0m', 'expanded_url': 'http://www.cdwg.com', 'display_url': 'cdwg.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 6416, 'friends_count': 7033, 'listed_count': 106, 'created_at': 'Tue Feb 07 01:18:37 +0000 2017', 'favourites_count': 22540, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 34493, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/982851565475082241/sV75X7aU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/982851565475082241/sV75X7aU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/828774937640841216/1523241084', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': {'id': '300bcc6e23a88361', 'url': 'https://api.twitter.com/1.1/geo/id/300bcc6e23a88361.json', 'place_type': 'city', 'name': 'Seattle', 'full_name': 'Seattle, WA', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-122.436232, 47.4953154], [-122.2249728, 47.4953154], [-122.2249728, 47.734319], [-122.436232, 47.734319]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, {'created_at': 'Sat Jun 02 20:48:48 +0000 2018', 'id': 1003015597876277248, 'id_str': '1003015597876277248', 'text': 'RT @ARLAS_io: When #exploring 48 millions of #AIS positions becomes a game ... Discover the power and fluidity of #GeoBigData exploration b…', 'truncated': False, 'entities': {'hashtags': [{'text': 'exploring', 'indices': [19, 29]}, {'text': 'AIS', 'in ...
# ai
# {'statuses': [{'created_at': 'Sat Jun 02 20:49:01 +0000 2018', 'id': 1003015653257875457, 'id_str': '1003015653257875457', 'text': '@eucaroline2 O amigo ai quer kkk', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'eucaroline2', 'name': '💕', 'id': 367287330, 'id_str': '367287330', 'indices': [0, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1003015512094314497, 'in_reply_to_status_id_str': '1003015512094314497', 'in_reply_to_user_id': 367287330, 'in_reply_to_user_id_str': '367287330', 'in_reply_to_screen_name': 'eucaroline2', 'user': {'id': 978507337974640646, 'id_str': '978507337974640646', 'name': 'Sonhador 🙏', 'screen_name': 'LhauanM', 'location': 'Bangu, Rio de Janeiro', 'description': 'Na vida real o maior vilão sou eu🎼🎵 🙌🙏💓\n\n#Enérgicos⚡💜|\n\nwhats:990537205', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 81, 'friends_count': 127, 'listed_count': 0, 'created_at': 'Tue Mar 27 05:41:43 +0000 2018', 'favourites_count': 499, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 351, 'lang': 'pt', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/980861202719965185/u7B5-CGb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/980861202719965185/u7B5-CGb_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/978507337974640646/1522690432', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'pt'}, {'created_at': 'Sat Jun 02 20:49:01 +0000 2018', 'id': 1003015653241114626, 'id_str': '1003015653241114626', 'text': "RT @PanHoodjabi: J'ai perdu mon téléphone vers République à Lille aujourd'hui. C'est un Samsung galaxy S5 noir avec une coque jaune ( table…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PanHoodjabi', 'name': 'Mrs Hijab', 'id': 2504780877, 'id_str': '2504780877', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 938890665936740352, 'id_str': '938890665936740352', 'name': 'No chill', 'screen_name': 'thistruthteeam', 'location': '', 'description': "La trollerie n'est jamais finie", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 75, 'friends_count': 62, 'listed_count': 0, 'created_at': 'Thu Dec 07 21:59:13 +0000 2017', 'favourites_count': 2503, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3395, 'lang': 'fr', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/ima ...
# vr
# {'statuses': [{'created_at': 'Sat Jun 02 20:49:00 +0000 2018', 'id': 1003015648161615872, 'id_str': '1003015648161615872', 'text': 'Take a VR journey to an exoplanet with NASA’s new ‘Travel Bureau’ https://t.co/3Dh98A5tcJ https://t.co/iX8zDdKKFY', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/3Dh98A5tcJ', 'expanded_url': 'http://dlvr.it/QVzYl7', 'display_url': 'dlvr.it/QVzYl7', 'indices': [66, 89]}], 'media': [{'id': 1003015646370598913, 'id_str': '1003015646370598913', 'indices': [90, 113], 'media_url': 'http://pbs.twimg.com/media/DettaooUEAEOi88.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DettaooUEAEOi88.jpg', 'url': 'https://t.co/iX8zDdKKFY', 'display_url': 'pic.twitter.com/iX8zDdKKFY', 'expanded_url': 'https://twitter.com/RobieCuriel/status/1003015648161615872/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1003015646370598913, 'id_str': '1003015646370598913', 'indices': [90, 113], 'media_url': 'http://pbs.twimg.com/media/DettaooUEAEOi88.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DettaooUEAEOi88.jpg', 'url': 'https://t.co/iX8zDdKKFY', 'display_url': 'pic.twitter.com/iX8zDdKKFY', 'expanded_url': 'https://twitter.com/RobieCuriel/status/1003015648161615872/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1200, 'h': 628, 'resize': 'fit'}, 'small': {'w': 680, 'h': 356, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 306885876, 'id_str': '306885876', 'name': 'Roberto Curiel', 'screen_name': 'RobieCuriel', 'location': 'ciudad de mexico', 'description': 'Gerente de Medios Digitales en Megamedia, feliz de trabajar en medios y en permanente aprendizaje Digital, amante de la tecnología, cine y un buen vino.', 'url': 'https://t.co/u4KjN6gy5Q', 'entities': {'url': {'urls': [{'url': 'https://t.co/u4KjN6gy5Q', 'expanded_url': 'http://www.yucatan.com.mx', 'display_url': 'yucatan.com.mx', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 140, 'friends_count': 289, 'listed_count': 0, 'created_at': 'Sat May 28 16:29:41 +0000 2011', 'favourites_count': 102, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3148, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/470745438333976577/_IO-uRVg_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/470745438333976577/_IO-uRVg_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/306885876/1359870800', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, ' ...
# foreverchuck
# {'statuses': [{'created_at': 'Sat Jun 02 16:59:02 +0000 2018', 'id': 1002957774102376450, 'id_str': '1002957774102376450', 'text': 'RT @AlissaViolet: Killing it in my red @Converse high tops. #ForeverChuck #ad https://t.co/qneguMWaRY https://t.co/EIy6XozTHY', 'truncated': False, 'entities': {'hashtags': [{'text': 'ForeverChuck', 'indices': [60, 73]}, {'text': 'ad', 'indices': [74, 77]}], 'symbols': [], 'user_mentions': [{'screen_name': 'AlissaViolet', 'name': 'Alissa Violet', 'id': 529547302, 'id_str': '529547302', 'indices': [3, 16]}, {'screen_name': 'Converse', 'name': 'Converse', 'id': 183398746, 'id_str': '183398746', 'indices': [39, 48]}], 'urls': [{'url': 'https://t.co/qneguMWaRY', 'expanded_url': 'https://youtu.be/2XgInjmWYcA', 'display_url': 'youtu.be/2XgInjmWYcA', 'indices': [78, 101]}], 'media': [{'id': 933801147525033984, 'id_str': '933801147525033984', 'indices': [102, 125], 'media_url': 'http://pbs.twimg.com/media/DPWHMjkU8AA_xpg.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DPWHMjkU8AA_xpg.jpg', 'url': 'https://t.co/EIy6XozTHY', 'display_url': 'pic.twitter.com/EIy6XozTHY', 'expanded_url': 'https://twitter.com/AlissaViolet/status/933801155146199040/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 933801155146199040, 'source_status_id_str': '933801155146199040', 'source_user_id': 529547302, 'source_user_id_str': '529547302'}]}, 'extended_entities': {'media': [{'id': 933801147525033984, 'id_str': '933801147525033984', 'indices': [102, 125], 'media_url': 'http://pbs.twimg.com/media/DPWHMjkU8AA_xpg.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DPWHMjkU8AA_xpg.jpg', 'url': 'https://t.co/EIy6XozTHY', 'display_url': 'pic.twitter.com/EIy6XozTHY', 'expanded_url': 'https://twitter.com/AlissaViolet/status/933801155146199040/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 933801155146199040, 'source_status_id_str': '933801155146199040', 'source_user_id': 529547302, 'source_user_id_str': '529547302'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 947235049740660737, 'id_str': '947235049740660737', 'name': 'geoffrey', 'screen_name': 'Geoffrey304_', 'location': 'Alissa', 'description': 'fortnite and crap. my duo @akadylanns13', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Sat Dec 30 22:36:49 +0000 2017', 'favourites_count': 436, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 564, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1000419011820220418/A5yMGGuP_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000419011820220418/A5yMGGuP_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/947235049740660737/1526245744', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, ' ...

# %% [markdown]
# # Students turn Activity 11

# %% [markdown]
# # Subway Delays in New York City
#
# ## Instructions
#
# * In this activity, you will use data gathered from Twitter to plot which trains in the NYC subway system most frequently cause delays.
#
# * The Twitter account **SubwayStats** announces delays and changes in the NYC subway system.
#
# * Your goal is to pull the 1,000 most recent tweets from that account and use MatPlotLib to generate a bar chart of the number of delays per each train:
#
#   ![subway.png](subway.png)
#
# * Accomplish this task by first compiling a Python dictionary, whose key value pairs consist of each train and the number of delays:
#
#   ![subway1.png](subway1.png)
#
# * In order to build such a dictionary, you will need to filter the tweet texts.
#
# * See the Jupyter Notebook file for more specific instructions at each step. Good luck!

# %%
# Dependencies
import tweepy
import json
import pandas as pd
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Array of Trains
delayed_trains = {}
    
# Target User
target_user = "SubwayStats"

# Loop through 50 pages of 
for x in range(1,51):
    
    public_tweets = api.user_timeline(target_user, page=x)
    
    for tweet in public_tweets:
        tweet_text = tweet["text"].lower().split(" ")
        
        if ("delays" in tweet_text or "change" in tweet_text):
        
        # Create a counter for viewing every 100 tweets
        if counter % 100 == 0: #multiple of 100
            print(raw_time)

# %%
# Print the Train Delay counts


# Convert Train Delay object into a series

# Preview the results

# %%
# Create a plot
